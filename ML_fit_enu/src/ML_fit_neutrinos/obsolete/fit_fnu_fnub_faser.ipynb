# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
# from read_fk_table import get_fk_table
from read_faserv_pdf import read_pdf
# from read_LHEF import read_LHEF_data
from data_errors import compute_errors
from MC_data_reps import generate_MC_replicas
from postfit_criteria import Postfit
from form_loss_fct import complete_loss_fct, raw_loss_fct
from postfit_measures import Measures
from logspace_grid import generate_grid
# from rebin_fk_data import rebin_fk

# %%
# Define global variables
num_obs = 1 #between 1 and 4
REPLICAS  = 1

#HYPERPARAMETERS
preproc = 1
l1 = 2
l2 = 2
l3 = 2

fit_level = 0

lr = 0.1
max_counter = 100
max_Nepochs = 3500

# %%
# def read_LHEF_data():
#     """Read histograms of data

#     Args:
#         num_obs (int): number of files to read data from

#     Returns:
#         tuple: returns tuple of lists and arrays containing the data
#     """

#     filenames = ["data_Enu_mu"]
#     (binwidths, events, xvals_per_obs, max_events, min_events, xlabels) = (
#         [],
#         [],
#         [],
#         [],
#         [],
#         [],
#     )
#     lumin_factor = 65.6 / 150
#     val_n = np.loadtxt(f"data/{filenames[0]}_n.dat", unpack=True)
#     val_p = np.loadtxt(f"data/{filenames[0]}_p.dat", unpack=True)
    
#     val = 74 / 183 * val_p + (183 - 74) / 183 * val_n
#     diff = 100
#     val *= diff * lumin_factor
#     err = val/20
#     events = val
#     xvals_per_obs = np.arange(0,6000,100)
#     min_events = val - err
#     max_events = (val + err)
#     binwidths = diff * lumin_factor

#     xlabels.append(filenames[0].replace(".dat", ""))

#     events_per_obs = events

#     return (
#         events,
#         max_events,
#         min_events,
#         xvals_per_obs,
#         binwidths,
#         xlabels,
#         events_per_obs,
#     )

# %%
# from read_fk_table import get_fk_table

import pandas as pd
# import torch
import torch.nn.functional


def get_fk_table(filename):
    """This function reads the fk table for the neutrino flux and pads them for computational efficiency later on

    Returns:
        tuple: x_alphas(grid points) and the fk table in tensor to fit torch
    """

    file_path_n = f"data/{filename}_n.dat"
    df_n = pd.read_csv(file_path_n, sep="\s+", header=None)
    fk_table_n = df_n.to_numpy()

    file_path_p = f"data/{filename}_p.dat"
    df_p = pd.read_csv(file_path_p, sep="\s+", header=None)
    fk_table_p = df_p.to_numpy()

    x_alpha = fk_table_p[0, :]
    x_alpha = x_alpha.reshape(len(x_alpha), 1)

    fk_table = (74 / 183 )* fk_table_p + ((183 - 74) / 183) * fk_table_n

    # strip first row to get fk table
    fk_table = fk_table[1:, :]

    x_alpha = torch.tensor(x_alpha, dtype=torch.float32).view(-1, 1)
    fk_table = torch.tensor(fk_table, dtype=torch.float32)

    return x_alpha, fk_table

filename = "FK_Enu_mu"
x_alphas, fk_tables_mu = get_fk_table(filename = filename)
filename = "FK_Enu_mub"
x_alphas, fk_tables_mub = get_fk_table(filename = filename)
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_22806/4156442672.py:16: SyntaxWarning: invalid escape sequence '\s'
#   df_n = pd.read_csv(file_path_n, sep="\s+", header=None)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_22806/4156442672.py:20: SyntaxWarning: invalid escape sequence '\s'
#   df_p = pd.read_csv(file_path_p, sep="\s+", header=None)

# %%
# events = [50, 97, 71, 69, 48, 27]
# minev = [5.9, 4.3, 2.5, 2.2, 3.7,5.1]
events = [66.8, 44.3 +92.7+ 68.5, 21.9+44.1]
# events = [33.6, 59.5, 51.6, 84.1, 50.1, 19.6]
std_errev = [1.6,2.3 +2.5+1.7 ,2.9+3.1]
# events = []
# events, max_events, min_events, xvals_per_obs, binwidths, xlabels, events_per_obs, = read_LHEF_data()

sig_sys = std_errev
sig_stat = np.sqrt(events)
binwidths = 100 * 65.6/150 
xlabels = ['mu']
data = events
def rebin_fk(faser_bins,fk_tables):

    # xvals_per_obs = high[:-1]
    xvals_per_obs = np.arange(0, 6100, 100)
    print(xvals_per_obs)
    # xvals_per_obs = np.array(xvals_per_obs)
    # data = np.array(data)
    # data_faser,data_faser_min,data_faser_max, = ,[],[],[]
    fk_tables_faser = []
    lower_bound = 100
    # faser_bins = [300, 600, 1000,1900]
    for bin_val in faser_bins:
        indices = np.where((xvals_per_obs < bin_val) & (xvals_per_obs >= lower_bound))[0]

        print(indices)

        # max_range = max(indices) + min_range + 1

        # data_faser.append(np.sum(data[min_range:max_range]))
        # data_faser_min.append(np.sum(data_min[min_range:max_range]))
        # data_faser_max.append(np.sum(data_max[min_range:max_range]))

        # xvals_per_obs = xvals_per_obs[max(indices)  :]
  
        summed_column = torch.sum(fk_tables[min(indices):max(indices) +1, :], axis=0)
        summed_column = summed_column.unsqueeze(0)
        print(summed_column.shape)
        fk_tables_faser.append(summed_column)

        # min_range = max_range
        lower_bound = bin_val

    # xvals_per_obs_faser.append(xvals_per_obs[-1])    
    # summed_column = torch.sum(fk_tables[max_range:, :], axis=0)
    # summed_column = summed_column.unsqueeze(0)
    # data_faser.append(np.sum(data[max_range:]))
    # data_faser_min.append(np.sum(data_min[max_range:]))
    # data_faser_max.append(np.sum(data_max[max_range:]))
    # fk_tables_faser.append(summed_column)


    fk_tables_faser = torch.cat(fk_tables_faser, dim=0)

    
    # data_faser = np.array(data_faser)
    # data_faser_min = np.array(data_faser_min)
    # data_faser_max = np.array(data_faser_max)


    return fk_tables_faser


# data, data_min, data_max, xvals_per_obs, binwidths, xlabels, events_per_obs = rebin_fk()
faser_bins_mu = [300, 1000,1900]
fk_table_mu = rebin_fk(faser_bins_mu,fk_tables_mu)
faser_bins_mub = [300, 1000,1900]
fk_table_mub = rebin_fk(faser_bins_mub,fk_tables_mub)

fk_tables = fk_table_mu + fk_table_mub


xvals_per_obs_mu = [100,300,600,1000]
xvals_per_obs = [-1000,-300,-100]
xvals_per_obs_mub = [-100,-300,-1000]
# Out:
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100
#  4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500
#  5600 5700 5800 5900 6000]
# [1 2]
# torch.Size([1, 50])
# [3 4 5 6 7 8 9]
# torch.Size([1, 50])
# [10 11 12 13 14 15 16 17 18]
# torch.Size([1, 50])
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100
#  4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500
#  5600 5700 5800 5900 6000]
# [1 2]
# torch.Size([1, 50])
# [3 4 5 6 7 8 9]
# torch.Size([1, 50])
# [10 11 12 13 14 15 16 17 18]
# torch.Size([1, 50])

# %%
pdf = "faserv"
faser_pdf,x_faser = read_pdf(pdf,x_alphas.flatten(),14)
faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
conv = torch.matmul(fk_table_mu,faser_pdf) * binwidths 
plt.plot(xvals_per_obs,conv,label='conv')


faser_pdf,x_faser = read_pdf(pdf,x_alphas.flatten(),-14)
faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
conv = torch.matmul(fk_table_mub,faser_pdf) * binwidths 
plt.plot(xvals_per_obs,conv,label='conv2')

plt.plot(xvals_per_obs,data,'o',label='data')
plt.legend()
print(conv.detach().numpy().flatten())
print(data[:-2])
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# [  4.514426 160.57054  121.87771 ]
# [66.8]
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_22806/1075048817.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_22806/1075048817.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)

# %%
# data,data_min,data_max,xvals_per_obs,binwidths,xlabels,events_per_obs,fk_tables,x_alphas = rebin_fk(rebin=1)

# %%
#Get errors
# sig_sys,sig_tot, cov_matrix = compute_errors(data,data_min,data_max)  
# xvals_per_obs = [100,300,600,-100,-300,1000] 
# xvals_per_obs = [100,300,600,100,-300,-100]  
# cov_matrix = np.array([
#     [9.2,-0.32,  0.08, -0.03,  0.00,  0.00],
#     [-0.32, 10.2, -0.43,  0.10, -0.01, -0.00],
#     [ 0.08, -0.43, 9.6, -0.31,  0.04, -0.02],
#     [-0.03,  0.10, -0.31, 22.3,-0.14,  0.01],
#     [ 0.00, -0.01,  0.04, -0.14, 12.1,-0.24],
#     [ 0.00, -0.00, -0.02,  0.01, -0.24,7.5]
# ])
cov_matrix = np.array([
    [ 1738, -130+281-734,   15-69],
    [ -130+281-734,  622+6239+4165, -147+2-4-1623-27+340],
    [  15-69, -147+2-4-1623-27+34,  847+5186]
])
sig_sys = np.array(sig_sys)
# np.fill_diagonal(cov_matrix, sig_stat**2 + sig_sys**2)
cov_matrix = np.linalg.inv(cov_matrix)
cov_matrix = torch.tensor(cov_matrix, dtype=torch.float32, requires_grad=False)
#Generate MC replicas of data
level0,level1,level2 = generate_MC_replicas(REPLICAS,data,sig_sys,sig_stat)
# Get faserv pdf
pdf = "faserv"
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
faser_pdf,x_faser = read_pdf(pdf,x_vals,14)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
if fit_level ==0:
    pred = level0
if fit_level ==1:
    pred = level1
if fit_level ==2:
    pred = level2

# %%
print(data)
print(level1)
print(level2)
plt.plot(xvals_per_obs,data)
plt.xlabel(xlabels)
plt.ylabel('N')
plt.title("raw data")
plt.show()

for i in range(REPLICAS):
    plt.plot(
        xvals_per_obs, level2[i], 'o',label="level2"
    )
    plt.plot(
        xvals_per_obs, level1[i], 'o',label="level1"
    )
    plt.plot(xvals_per_obs, data,'o',label="level0")
    plt.xlabel(xlabels)
    plt.legend()
    plt.ylabel("N")
    plt.title("level 2 data")
    plt.show()
# Out:
# [66.8, 205.5, 66.0]
# [tensor([ 58.4892, 191.1441,  63.9395])]
# [tensor([ 58.8132, 162.3255,  60.9965])]

# %%
class SimplePerceptron(torch.nn.Module):
    def __init__(self, l1,l2,l3):
        super(SimplePerceptron, self).__init__()
        self.linear = torch.nn.Linear(1,l1)
        self.hidden = torch.nn.Linear(l1,l2)
        self.hidden2 = torch.nn.Linear(l2,l3)
        self.hidden3 = torch.nn.Linear(l3,1)
        self.relu = torch.nn.ReLU()

    def forward(self, y):
        y = self.linear(y)
        y = self.relu(y)
        y = self.hidden(y)
        y = self.relu(y)
        y = self.hidden2(y)
        y = self.relu(y)
        y = self.hidden3(y)
        y = self.relu(y)
        # y = torch.nn.functional.softplus(y)
    
        return y

# %%
import torch.nn as nn

if preproc == 1:
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha,beta,gamma):
            super(CustomPreprocessing, self).__init__()

            # self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
            # self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32, requires_grad=True))
            # self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32, requires_grad=True))

            self.register_buffer("alpha", torch.tensor(alpha, dtype=torch.float32))
            self.register_buffer("beta", torch.tensor(beta, dtype=torch.float32))
            self.register_buffer("gamma", torch.tensor(gamma, dtype=torch.float32))

        def forward(self, x):
            # alpha = (1 - 0.2)/2 *torch.tanh(self.alpha) + (1 + 0.2)/2
            # beta = (1.9 - 0.1)/2 *torch.tanh(self.alpha) + (1.9 + 0.1)/2
            # beta = abs(self.beta)
            alpha = 1 - torch.nn.functional.softplus(self.alpha)
            return self.gamma * (1 - x) ** self.beta * x**(1-alpha) 
            # return 10 * (1 - x)**2 * x**(1.5) 
            # return  self.gamma*(1 - x) ** self.beta * x**(1-self.alpha) 
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha, beta, gamma,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha, beta,gamma)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            f_preproc = self.preprocessing(x)
            f_NN = self.mlp(x)
            f_nu = f_preproc * f_NN
            return f_NN
        
        def neuralnet(self, x):
            f_NN = self.mlp(x)
            return f_NN
        
        def preproc(self, x):
            f_preproc = self.preprocessing(x)
            return f_preproc

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss,self).__init__()

    def forward(self,pred,
    data,
    cov_matrix):
        loss = raw_loss_fct(pred,
    data,
    cov_matrix)
        return loss

# %%
#Define variables for fit
# x_alpha_more_bins = np.logspace(-5,0,250)
# x_alpha_more_bins = torch.tensor(x_alpha_more_bins, dtype=torch.float32).view(-1,1)
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
x_vals = torch.tensor(x_vals, dtype=torch.float32).view(-1,1)
neutrino_pdfs_mu,neutrino_pdfs_mub,N_event_pred, arc_lenghts, chi_squares, int_penaltys,pos_penaltys, preproc_pdfs, nn_pdfs  = [],[],[],[],[],[],[],[],[]

# %%
# x_alphas *=2
if preproc == 1:
    alpha,beta,gamma = 1,1,10
    model = PreprocessedMLP(alpha, beta, gamma,l1, l2, l3)
         
            # model.load_state_dict(model_params)    

    criterion = CustomLoss()
        # criterion = torch.nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=0.001)
    # optimizer = torch.optim.Adam(model.parameters(), lr=lr)
def perform_fit(pred,REPLICAS):
    for i in range(REPLICAS):
        losses = []
        pred[i] = pred[i].squeeze()
        model.train()
        best_loss = 1e13 # initial loss
        counter = 0
        num_epochs = 6000
        # num_epochs = 0
        for ep in range(num_epochs):
        # while counter < max_counter:  
            # if num_epochs>max_Nepochs:
            #     break
            
            # num_epochs+=1
            optimizer.zero_grad()
            y_pred =  model(x_alphas) 
            # y_pred =  model(x_alphas) * x_alphas
            y_preds = torch.matmul(fk_tables,y_pred)  * binwidths 

            y_preds = y_preds.squeeze()

            loss = (criterion(y_preds, pred[i],cov_matrix))
            loss.backward()
            print(loss)
    
            losses.append(loss.detach().numpy())
            optimizer.step()
            
            # if ep % 100 == 0:
            #     print(loss.detach().numpy())   
            if abs(loss) <.02:
                break
            if loss < best_loss:
                best_loss = loss
                counter = 0
            else:
                counter +=1   

        if loss < 10:    

            print(f"reduced chi^2 level 2 = {loss}")
            # print(f"reduced chi^2 level 1 = {red_chi_square_level1}")
            print(f"Constrained alpha: {(model.preprocessing.alpha.item())}")
            print(f"Constrained beta: {(model.preprocessing.beta.item())}")
            print(f"Constrained gamma: {model.preprocessing.gamma.item()}") 

            # save outcome of fit and its measures for postfit selection criteria
            chi_squares.append(loss.detach().numpy())
            # preproc_pdf = ((1 - x_alpha_more_bins) ** (beta) * x_alpha_more_bins ** (1-alpha)).detach().numpy().flatten()
            f_nu_mu = model(x_vals).detach().numpy().flatten() 
            
            # print(preproc_pdf.shape)

            preproc_pdfs.append(model.preproc(x_vals).detach().numpy().flatten())
            nn_pdfs.append(model.neuralnet(x_vals).detach().numpy().flatten())

            N_event_pred.append(y_preds.detach().numpy())
            plt.plot(xvals_per_obs,y_preds.detach().numpy().flatten(),label = 'nn')
            plt.plot(xvals_per_obs,pred[i],label = 'level2')
            plt.legend()
            plt.show()
            # cont_pred = model(x_alpha_more_bins).detach().numpy().flatten()
            neutrino_pdfs_mu.append(f_nu_mu)

            plt.yscale('log')
            print(f'counter = {counter}')
            plt.plot(range(1, len(losses) + 1), losses)
            plt.xlabel('#epochs')
            plt.ylabel('loss')
            plt.title('level 0 closure test, no preprocessing')
            plt.show()
            # plt.plot(x_alpha_more_bins,preproc_pdf)
            # plt.xscale('log')
            # plt.yscale('log')
            # plt.show()
    # return arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model
    return chi_squares,N_event_pred, neutrino_pdfs_mu,neutrino_pdfs_mub,model

# %%
chi_squares,N_event_pred, neutrino_pdfs_mu,neutrino_pdfs_mub,model = perform_fit(pred,REPLICAS)
# Out:
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1724, grad_fn=<DotBackward0>)
# tensor(9.1722, grad_fn=<DotBackward0>)
# tensor(9.1710, grad_fn=<DotBackward0>)
# tensor(9.1697, grad_fn=<DotBackward0>)
# tensor(9.1682, grad_fn=<DotBackward0>)
# tensor(9.1664, grad_fn=<DotBackward0>)
# tensor(9.1643, grad_fn=<DotBackward0>)
# tensor(9.1618, grad_fn=<DotBackward0>)
# tensor(9.1590, grad_fn=<DotBackward0>)
# tensor(9.1558, grad_fn=<DotBackward0>)
# tensor(9.1521, grad_fn=<DotBackward0>)
# tensor(9.1481, grad_fn=<DotBackward0>)
# tensor(9.1436, grad_fn=<DotBackward0>)
# tensor(9.1386, grad_fn=<DotBackward0>)
# tensor(9.1332, grad_fn=<DotBackward0>)
# tensor(9.1271, grad_fn=<DotBackward0>)
# tensor(9.1202, grad_fn=<DotBackward0>)
# tensor(9.1125, grad_fn=<DotBackward0>)
# tensor(9.1036, grad_fn=<DotBackward0>)
# tensor(9.0934, grad_fn=<DotBackward0>)
# tensor(9.0818, grad_fn=<DotBackward0>)
# tensor(9.0683, grad_fn=<DotBackward0>)
# tensor(9.0526, grad_fn=<DotBackward0>)
# tensor(9.0340, grad_fn=<DotBackward0>)
# tensor(9.0121, grad_fn=<DotBackward0>)
# tensor(8.9858, grad_fn=<DotBackward0>)
# tensor(8.9544, grad_fn=<DotBackward0>)
# tensor(8.9167, grad_fn=<DotBackward0>)
# tensor(8.8714, grad_fn=<DotBackward0>)
# tensor(8.8171, grad_fn=<DotBackward0>)
# tensor(8.7523, grad_fn=<DotBackward0>)
# tensor(8.6752, grad_fn=<DotBackward0>)
# tensor(8.5842, grad_fn=<DotBackward0>)
# tensor(8.4775, grad_fn=<DotBackward0>)
# tensor(8.3535, grad_fn=<DotBackward0>)
# tensor(8.2109, grad_fn=<DotBackward0>)
# tensor(8.0488, grad_fn=<DotBackward0>)
# tensor(7.8671, grad_fn=<DotBackward0>)
# tensor(7.6666, grad_fn=<DotBackward0>)
# tensor(7.4501, grad_fn=<DotBackward0>)
# tensor(7.2223, grad_fn=<DotBackward0>)
# tensor(6.9910, grad_fn=<DotBackward0>)
# tensor(6.7681, grad_fn=<DotBackward0>)
# tensor(6.5702, grad_fn=<DotBackward0>)
# tensor(6.4194, grad_fn=<DotBackward0>)
# tensor(6.3409, grad_fn=<DotBackward0>)
# tensor(6.3545, grad_fn=<DotBackward0>)
# tensor(6.4526, grad_fn=<DotBackward0>)
# tensor(6.5799, grad_fn=<DotBackward0>)
# tensor(6.6628, grad_fn=<DotBackward0>)
# tensor(6.6675, grad_fn=<DotBackward0>)
# tensor(6.6079, grad_fn=<DotBackward0>)
# tensor(6.5182, grad_fn=<DotBackward0>)
# tensor(6.4304, grad_fn=<DotBackward0>)
# tensor(6.3658, grad_fn=<DotBackward0>)
# tensor(6.3334, grad_fn=<DotBackward0>)
# tensor(6.3316, grad_fn=<DotBackward0>)
# tensor(6.3512, grad_fn=<DotBackward0>)
# tensor(6.3783, grad_fn=<DotBackward0>)
# tensor(6.4011, grad_fn=<DotBackward0>)
# tensor(6.4141, grad_fn=<DotBackward0>)
# tensor(6.4166, grad_fn=<DotBackward0>)
# tensor(6.4100, grad_fn=<DotBackward0>)
# tensor(6.3970, grad_fn=<DotBackward0>)
# tensor(6.3803, grad_fn=<DotBackward0>)
# tensor(6.3629, grad_fn=<DotBackward0>)
# tensor(6.3470, grad_fn=<DotBackward0>)
# tensor(6.3342, grad_fn=<DotBackward0>)
# tensor(6.3256, grad_fn=<DotBackward0>)
# tensor(6.3213, grad_fn=<DotBackward0>)
# tensor(6.3207, grad_fn=<DotBackward0>)
# tensor(6.3228, grad_fn=<DotBackward0>)
# tensor(6.3262, grad_fn=<DotBackward0>)
# tensor(6.3294, grad_fn=<DotBackward0>)
# tensor(6.3312, grad_fn=<DotBackward0>)
# tensor(6.3310, grad_fn=<DotBackward0>)
# tensor(6.3289, grad_fn=<DotBackward0>)
# tensor(6.3253, grad_fn=<DotBackward0>)
# tensor(6.3213, grad_fn=<DotBackward0>)
# tensor(6.3177, grad_fn=<DotBackward0>)
# tensor(6.3150, grad_fn=<DotBackward0>)
# tensor(6.3135, grad_fn=<DotBackward0>)
# tensor(6.3132, grad_fn=<DotBackward0>)
# tensor(6.3136, grad_fn=<DotBackward0>)
# tensor(6.3145, grad_fn=<DotBackward0>)
# tensor(6.3152, grad_fn=<DotBackward0>)
# tensor(6.3155, grad_fn=<DotBackward0>)
# tensor(6.3152, grad_fn=<DotBackward0>)
# tensor(6.3143, grad_fn=<DotBackward0>)
# tensor(6.3128, grad_fn=<DotBackward0>)
# tensor(6.3108, grad_fn=<DotBackward0>)
# tensor(6.3086, grad_fn=<DotBackward0>)
# tensor(6.3065, grad_fn=<DotBackward0>)
# tensor(6.3050, grad_fn=<DotBackward0>)
# tensor(6.3045, grad_fn=<DotBackward0>)
# tensor(6.3040, grad_fn=<DotBackward0>)
# tensor(6.3027, grad_fn=<DotBackward0>)
# tensor(6.3008, grad_fn=<DotBackward0>)
# tensor(6.2990, grad_fn=<DotBackward0>)
# tensor(6.2973, grad_fn=<DotBackward0>)
# tensor(6.2968, grad_fn=<DotBackward0>)
# tensor(6.2939, grad_fn=<DotBackward0>)
# tensor(6.2915, grad_fn=<DotBackward0>)
# tensor(6.2888, grad_fn=<DotBackward0>)
# tensor(6.2859, grad_fn=<DotBackward0>)
# tensor(6.2828, grad_fn=<DotBackward0>)
# tensor(6.2792, grad_fn=<DotBackward0>)
# tensor(6.2749, grad_fn=<DotBackward0>)
# tensor(6.2702, grad_fn=<DotBackward0>)
# tensor(6.2652, grad_fn=<DotBackward0>)
# tensor(6.2600, grad_fn=<DotBackward0>)
# tensor(6.2542, grad_fn=<DotBackward0>)
# tensor(6.2476, grad_fn=<DotBackward0>)
# tensor(6.2405, grad_fn=<DotBackward0>)
# tensor(6.2334, grad_fn=<DotBackward0>)
# tensor(6.2255, grad_fn=<DotBackward0>)
# tensor(6.2170, grad_fn=<DotBackward0>)
# tensor(6.2097, grad_fn=<DotBackward0>)
# tensor(6.1991, grad_fn=<DotBackward0>)
# tensor(6.1900, grad_fn=<DotBackward0>)
# tensor(6.1796, grad_fn=<DotBackward0>)
# tensor(6.1693, grad_fn=<DotBackward0>)
# tensor(6.1592, grad_fn=<DotBackward0>)
# tensor(6.1477, grad_fn=<DotBackward0>)
# tensor(6.1365, grad_fn=<DotBackward0>)
# tensor(6.1241, grad_fn=<DotBackward0>)
# tensor(6.1121, grad_fn=<DotBackward0>)
# tensor(6.0986, grad_fn=<DotBackward0>)
# tensor(6.0848, grad_fn=<DotBackward0>)
# tensor(6.0707, grad_fn=<DotBackward0>)
# tensor(6.0555, grad_fn=<DotBackward0>)
# tensor(6.0439, grad_fn=<DotBackward0>)
# tensor(6.0207, grad_fn=<DotBackward0>)
# tensor(6.0069, grad_fn=<DotBackward0>)
# tensor(5.9841, grad_fn=<DotBackward0>)
# tensor(5.9605, grad_fn=<DotBackward0>)
# tensor(5.9421, grad_fn=<DotBackward0>)
# tensor(5.9118, grad_fn=<DotBackward0>)
# tensor(5.8873, grad_fn=<DotBackward0>)
# tensor(5.8582, grad_fn=<DotBackward0>)
# tensor(5.8253, grad_fn=<DotBackward0>)
# tensor(5.7913, grad_fn=<DotBackward0>)
# tensor(5.7527, grad_fn=<DotBackward0>)
# tensor(5.7179, grad_fn=<DotBackward0>)
# tensor(5.6773, grad_fn=<DotBackward0>)
# tensor(5.6261, grad_fn=<DotBackward0>)
# tensor(5.5861, grad_fn=<DotBackward0>)
# tensor(5.5300, grad_fn=<DotBackward0>)
# tensor(5.4825, grad_fn=<DotBackward0>)
# tensor(5.4247, grad_fn=<DotBackward0>)
# tensor(5.3737, grad_fn=<DotBackward0>)
# tensor(5.3142, grad_fn=<DotBackward0>)
# tensor(5.2610, grad_fn=<DotBackward0>)
# tensor(5.1822, grad_fn=<DotBackward0>)
# tensor(5.1117, grad_fn=<DotBackward0>)
# tensor(5.0498, grad_fn=<DotBackward0>)
# tensor(4.9598, grad_fn=<DotBackward0>)
# tensor(4.8857, grad_fn=<DotBackward0>)
# tensor(4.8051, grad_fn=<DotBackward0>)
# tensor(4.7069, grad_fn=<DotBackward0>)
# tensor(4.6260, grad_fn=<DotBackward0>)
# tensor(4.5220, grad_fn=<DotBackward0>)
# tensor(4.4301, grad_fn=<DotBackward0>)
# tensor(4.3182, grad_fn=<DotBackward0>)
# tensor(4.2314, grad_fn=<DotBackward0>)
# tensor(4.1018, grad_fn=<DotBackward0>)
# tensor(4.0241, grad_fn=<DotBackward0>)
# tensor(3.8867, grad_fn=<DotBackward0>)
# tensor(3.8077, grad_fn=<DotBackward0>)
# tensor(3.6578, grad_fn=<DotBackward0>)
# tensor(3.5638, grad_fn=<DotBackward0>)
# tensor(3.4447, grad_fn=<DotBackward0>)
# tensor(3.3316, grad_fn=<DotBackward0>)
# tensor(3.2339, grad_fn=<DotBackward0>)
# tensor(3.1235, grad_fn=<DotBackward0>)
# tensor(3.0465, grad_fn=<DotBackward0>)
# tensor(2.9598, grad_fn=<DotBackward0>)
# tensor(2.8890, grad_fn=<DotBackward0>)
# tensor(2.7996, grad_fn=<DotBackward0>)
# tensor(2.7276, grad_fn=<DotBackward0>)
# tensor(2.6414, grad_fn=<DotBackward0>)
# tensor(2.5690, grad_fn=<DotBackward0>)
# tensor(2.5061, grad_fn=<DotBackward0>)
# tensor(2.4399, grad_fn=<DotBackward0>)
# tensor(2.3980, grad_fn=<DotBackward0>)
# tensor(2.3560, grad_fn=<DotBackward0>)
# tensor(2.3316, grad_fn=<DotBackward0>)
# tensor(2.3101, grad_fn=<DotBackward0>)
# tensor(2.2924, grad_fn=<DotBackward0>)
# tensor(2.2781, grad_fn=<DotBackward0>)
# tensor(2.2673, grad_fn=<DotBackward0>)
# tensor(2.2580, grad_fn=<DotBackward0>)
# tensor(2.2529, grad_fn=<DotBackward0>)
# tensor(2.2471, grad_fn=<DotBackward0>)
# tensor(2.2455, grad_fn=<DotBackward0>)
# tensor(2.2428, grad_fn=<DotBackward0>)
# tensor(2.2415, grad_fn=<DotBackward0>)
# tensor(2.2412, grad_fn=<DotBackward0>)
# tensor(2.2396, grad_fn=<DotBackward0>)
# tensor(2.2385, grad_fn=<DotBackward0>)
# tensor(2.2372, grad_fn=<DotBackward0>)
# tensor(2.2358, grad_fn=<DotBackward0>)
# tensor(2.2352, grad_fn=<DotBackward0>)
# tensor(2.2361, grad_fn=<DotBackward0>)
# tensor(2.2365, grad_fn=<DotBackward0>)
# tensor(2.2368, grad_fn=<DotBackward0>)
# tensor(2.2362, grad_fn=<DotBackward0>)
# tensor(2.2351, grad_fn=<DotBackward0>)
# tensor(2.2349, grad_fn=<DotBackward0>)
# tensor(2.2350, grad_fn=<DotBackward0>)
# tensor(2.2356, grad_fn=<DotBackward0>)
# tensor(2.2363, grad_fn=<DotBackward0>)
# tensor(2.2366, grad_fn=<DotBackward0>)
# tensor(2.2368, grad_fn=<DotBackward0>)
# tensor(2.2373, grad_fn=<DotBackward0>)
# tensor(2.2379, grad_fn=<DotBackward0>)
# tensor(2.2386, grad_fn=<DotBackward0>)
# tensor(2.2394, grad_fn=<DotBackward0>)
# tensor(2.2404, grad_fn=<DotBackward0>)
# tensor(2.2414, grad_fn=<DotBackward0>)
# tensor(2.2421, grad_fn=<DotBackward0>)
# tensor(2.2428, grad_fn=<DotBackward0>)
# tensor(2.2433, grad_fn=<DotBackward0>)
# tensor(2.2438, grad_fn=<DotBackward0>)
# tensor(2.2443, grad_fn=<DotBackward0>)
# tensor(2.2449, grad_fn=<DotBackward0>)
# tensor(2.2457, grad_fn=<DotBackward0>)
# tensor(2.2464, grad_fn=<DotBackward0>)
# tensor(2.2471, grad_fn=<DotBackward0>)
# tensor(2.2479, grad_fn=<DotBackward0>)
# tensor(2.2488, grad_fn=<DotBackward0>)
# tensor(2.2496, grad_fn=<DotBackward0>)
# tensor(2.2506, grad_fn=<DotBackward0>)
# tensor(2.2517, grad_fn=<DotBackward0>)
# tensor(2.2528, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2588, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2603, grad_fn=<DotBackward0>)
# tensor(2.2610, grad_fn=<DotBackward0>)
# tensor(2.2615, grad_fn=<DotBackward0>)
# tensor(2.2620, grad_fn=<DotBackward0>)
# tensor(2.2624, grad_fn=<DotBackward0>)
# tensor(2.2627, grad_fn=<DotBackward0>)
# tensor(2.2630, grad_fn=<DotBackward0>)
# tensor(2.2632, grad_fn=<DotBackward0>)
# tensor(2.2634, grad_fn=<DotBackward0>)
# tensor(2.2634, grad_fn=<DotBackward0>)
# tensor(2.2635, grad_fn=<DotBackward0>)
# tensor(2.2634, grad_fn=<DotBackward0>)
# tensor(2.2633, grad_fn=<DotBackward0>)
# tensor(2.2632, grad_fn=<DotBackward0>)
# tensor(2.2631, grad_fn=<DotBackward0>)
# tensor(2.2629, grad_fn=<DotBackward0>)
# tensor(2.2626, grad_fn=<DotBackward0>)
# tensor(2.2624, grad_fn=<DotBackward0>)
# tensor(2.2621, grad_fn=<DotBackward0>)
# tensor(2.2619, grad_fn=<DotBackward0>)
# tensor(2.2616, grad_fn=<DotBackward0>)
# tensor(2.2613, grad_fn=<DotBackward0>)
# tensor(2.2610, grad_fn=<DotBackward0>)
# tensor(2.2607, grad_fn=<DotBackward0>)
# tensor(2.2604, grad_fn=<DotBackward0>)
# tensor(2.2602, grad_fn=<DotBackward0>)
# tensor(2.2599, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2594, grad_fn=<DotBackward0>)
# tensor(2.2592, grad_fn=<DotBackward0>)
# tensor(2.2590, grad_fn=<DotBackward0>)
# tensor(2.2588, grad_fn=<DotBackward0>)
# tensor(2.2586, grad_fn=<DotBackward0>)
# tensor(2.2584, grad_fn=<DotBackward0>)
# tensor(2.2583, grad_fn=<DotBackward0>)
# tensor(2.2582, grad_fn=<DotBackward0>)
# tensor(2.2580, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2574, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2581, grad_fn=<DotBackward0>)
# tensor(2.2587, grad_fn=<DotBackward0>)
# tensor(2.2595, grad_fn=<DotBackward0>)
# tensor(2.2601, grad_fn=<DotBackward0>)
# tensor(2.2603, grad_fn=<DotBackward0>)
# tensor(2.2597, grad_fn=<DotBackward0>)
# tensor(2.2586, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2580, grad_fn=<DotBackward0>)
# tensor(2.2589, grad_fn=<DotBackward0>)
# tensor(2.2587, grad_fn=<DotBackward0>)
# tensor(2.2578, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2563, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2585, grad_fn=<DotBackward0>)
# tensor(2.2604, grad_fn=<DotBackward0>)
# tensor(2.2627, grad_fn=<DotBackward0>)
# tensor(2.2648, grad_fn=<DotBackward0>)
# tensor(2.2646, grad_fn=<DotBackward0>)
# tensor(2.2617, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2602, grad_fn=<DotBackward0>)
# tensor(2.2582, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2584, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2563, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2554, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2554, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2582, grad_fn=<DotBackward0>)
# tensor(2.2601, grad_fn=<DotBackward0>)
# tensor(2.2621, grad_fn=<DotBackward0>)
# tensor(2.2640, grad_fn=<DotBackward0>)
# tensor(2.2639, grad_fn=<DotBackward0>)
# tensor(2.2615, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2594, grad_fn=<DotBackward0>)
# tensor(2.2587, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2554, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2591, grad_fn=<DotBackward0>)
# tensor(2.2642, grad_fn=<DotBackward0>)
# tensor(2.2716, grad_fn=<DotBackward0>)
# tensor(2.2769, grad_fn=<DotBackward0>)
# tensor(2.2749, grad_fn=<DotBackward0>)
# tensor(2.2633, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2586, grad_fn=<DotBackward0>)
# tensor(2.2658, grad_fn=<DotBackward0>)
# tensor(2.2651, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2611, grad_fn=<DotBackward0>)
# tensor(2.2622, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2589, grad_fn=<DotBackward0>)
# tensor(2.2599, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2579, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2600, grad_fn=<DotBackward0>)
# tensor(2.2650, grad_fn=<DotBackward0>)
# tensor(2.2726, grad_fn=<DotBackward0>)
# tensor(2.2740, grad_fn=<DotBackward0>)
# tensor(2.2699, grad_fn=<DotBackward0>)
# tensor(2.2587, grad_fn=<DotBackward0>)
# tensor(2.2559, grad_fn=<DotBackward0>)
# tensor(2.2628, grad_fn=<DotBackward0>)
# tensor(2.2634, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2607, grad_fn=<DotBackward0>)
# tensor(2.2649, grad_fn=<DotBackward0>)
# tensor(2.2625, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2577, grad_fn=<DotBackward0>)
# tensor(2.2586, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2564, grad_fn=<DotBackward0>)
# tensor(2.2580, grad_fn=<DotBackward0>)
# tensor(2.2600, grad_fn=<DotBackward0>)
# tensor(2.2630, grad_fn=<DotBackward0>)
# tensor(2.2656, grad_fn=<DotBackward0>)
# tensor(2.2675, grad_fn=<DotBackward0>)
# tensor(2.2659, grad_fn=<DotBackward0>)
# tensor(2.2620, grad_fn=<DotBackward0>)
# tensor(2.2569, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2560, grad_fn=<DotBackward0>)
# tensor(2.2588, grad_fn=<DotBackward0>)
# tensor(2.2605, grad_fn=<DotBackward0>)
# tensor(2.2591, grad_fn=<DotBackward0>)
# tensor(2.2565, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2572, grad_fn=<DotBackward0>)
# tensor(2.2576, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2535, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# ...
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2561, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2589, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2614, grad_fn=<DotBackward0>)
# tensor(2.2604, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2583, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2551, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2567, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2573, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2556, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2546, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2555, grad_fn=<DotBackward0>)
# tensor(2.2557, grad_fn=<DotBackward0>)
# tensor(2.2570, grad_fn=<DotBackward0>)
# tensor(2.2575, grad_fn=<DotBackward0>)
# tensor(2.2593, grad_fn=<DotBackward0>)
# tensor(2.2596, grad_fn=<DotBackward0>)
# tensor(2.2612, grad_fn=<DotBackward0>)
# tensor(2.2603, grad_fn=<DotBackward0>)
# tensor(2.2603, grad_fn=<DotBackward0>)
# tensor(2.2580, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2558, grad_fn=<DotBackward0>)
# tensor(2.2568, grad_fn=<DotBackward0>)
# tensor(2.2563, grad_fn=<DotBackward0>)
# tensor(2.2562, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2543, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2549, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2548, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2547, grad_fn=<DotBackward0>)
# tensor(2.2544, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2542, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2536, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2537, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2539, grad_fn=<DotBackward0>)
# tensor(2.2538, grad_fn=<DotBackward0>)
# tensor(2.2541, grad_fn=<DotBackward0>)
# tensor(2.2540, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2545, grad_fn=<DotBackward0>)
# tensor(2.2552, grad_fn=<DotBackward0>)
# tensor(2.2554, grad_fn=<DotBackward0>)
# tensor(2.2566, grad_fn=<DotBackward0>)
# tensor(2.2571, grad_fn=<DotBackward0>)
# tensor(2.2589, grad_fn=<DotBackward0>)
# tensor(2.2595, grad_fn=<DotBackward0>)
# tensor(2.2628, grad_fn=<DotBackward0>)
# tensor(2.2635, grad_fn=<DotBackward0>)
# tensor(2.2644, grad_fn=<DotBackward0>)
# tensor(2.2610, grad_fn=<DotBackward0>)
# tensor(2.2583, grad_fn=<DotBackward0>)
# tensor(2.2553, grad_fn=<DotBackward0>)
# tensor(2.2550, grad_fn=<DotBackward0>)
# reduced chi^2 level 2 = 2.2550339698791504
# Constrained alpha: 1.0
# Constrained beta: 1.0
# Constrained gamma: 10.0
# counter = 5786

# %%
closure_fit = Postfit()
# neutrino_pdfs, N_event_pred = closure_fit.apply_postfit_criteria(chi_squares,N_event_pred,neutrino_pdfs)

# %%
x_vals = x_vals.detach().numpy().flatten()
faser_pdf_mu,x_faser = read_pdf(pdf,x_vals,14) 
faser_pdf_mub,x_faser = read_pdf(pdf,x_vals,-14)
# mean_fnu = np.mean(neutrino_pdfs,axis=0) *x_vals
mean_fnu_mu = np.mean(neutrino_pdfs_mu,axis=0) 
mean_fnu_mub = np.mean(neutrino_pdfs_mub,axis=0) 

mean_pdf_preproc = np.mean(preproc_pdfs,axis=0) 
mean_nn_pdf = np.mean(nn_pdfs,axis=0)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# from lhapdf_grid import write_lhapdf_grid
# mean_fnu = np.mean(neutrino_pdfs, axis=0) * x_vals
# lhapdfpath = '/opt/anaconda3/envs/nnpdf_dev/share/LHAPDF/enu/enu_0000.dat'

# write_lhapdf_grid(x_vals,mean_fnu,lhapdfpath)

# %%
print(mean_fnu_mub.shape)
print(mean_fnu_mu.shape)
# Out:
# ()
# (250,)

# %%
# plt.plot(cont_x,mean_pdf_preproc*mean_nn_pdf*(x_alpha_more_bins.detach().numpy().flatten()),label = 'mult' )
plt.plot(x_vals*2,mean_fnu_mu*x_vals,'o',label="fnu mu",markersize=1.5)
plt.plot(x_vals*2,mean_pdf_preproc*x_vals,label="fpreproc",markersize=1.5)
plt.plot(x_vals*2,mean_nn_pdf*x_vals,label="fnn",markersize=1.5)
# plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.plot(x_faser*2,faser_pdf_mu*x_faser,label ='faserv pdf')
plt.xlabel(r"$x_{\nu}$",fontsize = 14)
plt.ylabel(r"$f_{\nu_e}(x_{\nu})$",fontsize = 14)
plt.ylim(10**-1,10**6)
plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(cont_x,mean_pdf_preproc*mean_nn_pdf*(x_alpha_more_bins.detach().numpy().flatten()),label = 'mult' )
plt.plot(x_vals*2,mean_fnu_mub*x_vals,'o',label="fnu mub",markersize=1.5)
# plt.plot(x_vals,mean_pdf_preproc,label="fpreproc",markersize=1.5)
# plt.plot(x_vals,mean_nn_pdf,label="fnn",markersize=1.5)
# plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.plot(x_faser*2,faser_pdf_mub*x_vals,label ='faserv pdf')
plt.xlabel(r"$x_{\nu}$",fontsize = 14)
plt.ylabel(r"$f_{\nu_e}(x_{\nu})$",fontsize = 14)
# plt.ylim(10**-1,10**6)
# plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()

# %%
print(xvals_per_obs)
# Out:
# [-1000, -300, -100]

# %%
from plot_results import plot
sig_tot = np.sqrt(sig_sys+sig_stat)
plot(x_vals, neutrino_pdfs_mu, level0, N_event_pred, sig_tot, xvals_per_obs,14)
plot(x_vals, neutrino_pdfs_mu, level0, N_event_pred, sig_tot, xvals_per_obs,-14)
# Out:
# [ 66.8 205.5  66.   66. ]LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# [  4.2156343 226.1815     70.83616    70.83616  ]
#
# [ 66.8 205.5  66.   66. ]
# [  4.2156343 226.1815     70.83616    70.83616  ]
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: divide by zero encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: invalid value encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: invalid value encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: invalid value encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:188: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: divide by zero encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: invalid value encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: invalid value encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: invalid value encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:188: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Error in callback <function flush_figures at 0x12fdf60c0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/formatters.py:182, in DisplayFormatter.format(self, obj, include, exclude)
#     180 md = None
#     181 try:
# --> 182     data = formatter(obj)
#     183 except:
#     184     # FIXME: log the exception
#     185     raise
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/formatters.py:226, in catch_format_error(method, self, *args, **kwargs)
#     224 """show traceback on failed format call"""
#     225 try:
# --> 226     r = method(self, *args, **kwargs)
#     227 except NotImplementedError:
#     228     # don't warn on NotImplementedErrors
#     229     return self._check_return(None, args[0])
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/backend_bases.py:2178, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
# -> 2178         bbox_inches = self.figure.get_tightbbox(
#    2179             renderer, bbox_extra_artists=bbox_extra_artists)
#    2180         if (isinstance(layout_engine, ConstrainedLayoutEngine) and
#    2181                 pad_inches == "layout"):
#    2182             h_pad = layout_engine.get()["h_pad"]
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:457, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     451 if len(args) > name_idx:
#     452     warn_deprecated(
#     453         since, message="Passing the %(name)s %(obj_type)s "
#     454         "positionally is deprecated since Matplotlib %(since)s; the "
#     455         "parameter will become keyword-only %(removal)s.",
#     456         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 457 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/figure.py:1787, in FigureBase.get_tightbbox(self, renderer, bbox_extra_artists)
#    1783 if ax.get_visible():
#    1784     # some Axes don't take the bbox_extra_artists kwarg so we
#    1785     # need this conditional....
#    1786     try:
# -> 1787         bbox = ax.get_tightbbox(
#    1788             renderer, bbox_extra_artists=bbox_extra_artists)
#    1789     except TypeError:
#    1790         bbox = ax.get_tightbbox(renderer)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:457, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     451 if len(args) > name_idx:
#     452     warn_deprecated(
#     453         since, message="Passing the %(name)s %(obj_type)s "
#     454         "positionally is deprecated since Matplotlib %(since)s; the "
#     455         "parameter will become keyword-only %(removal)s.",
#     456         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 457 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/axes/_base.py:4499, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4496     bbox_artists = self.get_default_bbox_extra_artists()
#    4498 for a in bbox_artists:
# -> 4499     bbox = a.get_tightbbox(renderer)
#    4500     if (bbox is not None
#    4501             and 0 < bbox.width < np.inf
#    4502             and 0 < bbox.height < np.inf):
#    4503         bb.append(bbox)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/artist.py:365, in Artist.get_tightbbox(self, renderer)
#     349 def get_tightbbox(self, renderer=None):
#     350     """
#     351     Like `.Artist.get_window_extent`, but includes any clipping.
#     352
#    (...)
#     363         Returns None if clipping results in no intersection.
#     364     """
# --> 365     bbox = self.get_window_extent(renderer)
#     366     if self.get_clip_on():
#     367         clip_box = self.get_clip_box()
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/spines.py:154, in Spine.get_window_extent(self, renderer)
#     152 # make sure the location is updated so that transforms etc are correct:
#     153 self._adjust_location()
# --> 154 bb = super().get_window_extent(renderer=renderer)
#     155 if self.axis is None or not self.axis.get_visible():
#     156     return bb
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/patches.py:645, in Patch.get_window_extent(self, renderer)
#     644 def get_window_extent(self, renderer=None):
# --> 645     return self.get_path().get_extents(self.get_transform())
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/path.py:625, in Path.get_extents(self, transform, **kwargs)
#     623 from .transforms import Bbox
#     624 if transform is not None:
# --> 625     self = transform.transform_path(self)
#     626 if self.codes is None:
#     627     xys = self.vertices
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/transforms.py:1610, in Transform.transform_path(self, path)
#    1603 def transform_path(self, path):
#    1604     """
#    1605     Apply the transform to `.Path` *path*, returning a new `.Path`.
#    1606
#    1607     In some cases, this transform may insert curves into the path
#    1608     that began as line segments.
#    1609     """
# -> 1610     return self.transform_path_affine(self.transform_path_non_affine(path))
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/transforms.py:1620, in Transform.transform_path_affine(self, path)
#    1612 def transform_path_affine(self, path):
#    1613     """
#    1614     Apply the affine part of this transform to `.Path` *path*, returning a
#    1615     new `.Path`.
#    (...)
#    1618     ``transform_path_affine(transform_path_non_affine(values))``.
#    1619     """
# -> 1620     return self.get_affine().transform_path_affine(path)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/transforms.py:1812, in AffineBase.transform_path_affine(self, path)
#    1810 def transform_path_affine(self, path):
#    1811     # docstring inherited
# -> 1812     return Path(self.transform_affine(path.vertices),
#    1813                 path.codes, path._interpolation_steps)
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/path.py:152, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     150 self._codes = codes
#     151 self._interpolation_steps = _interpolation_steps
# --> 152 self._update_values()
#     154 if readonly:
#     155     self._vertices.flags.writeable = False
#
# File /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/matplotlib/path.py:202, in Path._update_values(self)
#     199     v = _to_unmasked_float_array(vertices)
#     200     return cls(np.concatenate([v, v[:1]]), closed=True)
# --> 202 def _update_values(self):
#     203     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     204     self._should_simplify = (
#     205         self._simplify_threshold > 0 and
#     206         mpl.rcParams['path.simplify'] and
#     207         len(self._vertices) >= 128 and
#     208         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     209     )
#
# KeyboardInterrupt:

# %%
mean_N_event_fits = np.mean(N_event_pred,axis=0)
sigma_N_event_fits = np.std(N_event_pred,axis=0)

mean_N_event_fit = mean_N_event_fits.flatten()
sigma_N_event_fit = sigma_N_event_fits.flatten()
xvals_per_obs = np.array(xvals_per_obs)
sorted_indices = np.argsort(xvals_per_obs)

# Sort both arrays using the same indices
sorted_xvals_per_obs = xvals_per_obs[sorted_indices]
sorted_mean_N_event_fit = mean_N_event_fit[sorted_indices]
sorted_sigma_N_event_fit = sigma_N_event_fit[sorted_indices]
level0data = level0[0]
sorted_level0 = level0data[sorted_indices]

plt.plot(sorted_xvals_per_obs,sorted_mean_N_event_fit,label="Level 0 closure test")

plt.fill_between(sorted_xvals_per_obs,(sorted_mean_N_event_fit+sorted_sigma_N_event_fit),(sorted_mean_N_event_fit-sorted_sigma_N_event_fit),label=r"1 $\sigma$ error",color = 'red')

# plt.plot(xvals_per_obs[i],events_per_obs[i],'go',markersize=1.5)
plt.plot(sorted_xvals_per_obs,sorted_level0,'bo',markersize=1.5)
# plt.errorbar(xvals_per_obs[i],events_per_obs[i],yerr=np.sqrt(sig_tot),label='POWHEG +PY8 NLO',color = 'green',alpha=0.6 )
# plt.fill_between(xvals_per_obs[i],events_per_obs[i]+np.sqrt(sig_tot), events_per_obs[i]-np.sqrt(sig_tot),color = 'green',alpha=0.6)
plt.xlabel(r"$E_{\nu}$[GeV]",fontsize = 14)
plt.ylabel(r"$N_{int}$",fontsize = 14)
plt.grid()
plt.legend()
# plt.savefig('N_int_fit.pdf')
plt.show()

# %%
# Quantitative validation of PDF uncertainties in closure tests
# theoretical prediction for # of events
pdf = "faserv"
lowx = -8
n=50
# x_vals = generate_grid(lowx,n)

faser_pdf,x_faser = read_pdf(pdf,x_vals)
postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
print(f'delta chi^2 = {delta_chi}')

phi_chi_squared = postfit_measures.compute_phi(data, chi_squares)
print(f'phi level 2 = {phi_chi_squared}')

dist,xnu  = postfit_measures.compute_distance(neutrino_pdfs,x_vals)
plt.plot(xnu,dist,'o')
plt.ylabel('distance to truth')
plt.xlabel('xnu')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 8
#       5 n=50
#       6 # x_vals = generate_grid(lowx,n)
# ----> 8 faser_pdf,x_faser = read_pdf(pdf,x_vals)
#       9 postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
#      10 delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
#
# TypeError: read_pdf() missing 1 required positional argument: 'particle'

# %%
def compute_accuracy():
    log_spaced = np.logspace(np.log10(1e-5), np.log10(0.1), 10)
    linear_spaced = np.linspace(0.1, 1, 10)
    x_xi_measure = np.concatenate((log_spaced, linear_spaced))
    x_xi_measure= torch.tensor(x_xi_measure, dtype=torch.float32).view(-1,1)

    pdf = "faserv"

    faser_pdf,x_faser = read_pdf(pdf,x_xi_measure)
    faser_pdf =faser_pdf.detach().numpy().squeeze()

    arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level1,REPLICAS=  1)
    mean_neutrino_pdf =model(x_xi_measure).detach().numpy().squeeze()
    
    return mean_neutrino_pdf,faser_pdf,n

# mean_neutrino_pdf,faser_pdf,n = compute_accuracy()
# xi = np.sum(abs(mean_neutrino_pdf-faser_pdf) < error_neutrino_fit)/ n
# print(f'xi = {xi}')

# %%
def compute_bias_to_variance(num_level1_shifts,level0,level1,level2):
    biases = []
    variances = []
    level1 = np.array(level1)
    level0 = np.array(level0)
    diff_level01 = level1 - level0
    level2 -= diff_level01
    level0 = torch.tensor(level0, dtype=torch.float32)
    for i in range(num_level1_shifts):
        
        # generate level2 data with different level 1 shifts
        r_sys = np.random.normal(0, 1) * sig_sys / 10
        r_stat = np.random.normal(0, 1) * np.sqrt(data) / 10
        level2 += r_sys + r_stat
        level2 = torch.tensor(level2, dtype=torch.float32)
        
        arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level2,REPLICAS = 3)
        mean_N_events = np.mean(N_event_pred,axis=0)
        mean_N_events = torch.tensor(mean_N_events, dtype=torch.float32)
        
        mean_chi_square = raw_loss_fct(level0[0],mean_N_events,cov_matrix)
        biases.append(mean_chi_square)

        chi_square_level2 = 0
        for j in range (REPLICAS):
            chi_square_level2 += raw_loss_fct(level2[j],mean_N_events, cov_matrix)
        variances.append(chi_square_level2/REPLICAS)


    exp_bias = np.mean(biases)
    exp_variance = np.mean(variances)
    ratio = exp_bias/exp_variance
    return ratio
    
# ratio = compute_bias_to_variance(1,level0,level1,level2)
# print(f'ratio = {ratio}')


#BIAS:
    # mc reps = level 1 + level 2
    # average over level 1: keep level 2 the same, but add different level 1 shifts
    # compute reduced chi square with respect to level 0 data
    # VARIANCE:
    # mc reps = level 1 + level 2
    # average chi^2 over several level 2 shifts
    # do not average over level 1 shifts since it is expected to be constant
    # Compute reduced chi square with respect to all level 2 replics: so do not have to run a lot more fits it seems
    # however since these multiple level 1 fits have to be run anyway, it is no problemo
