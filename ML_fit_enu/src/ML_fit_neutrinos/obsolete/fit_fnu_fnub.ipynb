# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
# from read_fk_table import get_fk_table
from read_faserv_pdf import read_pdf
# from read_LHEF import read_LHEF_data
from data_errors import compute_errors
from MC_data_reps import generate_MC_replicas
from postfit_criteria import Postfit
from form_loss_fct import complete_loss_fct, raw_loss_fct
from postfit_measures import Measures
from logspace_grid import generate_grid
# from rebin_fk_data import rebin_fk

# %%
# Define global variables
num_obs = 1 #between 1 and 4
REPLICAS  = 10

#HYPERPARAMETERS
preproc = 1
l1 = 2
l2 = 2
l3 = 2
fit_level = 2

lr = 0.1
max_counter = 50
max_Nepochs = 3500

# %%
def read_LHEF_data(filenames):
    """Read histograms of data

    Args:
        num_obs (int): number of files to read data from

    Returns:
        tuple: returns tuple of lists and arrays containing the data
    """

    
    (binwidths, events, xvals_per_obs, max_events, min_events, xlabels) = (
        [],
        [],
        [],
        [],
        [],
        [],
    )
    if filenames == "data_Enu_mu":
        val_n = np.loadtxt(f"data/{filenames}_n.dat", unpack=True)
        val_p = np.loadtxt(f"data/{filenames}_p.dat", unpack=True)
        diff = 100
        
        
        
        val = 74 / 183 * val_p + (183 - 74) / 183 * val_n
        val *= diff 
    else:
        val = np.loadtxt(f"data/{filenames}.dat", unpack=True)
        diff = 100
        
    
    err = val/20
    events = val
    xvals_per_obs = np.arange(0,6000,100)
    min_events = val - err
    max_events = (val + err)
    binwidths = diff 

    xlabels.append(filenames[0].replace(".dat", ""))

    events_per_obs = events

    return (
        events,
        max_events,
        min_events,
        xvals_per_obs,
        binwidths,
        xlabels,
        events_per_obs,
    )

filename_mu = "data_Enu_mu"
events_mu, max_events_mu, min_events_mu,xvals_per_obs_mu,binwidths,xlabels,events_per_obs_mu = read_LHEF_data(filename_mu)
filename_mub = "data_Enu_mub"
events_mub, max_events_mub, min_events_mub,xvals_per_obs_mub,binwidths,xlabels,events_per_obs_mub = read_LHEF_data(filename_mub)

event_total = events_mu+events_mub
event_total_max = max_events_mu+max_events_mub
event_total_min = min_events_mu+min_events_mub

# %%
# from read_fk_table import get_fk_table

import pandas as pd
# import torch
import torch.nn.functional


def get_fk_table(filename):
    """This function reads the fk table for the neutrino flux and pads them for computational efficiency later on

    Returns:
        tuple: x_alphas(grid points) and the fk table in tensor to fit torch
    """

    file_path_n = f"data/{filename}_n.dat"
    df_n = pd.read_csv(file_path_n, sep="\s+", header=None)
    fk_table_n = df_n.to_numpy()

    file_path_p = f"data/{filename}_p.dat"
    df_p = pd.read_csv(file_path_p, sep="\s+", header=None)
    fk_table_p = df_p.to_numpy()

    x_alpha = fk_table_p[0, :]
    x_alpha = x_alpha.reshape(len(x_alpha), 1)

    fk_table = (74 / 183 )* fk_table_p + ((183 - 74) / 183) * fk_table_n

    # strip first row to get fk table
    fk_table = fk_table[1:, :]

    x_alpha = torch.tensor(x_alpha, dtype=torch.float32).view(-1, 1)
    fk_table = torch.tensor(fk_table, dtype=torch.float32)

    return x_alpha, fk_table

filename = "FK_Enu_mu"
x_alphas, fk_tables_mu = get_fk_table(filename = filename)
filename = "FK_Enu_mub"
x_alphas, fk_tables_mub = get_fk_table(filename = filename)
fk_tables_tot = fk_tables_mu + fk_tables_mub
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:16: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_23029/2835427693.py:16: SyntaxWarning: invalid escape sequence '\s'
#   df_n = pd.read_csv(file_path_n, sep="\s+", header=None)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_23029/2835427693.py:20: SyntaxWarning: invalid escape sequence '\s'
#   df_p = pd.read_csv(file_path_p, sep="\s+", header=None)

# %%
# events = [50, 97, 71, 69, 48, 27]
# minev = [5.9, 4.3, 2.5, 2.2, 3.7,5.1]
# events = [44.1, 92.7, 68.5, 66.8, 44.3, 21.9]
# events = [33.6, 59.5, 51.6, 84.1, 50.1, 19.6]
# std_errev = [3.1,2.5,1.7,1.6,2.3,2.9]
# events, max_events, min_events, xvals_per_obs, binwidths, xlabels, events_per_obs, = read_LHEF_data()

# sig_sys = std_errev
# sig_stat = np.sqrt(events)
# binwidths = 100 * 65.6/150 
# xlabels = ['mu']
# data = events
def rebin_fk(faser_bins,fk_tables,data,data_max,data_min):

    # xvals_per_obs = high[:-1]
    xvals_per_obs = np.arange(0, 6100, 100)
    print(xvals_per_obs)
    # xvals_per_obs = np.array(xvals_per_obs)
    data = np.array(data)
    data_faser,data_faser_min,data_faser_max, = [],[],[]
    fk_tables_faser = []
    lower_bound = 100
    # faser_bins = [300, 600, 1000,1900]
    for bin_val in faser_bins:
        indices = np.where((xvals_per_obs < bin_val) & (xvals_per_obs >= lower_bound))[0]

        print(indices)

        # max_range = max(indices) + min_range + 1

        data_faser.append(np.sum(data[min(indices):max(indices) +1]))
        data_faser_min.append(np.sum(data_min[min(indices):max(indices) +1]))
        data_faser_max.append(np.sum(data_max[min(indices):max(indices) +1]))

        # xvals_per_obs = xvals_per_obs[max(indices)  :]
  
        summed_column = torch.sum(fk_tables[min(indices):max(indices) +1, :], axis=0)
        summed_column = summed_column.unsqueeze(0)
        print(summed_column.shape)
        fk_tables_faser.append(summed_column)

        # min_range = max_range
        lower_bound = bin_val

    # xvals_per_obs_faser.append(xvals_per_obs[-1])    
    # summed_column = torch.sum(fk_tables[max_range:, :], axis=0)
    # summed_column = summed_column.unsqueeze(0)
    # data_faser.append(np.sum(data[max_range:]))
    # data_faser_min.append(np.sum(data_min[max_range:]))
    # data_faser_max.append(np.sum(data_max[max_range:]))
    # fk_tables_faser.append(summed_column)


    fk_tables_faser = torch.cat(fk_tables_faser, dim=0)

    
    data_faser = np.array(data_faser)
    data_faser_min = np.array(data_faser_min)
    data_faser_max = np.array(data_faser_max)


    return fk_tables_faser, data_faser,data_faser_max,data_faser_min


# data, data_min, data_max, xvals_per_obs, binwidths, xlabels, events_per_obs = rebin_fk()
faser_bins = [300, 600, 1000,1900]

fk_tables, data,data_max,data_min = rebin_fk(faser_bins,fk_tables_tot, event_total,event_total_max,event_total_min)
xvals_per_obs = [100,300,600,1000]
# xvals_per_obs = [100,300,600,1000,-300,-100]
xvals_per_obs_mub = [-100,-300,-1000]
# Out:
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700
#  2800 2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100
#  4200 4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500
#  5600 5700 5800 5900 6000]
# [1 2]
# torch.Size([1, 50])
# [3 4 5]
# torch.Size([1, 50])
# [6 7 8 9]
# torch.Size([1, 50])
# [10 11 12 13 14 15 16 17 18]
# torch.Size([1, 50])

# %%
# def combine_mu_mub(mu,mub):
#     mu[-1] = mu[-1] + mub[-1]
#     mub = mub[:-1]
#     mub = mub[::-1]         
#     combined = np.hstack((mu, mub))
#     return combined


sig_sys,sig_tot, cov_matrix = compute_errors(data,data_min,data_max)  
#Combine data and errors
sig_stat = np.sqrt(data)

sig_tot = sig_stat**2 + sig_sys**2
# cov_matrix = np.diag(sig_tot)
# cov_matrix = np.linalg.inv(cov_matrix)
# cov_matrix = torch.tensor(cov_matrix, dtype=torch.float32, requires_grad=False)
#1. sig stat
#2. sig sys
#3. events
#4. xvals_per_obs

# %%
pdf = "faserv"
faser_pdf,x_faser = read_pdf(pdf,x_alphas.flatten(),14)
faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
conv = torch.matmul(fk_tables,faser_pdf) * binwidths 
plt.plot(xvals_per_obs,conv,label='conv')
# print(conv.detach().numpy().flatten()/data[:-2])
faser_pdf,x_faser = read_pdf(pdf,x_alphas.flatten(),-14)
faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
conv = torch.matmul(fk_tables,faser_pdf) * binwidths 
plt.plot(xvals_per_obs,conv,label='conv2')

plt.plot(xvals_per_obs,data,'o',label='data')
plt.legend()
print(conv.detach().numpy().flatten())
print(data[:-2])
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# [ 32.048805 293.2465   446.9101   550.6181  ]
# [ 39.31713536 349.96053618]
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_23029/218713170.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_23029/218713170.py:8: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)

# %%
# data,data_min,data_max,xvals_per_obs,binwidths,xlabels,events_per_obs,fk_tables,x_alphas = rebin_fk(rebin=1)

# %%
#Get errors
# sig_sys,sig_tot, cov_matrix = compute_errors(data,data_min,data_max)  
# xvals_per_obs = [100,300,600,-100,-300,1000] 
# xvals_per_obs = [100,300,600,100,-300,-100]  
# cov_matrix = np.array([
#     [9.2,-0.32,  0.08, -0.03,  0.00,  0.00],
#     [-0.32, 10.2, -0.43,  0.10, -0.01, -0.00],
#     [ 0.08, -0.43, 9.6, -0.31,  0.04, -0.02],
#     [-0.03,  0.10, -0.31, 22.3,-0.14,  0.01],
#     [ 0.00, -0.01,  0.04, -0.14, 12.1,-0.24],
#     [ 0.00, -0.00, -0.02,  0.01, -0.24,7.5]
# ])
# cov_matrix = np.array([
#     [5186, -1623,  340,  -69,    2,    5],
#     [-1623, 6239, -1952,  281,  -19,   -4],
#     [  340, -1952, 4165, -734,   56,  -27],
#     [  -69,   281, -734, 1738, -130,   15],
#     [    2,   -19,   56, -130,  622, -147],
#     [    5,    -4,  -27,   15, -147,  847]
# ])
# sig_sys = np.array(sig_sys)
# # np.fill_diagonal(cov_matrix, sig_stat**2 + sig_sys**2)
# cov_matrix = np.linalg.inv(cov_matrix)
# cov_matrix = torch.tensor(cov_matrix, dtype=torch.float32, requires_grad=False)
#Generate MC replicas of data
level0,level1,level2 = generate_MC_replicas(REPLICAS,data,sig_sys,sig_stat)
# Get faserv pdf
pdf = "faserv"
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
faser_pdf,x_faser = read_pdf(pdf,x_vals,14)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
if fit_level ==0:
    pred = level0
if fit_level ==1:
    pred = level1
if fit_level ==2:
    pred = level2

# %%
print(data)
print(level1)
print(level2)
plt.plot(xvals_per_obs,data)
plt.xlabel(xlabels)
plt.ylabel('N')
plt.title("raw data")
plt.show()

for i in range(REPLICAS):
    plt.plot(
        xvals_per_obs, level2[i], 'o',label="level2"
    )
    plt.plot(
        xvals_per_obs, level1[i], 'o',label="level1"
    )
    plt.plot(xvals_per_obs, data,'o',label="level0")
    plt.xlabel(xlabels)
    plt.legend()
    plt.ylabel("N")
    plt.title("level 2 data")
    plt.show()
# Out:
# [ 39.31713536 349.96053618 545.62130453 721.87346212]
# [tensor([ 38.4236, 354.6994, 604.2358, 753.8539]), tensor([ 31.1328, 411.7092, 555.5742, 775.8582]), tensor([ 31.9809, 348.4439, 537.6627, 751.3328]), tensor([ 43.3167, 304.4915, 580.1096, 716.2706]), tensor([ 36.3817, 409.0580, 532.6572, 751.9227]), tensor([ 31.7190, 355.1787, 543.7598, 666.6155]), tensor([ 47.2763, 372.0740, 565.4579, 644.1793]), tensor([ 41.7461, 345.1740, 521.7735, 756.1074]), tensor([ 40.2981, 337.0337, 536.1727, 593.6907]), tensor([ 36.8782, 353.9170, 571.2112, 725.4683])]
# [tensor([ 51.7238, 370.1150, 554.5992, 732.9614]), tensor([ 17.0204, 477.3373, 528.7380, 853.2217]), tensor([ 24.8994, 321.2995, 508.1092, 744.2378]), tensor([ 45.9072, 288.0415, 639.4869, 720.8917]), tensor([ 35.0052, 381.2643, 611.9670, 682.3149]), tensor([ 36.0039, 340.4953, 540.1462, 640.1212]), tensor([ 56.9779, 395.5298, 579.8290, 614.2021]), tensor([ 61.6066, 295.8373, 482.3128, 865.9750]), tensor([ 31.2106, 340.2073, 523.4770, 565.7917]), tensor([ 32.2270, 333.3578, 579.1172, 757.3921])]

# %%
class SimplePerceptron(torch.nn.Module):
    def __init__(self, l1,l2,l3):
        super(SimplePerceptron, self).__init__()
        self.linear = torch.nn.Linear(1,l1)
        self.hidden = torch.nn.Linear(l1,l2)
        self.hidden2 = torch.nn.Linear(l2,l3)
        self.hidden3 = torch.nn.Linear(l3,1)
        self.relu = torch.nn.ReLU()

    def forward(self, y):
        y = self.linear(y)
        y = self.relu(y)
        y = self.hidden(y)
        y = self.relu(y)
        y = self.hidden2(y)
        y = self.relu(y)
        y = self.hidden3(y)
        y = self.relu(y)
        # y = torch.nn.functional.softplus(y)
    
        return y

# %%
import torch.nn as nn

if preproc == 1:
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha,beta,gamma):
            super(CustomPreprocessing, self).__init__()

            # self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
            # self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32, requires_grad=True))
            # self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32, requires_grad=True))

            self.register_buffer("alpha", torch.tensor(alpha, dtype=torch.float32))
            self.register_buffer("beta", torch.tensor(beta, dtype=torch.float32))
            self.register_buffer("gamma", torch.tensor(gamma, dtype=torch.float32))

        def forward(self, x):
            # alpha = (1 - 0.2)/2 *torch.tanh(self.alpha) + (1 + 0.2)/2
            # beta = (1.9 - 0.1)/2 *torch.tanh(self.alpha) + (1.9 + 0.1)/2
            # beta = torch.nn.functional.softmax(self.beta)
            # alpha = 1 - torch.nn.functional.softplus(self.alpha)
            return self.gamma * (1 - x) ** self.beta * x**(1-self.alpha) 
            # return 10 * (1 - x)**2 * x**(1.5) 
            # return  self.gamma*(1 - x) ** self.beta * x**(1-self.alpha) 
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha, beta, gamma,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha, beta,gamma)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            f_preproc = self.preprocessing(x)
            f_NN = self.mlp(x)
            f_nu = f_preproc * f_NN
            return f_NN
        
        def neuralnet(self, x):
            f_NN = self.mlp(x)
            return f_NN
        
        def preproc(self, x):
            f_preproc = self.preprocessing(x)
            return f_preproc

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss,self).__init__()

    def forward(self,pred,
    data,
    cov_matrix):
        loss = raw_loss_fct(pred,
    data,
    cov_matrix)
        return loss

# %%
#Define variables for fit
# x_alpha_more_bins = np.logspace(-5,0,250)
# x_alpha_more_bins = torch.tensor(x_alpha_more_bins, dtype=torch.float32).view(-1,1)
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
x_vals = torch.tensor(x_vals, dtype=torch.float32).view(-1,1)
neutrino_pdfs_mu,neutrino_pdfs_mub,N_event_pred, arc_lenghts, chi_squares, int_penaltys,pos_penaltys, preproc_pdfs, nn_pdfs  = [],[],[],[],[],[],[],[],[]

# %%
def perform_fit(pred,REPLICAS):
    for i in range(REPLICAS):
        if preproc == 1:
            alpha,beta,gamma = 1,1,10
            model = PreprocessedMLP(alpha, beta, gamma,l1, l2, l3)
                
                    # model.load_state_dict(model_params)    

            criterion = CustomLoss()
                # criterion = torch.nn.MSELoss()
            optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=0.01)
        losses = []
        pred[i] = pred[i].squeeze()
        model.train()
        best_loss = 1e13 # initial loss
        counter = 0
        num_epochs = 4000
        # num_epochs = 0
        for ep in range(num_epochs):
        # while counter < max_counter:  
        #     if num_epochs>max_Nepochs:
        #         break
            
            # num_epochs+=1
            optimizer.zero_grad()
            y_pred =  model(x_alphas) 
            # y_pred =  model(x_alphas) * x_alphas
            y_pred = torch.matmul(fk_tables,y_pred)  * binwidths 

            y_pred = y_pred.squeeze()
            # print(y_pred.shape)
            # print(pred[i].shape)
            # print(cov_matrix.shape)
            loss = (criterion(y_pred, pred[i],cov_matrix))
            loss.backward()
            print(loss)
    
            losses.append(loss.detach().numpy())
            optimizer.step()
            
            # if ep % 100 == 0:
            #     print(loss.detach().numpy())   
            # if abs(loss) <.00002:
            #     break
            # if loss < best_loss:
            #     best_loss = loss
            #     counter = 0
            # else:
            #     counter +=1   

        if loss < 100:    

            print(f"reduced chi^2 level 2 = {loss}")
            # print(f"reduced chi^2 level 1 = {red_chi_square_level1}")
            print(f"Constrained alpha: {(model.preprocessing.alpha.item())}")
            print(f"Constrained beta: {(model.preprocessing.beta.item())}")
            print(f"Constrained gamma: {model.preprocessing.gamma.item()}") 

            # save outcome of fit and its measures for postfit selection criteria
            chi_squares.append(loss.detach().numpy())
            # preproc_pdf = ((1 - x_alpha_more_bins) ** (beta) * x_alpha_more_bins ** (1-alpha)).detach().numpy().flatten()
            f_nu_mu = model(x_vals).detach().numpy().flatten() 
            
            # print(preproc_pdf.shape)

            preproc_pdfs.append(model.preproc(x_vals).detach().numpy().flatten())
            nn_pdfs.append(model.neuralnet(x_vals)[:,0].detach().numpy().flatten())

            N_event_pred.append(y_pred.detach().numpy())
            plt.plot(xvals_per_obs,y_pred.detach().numpy().flatten(),label = 'nn')
            plt.plot(xvals_per_obs,pred[i],label = 'level2')
            plt.legend()
            plt.show()
            # cont_pred = model(x_alpha_more_bins).detach().numpy().flatten()
            neutrino_pdfs_mu.append(f_nu_mu)

            plt.yscale('log')
            print(f'counter = {counter}')
            plt.plot(range(1, len(losses) + 1), losses)
            plt.xlabel('#epochs')
            plt.ylabel('loss')
            plt.title('level 0 closure test, no preprocessing')
            plt.show()
            # plt.plot(x_alpha_more_bins,preproc_pdf)
            # plt.xscale('log')
            # plt.yscale('log')
            # plt.show()
    # return arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model
    return chi_squares,N_event_pred, neutrino_pdfs_mu,neutrino_pdfs_mub,model

# %%
chi_squares,N_event_pred, neutrino_pdfs_mu,neutrino_pdfs_mub,model = perform_fit(pred,REPLICAS)
# Out:
# tensor(774.5352, grad_fn=<DotBackward0>)
# tensor(774.5352, grad_fn=<DotBackward0>)
# tensor(774.5097, grad_fn=<DotBackward0>)
# tensor(774.4589, grad_fn=<DotBackward0>)
# tensor(774.3981, grad_fn=<DotBackward0>)
# tensor(774.3288, grad_fn=<DotBackward0>)
# tensor(774.2574, grad_fn=<DotBackward0>)
# tensor(774.1836, grad_fn=<DotBackward0>)
# tensor(774.1055, grad_fn=<DotBackward0>)
# tensor(774.0160, grad_fn=<DotBackward0>)
# tensor(773.9155, grad_fn=<DotBackward0>)
# tensor(773.8045, grad_fn=<DotBackward0>)
# tensor(773.6824, grad_fn=<DotBackward0>)
# tensor(773.5455, grad_fn=<DotBackward0>)
# tensor(773.3925, grad_fn=<DotBackward0>)
# tensor(773.2220, grad_fn=<DotBackward0>)
# tensor(773.0330, grad_fn=<DotBackward0>)
# tensor(772.8240, grad_fn=<DotBackward0>)
# tensor(772.5941, grad_fn=<DotBackward0>)
# tensor(772.3422, grad_fn=<DotBackward0>)
# tensor(772.0673, grad_fn=<DotBackward0>)
# tensor(771.7684, grad_fn=<DotBackward0>)
# tensor(771.4446, grad_fn=<DotBackward0>)
# tensor(771.0951, grad_fn=<DotBackward0>)
# tensor(770.7180, grad_fn=<DotBackward0>)
# tensor(770.3038, grad_fn=<DotBackward0>)
# tensor(769.8451, grad_fn=<DotBackward0>)
# tensor(769.3282, grad_fn=<DotBackward0>)
# tensor(768.7344, grad_fn=<DotBackward0>)
# tensor(768.0411, grad_fn=<DotBackward0>)
# tensor(767.2196, grad_fn=<DotBackward0>)
# tensor(766.2343, grad_fn=<DotBackward0>)
# tensor(765.0419, grad_fn=<DotBackward0>)
# tensor(763.5899, grad_fn=<DotBackward0>)
# tensor(761.8168, grad_fn=<DotBackward0>)
# tensor(759.6502, grad_fn=<DotBackward0>)
# tensor(757.0072, grad_fn=<DotBackward0>)
# tensor(753.7930, grad_fn=<DotBackward0>)
# tensor(749.8934, grad_fn=<DotBackward0>)
# tensor(745.1510, grad_fn=<DotBackward0>)
# tensor(739.3939, grad_fn=<DotBackward0>)
# tensor(732.4247, grad_fn=<DotBackward0>)
# tensor(724.0261, grad_fn=<DotBackward0>)
# tensor(713.9646, grad_fn=<DotBackward0>)
# tensor(701.9958, grad_fn=<DotBackward0>)
# tensor(687.8732, grad_fn=<DotBackward0>)
# tensor(671.3596, grad_fn=<DotBackward0>)
# tensor(652.2448, grad_fn=<DotBackward0>)
# tensor(630.3720, grad_fn=<DotBackward0>)
# tensor(605.6477, grad_fn=<DotBackward0>)
# tensor(578.1251, grad_fn=<DotBackward0>)
# tensor(548.0139, grad_fn=<DotBackward0>)
# tensor(515.7690, grad_fn=<DotBackward0>)
# tensor(482.1721, grad_fn=<DotBackward0>)
# tensor(448.4342, grad_fn=<DotBackward0>)
# tensor(416.3105, grad_fn=<DotBackward0>)
# tensor(388.2021, grad_fn=<DotBackward0>)
# tensor(367.1582, grad_fn=<DotBackward0>)
# tensor(356.5398, grad_fn=<DotBackward0>)
# tensor(358.7897, grad_fn=<DotBackward0>)
# tensor(372.7167, grad_fn=<DotBackward0>)
# tensor(391.0740, grad_fn=<DotBackward0>)
# tensor(404.0071, grad_fn=<DotBackward0>)
# tensor(406.4231, grad_fn=<DotBackward0>)
# tensor(399.5580, grad_fn=<DotBackward0>)
# tensor(387.6645, grad_fn=<DotBackward0>)
# tensor(375.0539, grad_fn=<DotBackward0>)
# tensor(364.7316, grad_fn=<DotBackward0>)
# tensor(358.1063, grad_fn=<DotBackward0>)
# tensor(355.2590, grad_fn=<DotBackward0>)
# tensor(355.4348, grad_fn=<DotBackward0>)
# tensor(357.5317, grad_fn=<DotBackward0>)
# tensor(360.4621, grad_fn=<DotBackward0>)
# tensor(363.3514, grad_fn=<DotBackward0>)
# tensor(365.6044, grad_fn=<DotBackward0>)
# tensor(366.8939, grad_fn=<DotBackward0>)
# tensor(367.1149, grad_fn=<DotBackward0>)
# tensor(366.3357, grad_fn=<DotBackward0>)
# tensor(364.7345, grad_fn=<DotBackward0>)
# tensor(362.5886, grad_fn=<DotBackward0>)
# tensor(360.2056, grad_fn=<DotBackward0>)
# tensor(357.9025, grad_fn=<DotBackward0>)
# tensor(355.9620, grad_fn=<DotBackward0>)
# tensor(354.5943, grad_fn=<DotBackward0>)
# tensor(353.9016, grad_fn=<DotBackward0>)
# tensor(353.8583, grad_fn=<DotBackward0>)
# tensor(354.3143, grad_fn=<DotBackward0>)
# tensor(355.0294, grad_fn=<DotBackward0>)
# tensor(355.7338, grad_fn=<DotBackward0>)
# tensor(356.1981, grad_fn=<DotBackward0>)
# tensor(356.2894, grad_fn=<DotBackward0>)
# tensor(355.9930, grad_fn=<DotBackward0>)
# tensor(355.3974, grad_fn=<DotBackward0>)
# tensor(354.6512, grad_fn=<DotBackward0>)
# tensor(353.9122, grad_fn=<DotBackward0>)
# tensor(353.3052, grad_fn=<DotBackward0>)
# tensor(352.8994, grad_fn=<DotBackward0>)
# tensor(352.7050, grad_fn=<DotBackward0>)
# tensor(352.6853, grad_fn=<DotBackward0>)
# tensor(352.7754, grad_fn=<DotBackward0>)
# tensor(352.9027, grad_fn=<DotBackward0>)
# tensor(353.0033, grad_fn=<DotBackward0>)
# tensor(353.0323, grad_fn=<DotBackward0>)
# tensor(352.9689, grad_fn=<DotBackward0>)
# tensor(352.8150, grad_fn=<DotBackward0>)
# tensor(352.5909, grad_fn=<DotBackward0>)
# tensor(352.3282, grad_fn=<DotBackward0>)
# tensor(352.0619, grad_fn=<DotBackward0>)
# tensor(351.8227, grad_fn=<DotBackward0>)
# tensor(351.6313, grad_fn=<DotBackward0>)
# tensor(351.4955, grad_fn=<DotBackward0>)
# tensor(351.4093, grad_fn=<DotBackward0>)
# tensor(351.3574, grad_fn=<DotBackward0>)
# tensor(351.3187, grad_fn=<DotBackward0>)
# tensor(351.2729, grad_fn=<DotBackward0>)
# tensor(351.2050, grad_fn=<DotBackward0>)
# tensor(351.1082, grad_fn=<DotBackward0>)
# tensor(350.9845, grad_fn=<DotBackward0>)
# tensor(350.8423, grad_fn=<DotBackward0>)
# tensor(350.6932, grad_fn=<DotBackward0>)
# tensor(350.5487, grad_fn=<DotBackward0>)
# tensor(350.4167, grad_fn=<DotBackward0>)
# tensor(350.3011, grad_fn=<DotBackward0>)
# tensor(350.2007, grad_fn=<DotBackward0>)
# tensor(350.1108, grad_fn=<DotBackward0>)
# tensor(350.0253, grad_fn=<DotBackward0>)
# tensor(349.9378, grad_fn=<DotBackward0>)
# tensor(349.8436, grad_fn=<DotBackward0>)
# tensor(349.7402, grad_fn=<DotBackward0>)
# tensor(349.6279, grad_fn=<DotBackward0>)
# tensor(349.5087, grad_fn=<DotBackward0>)
# tensor(349.3858, grad_fn=<DotBackward0>)
# tensor(349.2628, grad_fn=<DotBackward0>)
# tensor(349.1423, grad_fn=<DotBackward0>)
# tensor(349.0259, grad_fn=<DotBackward0>)
# tensor(348.9137, grad_fn=<DotBackward0>)
# tensor(348.8045, grad_fn=<DotBackward0>)
# tensor(348.6966, grad_fn=<DotBackward0>)
# tensor(348.5880, grad_fn=<DotBackward0>)
# tensor(348.4771, grad_fn=<DotBackward0>)
# tensor(348.3630, grad_fn=<DotBackward0>)
# tensor(348.2458, grad_fn=<DotBackward0>)
# tensor(348.1262, grad_fn=<DotBackward0>)
# tensor(348.0052, grad_fn=<DotBackward0>)
# tensor(347.8839, grad_fn=<DotBackward0>)
# tensor(347.7629, grad_fn=<DotBackward0>)
# tensor(347.6425, grad_fn=<DotBackward0>)
# tensor(347.5227, grad_fn=<DotBackward0>)
# tensor(347.4028, grad_fn=<DotBackward0>)
# tensor(347.2822, grad_fn=<DotBackward0>)
# tensor(347.1603, grad_fn=<DotBackward0>)
# tensor(347.0365, grad_fn=<DotBackward0>)
# tensor(346.9108, grad_fn=<DotBackward0>)
# tensor(346.7831, grad_fn=<DotBackward0>)
# tensor(346.6539, grad_fn=<DotBackward0>)
# tensor(346.5234, grad_fn=<DotBackward0>)
# tensor(346.3920, grad_fn=<DotBackward0>)
# tensor(346.2599, grad_fn=<DotBackward0>)
# tensor(346.1270, grad_fn=<DotBackward0>)
# tensor(345.9933, grad_fn=<DotBackward0>)
# tensor(345.8587, grad_fn=<DotBackward0>)
# tensor(345.7228, grad_fn=<DotBackward0>)
# tensor(345.5855, grad_fn=<DotBackward0>)
# tensor(345.4467, grad_fn=<DotBackward0>)
# tensor(345.3063, grad_fn=<DotBackward0>)
# tensor(345.1643, grad_fn=<DotBackward0>)
# tensor(345.0209, grad_fn=<DotBackward0>)
# tensor(344.8760, grad_fn=<DotBackward0>)
# tensor(344.7296, grad_fn=<DotBackward0>)
# tensor(344.5814, grad_fn=<DotBackward0>)
# tensor(344.4308, grad_fn=<DotBackward0>)
# tensor(344.2770, grad_fn=<DotBackward0>)
# tensor(344.1179, grad_fn=<DotBackward0>)
# tensor(343.9511, grad_fn=<DotBackward0>)
# tensor(343.7744, grad_fn=<DotBackward0>)
# tensor(343.5883, grad_fn=<DotBackward0>)
# tensor(343.3936, grad_fn=<DotBackward0>)
# tensor(343.1800, grad_fn=<DotBackward0>)
# tensor(342.9282, grad_fn=<DotBackward0>)
# tensor(342.6331, grad_fn=<DotBackward0>)
# tensor(342.3073, grad_fn=<DotBackward0>)
# tensor(341.9681, grad_fn=<DotBackward0>)
# tensor(341.5882, grad_fn=<DotBackward0>)
# tensor(341.1530, grad_fn=<DotBackward0>)
# tensor(340.6982, grad_fn=<DotBackward0>)
# tensor(340.1763, grad_fn=<DotBackward0>)
# tensor(339.5673, grad_fn=<DotBackward0>)
# tensor(338.9201, grad_fn=<DotBackward0>)
# tensor(338.2008, grad_fn=<DotBackward0>)
# tensor(337.4034, grad_fn=<DotBackward0>)
# tensor(336.5396, grad_fn=<DotBackward0>)
# tensor(335.5444, grad_fn=<DotBackward0>)
# tensor(334.4733, grad_fn=<DotBackward0>)
# tensor(333.2728, grad_fn=<DotBackward0>)
# tensor(331.9658, grad_fn=<DotBackward0>)
# tensor(330.4917, grad_fn=<DotBackward0>)
# tensor(328.8591, grad_fn=<DotBackward0>)
# tensor(327.0201, grad_fn=<DotBackward0>)
# tensor(324.9795, grad_fn=<DotBackward0>)
# tensor(322.6474, grad_fn=<DotBackward0>)
# tensor(320.0439, grad_fn=<DotBackward0>)
# tensor(317.1072, grad_fn=<DotBackward0>)
# tensor(313.7872, grad_fn=<DotBackward0>)
# tensor(310.7301, grad_fn=<DotBackward0>)
# tensor(306.8720, grad_fn=<DotBackward0>)
# tensor(302.9939, grad_fn=<DotBackward0>)
# tensor(298.2838, grad_fn=<DotBackward0>)
# tensor(293.6261, grad_fn=<DotBackward0>)
# tensor(287.9044, grad_fn=<DotBackward0>)
# tensor(282.5192, grad_fn=<DotBackward0>)
# tensor(276.0587, grad_fn=<DotBackward0>)
# tensor(269.2020, grad_fn=<DotBackward0>)
# tensor(261.7130, grad_fn=<DotBackward0>)
# tensor(253.8976, grad_fn=<DotBackward0>)
# tensor(246.1061, grad_fn=<DotBackward0>)
# tensor(237.3202, grad_fn=<DotBackward0>)
# tensor(228.4863, grad_fn=<DotBackward0>)
# tensor(219.5166, grad_fn=<DotBackward0>)
# tensor(210.6712, grad_fn=<DotBackward0>)
# tensor(200.9770, grad_fn=<DotBackward0>)
# tensor(190.4243, grad_fn=<DotBackward0>)
# tensor(180.7683, grad_fn=<DotBackward0>)
# tensor(169.7252, grad_fn=<DotBackward0>)
# tensor(160.5231, grad_fn=<DotBackward0>)
# tensor(149.4974, grad_fn=<DotBackward0>)
# tensor(139.4755, grad_fn=<DotBackward0>)
# tensor(130.6755, grad_fn=<DotBackward0>)
# tensor(119.8047, grad_fn=<DotBackward0>)
# tensor(114.5200, grad_fn=<DotBackward0>)
# tensor(104.9886, grad_fn=<DotBackward0>)
# tensor(99.6174, grad_fn=<DotBackward0>)
# tensor(89.6355, grad_fn=<DotBackward0>)
# tensor(87.2801, grad_fn=<DotBackward0>)
# tensor(78.3452, grad_fn=<DotBackward0>)
# tensor(77.4005, grad_fn=<DotBackward0>)
# tensor(70.7320, grad_fn=<DotBackward0>)
# tensor(70.6960, grad_fn=<DotBackward0>)
# tensor(65.6139, grad_fn=<DotBackward0>)
# tensor(65.1709, grad_fn=<DotBackward0>)
# tensor(64.0048, grad_fn=<DotBackward0>)
# tensor(62.2718, grad_fn=<DotBackward0>)
# tensor(63.1536, grad_fn=<DotBackward0>)
# tensor(61.5325, grad_fn=<DotBackward0>)
# tensor(62.5577, grad_fn=<DotBackward0>)
# tensor(61.8040, grad_fn=<DotBackward0>)
# tensor(62.1099, grad_fn=<DotBackward0>)
# tensor(62.0578, grad_fn=<DotBackward0>)
# tensor(61.7108, grad_fn=<DotBackward0>)
# tensor(61.8750, grad_fn=<DotBackward0>)
# tensor(61.0212, grad_fn=<DotBackward0>)
# tensor(61.0694, grad_fn=<DotBackward0>)
# tensor(59.8977, grad_fn=<DotBackward0>)
# tensor(59.1768, grad_fn=<DotBackward0>)
# tensor(57.9034, grad_fn=<DotBackward0>)
# tensor(56.4084, grad_fn=<DotBackward0>)
# tensor(54.6409, grad_fn=<DotBackward0>)
# tensor(53.2045, grad_fn=<DotBackward0>)
# tensor(51.5150, grad_fn=<DotBackward0>)
# tensor(49.8510, grad_fn=<DotBackward0>)
# tensor(48.2585, grad_fn=<DotBackward0>)
# tensor(46.5658, grad_fn=<DotBackward0>)
# tensor(46.2112, grad_fn=<DotBackward0>)
# tensor(46.1508, grad_fn=<DotBackward0>)
# tensor(47.1499, grad_fn=<DotBackward0>)
# tensor(45.3149, grad_fn=<DotBackward0>)
# tensor(43.7597, grad_fn=<DotBackward0>)
# tensor(42.6516, grad_fn=<DotBackward0>)
# tensor(41.8241, grad_fn=<DotBackward0>)
# tensor(41.0668, grad_fn=<DotBackward0>)
# tensor(40.3124, grad_fn=<DotBackward0>)
# tensor(39.3901, grad_fn=<DotBackward0>)
# tensor(38.5646, grad_fn=<DotBackward0>)
# tensor(37.6913, grad_fn=<DotBackward0>)
# tensor(36.7557, grad_fn=<DotBackward0>)
# tensor(35.9128, grad_fn=<DotBackward0>)
# tensor(34.9619, grad_fn=<DotBackward0>)
# tensor(34.0665, grad_fn=<DotBackward0>)
# tensor(33.1596, grad_fn=<DotBackward0>)
# tensor(32.2191, grad_fn=<DotBackward0>)
# tensor(31.3410, grad_fn=<DotBackward0>)
# tensor(30.3942, grad_fn=<DotBackward0>)
# tensor(29.5190, grad_fn=<DotBackward0>)
# tensor(28.6036, grad_fn=<DotBackward0>)
# tensor(27.7383, grad_fn=<DotBackward0>)
# tensor(26.8667, grad_fn=<DotBackward0>)
# tensor(26.0222, grad_fn=<DotBackward0>)
# tensor(25.1993, grad_fn=<DotBackward0>)
# tensor(24.4232, grad_fn=<DotBackward0>)
# tensor(23.6802, grad_fn=<DotBackward0>)
# tensor(22.9696, grad_fn=<DotBackward0>)
# tensor(22.2995, grad_fn=<DotBackward0>)
# tensor(21.6341, grad_fn=<DotBackward0>)
# tensor(21.0249, grad_fn=<DotBackward0>)
# tensor(20.4084, grad_fn=<DotBackward0>)
# tensor(19.8504, grad_fn=<DotBackward0>)
# tensor(19.2898, grad_fn=<DotBackward0>)
# tensor(18.7879, grad_fn=<DotBackward0>)
# tensor(18.3011, grad_fn=<DotBackward0>)
# tensor(17.8557, grad_fn=<DotBackward0>)
# tensor(17.4057, grad_fn=<DotBackward0>)
# tensor(16.9998, grad_fn=<DotBackward0>)
# tensor(16.6159, grad_fn=<DotBackward0>)
# tensor(16.2745, grad_fn=<DotBackward0>)
# tensor(15.9469, grad_fn=<DotBackward0>)
# tensor(15.6479, grad_fn=<DotBackward0>)
# tensor(15.3640, grad_fn=<DotBackward0>)
# tensor(15.0996, grad_fn=<DotBackward0>)
# tensor(14.8581, grad_fn=<DotBackward0>)
# tensor(14.6411, grad_fn=<DotBackward0>)
# tensor(14.4546, grad_fn=<DotBackward0>)
# tensor(14.2745, grad_fn=<DotBackward0>)
# tensor(14.1103, grad_fn=<DotBackward0>)
# tensor(13.9627, grad_fn=<DotBackward0>)
# tensor(13.8355, grad_fn=<DotBackward0>)
# tensor(13.7262, grad_fn=<DotBackward0>)
# tensor(13.6223, grad_fn=<DotBackward0>)
# tensor(13.5299, grad_fn=<DotBackward0>)
# tensor(13.4505, grad_fn=<DotBackward0>)
# tensor(13.3829, grad_fn=<DotBackward0>)
# tensor(13.3262, grad_fn=<DotBackward0>)
# tensor(13.2723, grad_fn=<DotBackward0>)
# tensor(13.2252, grad_fn=<DotBackward0>)
# tensor(13.1882, grad_fn=<DotBackward0>)
# tensor(13.1565, grad_fn=<DotBackward0>)
# tensor(13.1290, grad_fn=<DotBackward0>)
# tensor(13.1048, grad_fn=<DotBackward0>)
# tensor(13.0838, grad_fn=<DotBackward0>)
# tensor(13.0682, grad_fn=<DotBackward0>)
# tensor(13.0557, grad_fn=<DotBackward0>)
# tensor(13.0434, grad_fn=<DotBackward0>)
# tensor(13.0331, grad_fn=<DotBackward0>)
# tensor(13.0258, grad_fn=<DotBackward0>)
# tensor(13.0198, grad_fn=<DotBackward0>)
# tensor(13.0148, grad_fn=<DotBackward0>)
# tensor(13.0105, grad_fn=<DotBackward0>)
# tensor(13.0068, grad_fn=<DotBackward0>)
# tensor(13.0044, grad_fn=<DotBackward0>)
# tensor(13.0031, grad_fn=<DotBackward0>)
# tensor(13.0015, grad_fn=<DotBackward0>)
# tensor(13.0001, grad_fn=<DotBackward0>)
# tensor(12.9997, grad_fn=<DotBackward0>)
# tensor(12.9997, grad_fn=<DotBackward0>)
# tensor(12.9998, grad_fn=<DotBackward0>)
# tensor(13.0001, grad_fn=<DotBackward0>)
# tensor(13.0007, grad_fn=<DotBackward0>)
# tensor(13.0016, grad_fn=<DotBackward0>)
# tensor(13.0029, grad_fn=<DotBackward0>)
# tensor(13.0042, grad_fn=<DotBackward0>)
# tensor(13.0056, grad_fn=<DotBackward0>)
# tensor(13.0073, grad_fn=<DotBackward0>)
# tensor(13.0093, grad_fn=<DotBackward0>)
# tensor(13.0113, grad_fn=<DotBackward0>)
# tensor(13.0134, grad_fn=<DotBackward0>)
# tensor(13.0157, grad_fn=<DotBackward0>)
# tensor(13.0181, grad_fn=<DotBackward0>)
# tensor(13.0206, grad_fn=<DotBackward0>)
# tensor(13.0231, grad_fn=<DotBackward0>)
# tensor(13.0257, grad_fn=<DotBackward0>)
# tensor(13.0283, grad_fn=<DotBackward0>)
# tensor(13.0310, grad_fn=<DotBackward0>)
# tensor(13.0337, grad_fn=<DotBackward0>)
# tensor(13.0363, grad_fn=<DotBackward0>)
# tensor(13.0389, grad_fn=<DotBackward0>)
# tensor(13.0416, grad_fn=<DotBackward0>)
# tensor(13.0441, grad_fn=<DotBackward0>)
# tensor(13.0466, grad_fn=<DotBackward0>)
# tensor(13.0490, grad_fn=<DotBackward0>)
# tensor(13.0513, grad_fn=<DotBackward0>)
# tensor(13.0535, grad_fn=<DotBackward0>)
# tensor(13.0557, grad_fn=<DotBackward0>)
# tensor(13.0577, grad_fn=<DotBackward0>)
# tensor(13.0596, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0630, grad_fn=<DotBackward0>)
# tensor(13.0646, grad_fn=<DotBackward0>)
# tensor(13.0660, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0686, grad_fn=<DotBackward0>)
# tensor(13.0697, grad_fn=<DotBackward0>)
# tensor(13.0707, grad_fn=<DotBackward0>)
# tensor(13.0715, grad_fn=<DotBackward0>)
# tensor(13.0723, grad_fn=<DotBackward0>)
# tensor(13.0730, grad_fn=<DotBackward0>)
# tensor(13.0736, grad_fn=<DotBackward0>)
# tensor(13.0740, grad_fn=<DotBackward0>)
# tensor(13.0744, grad_fn=<DotBackward0>)
# tensor(13.0748, grad_fn=<DotBackward0>)
# tensor(13.0750, grad_fn=<DotBackward0>)
# tensor(13.0752, grad_fn=<DotBackward0>)
# tensor(13.0753, grad_fn=<DotBackward0>)
# tensor(13.0754, grad_fn=<DotBackward0>)
# tensor(13.0754, grad_fn=<DotBackward0>)
# tensor(13.0753, grad_fn=<DotBackward0>)
# tensor(13.0752, grad_fn=<DotBackward0>)
# tensor(13.0751, grad_fn=<DotBackward0>)
# tensor(13.0749, grad_fn=<DotBackward0>)
# tensor(13.0747, grad_fn=<DotBackward0>)
# tensor(13.0745, grad_fn=<DotBackward0>)
# tensor(13.0743, grad_fn=<DotBackward0>)
# tensor(13.0740, grad_fn=<DotBackward0>)
# tensor(13.0738, grad_fn=<DotBackward0>)
# tensor(13.0735, grad_fn=<DotBackward0>)
# tensor(13.0732, grad_fn=<DotBackward0>)
# tensor(13.0729, grad_fn=<DotBackward0>)
# tensor(13.0726, grad_fn=<DotBackward0>)
# tensor(13.0723, grad_fn=<DotBackward0>)
# tensor(13.0720, grad_fn=<DotBackward0>)
# tensor(13.0717, grad_fn=<DotBackward0>)
# tensor(13.0714, grad_fn=<DotBackward0>)
# tensor(13.0711, grad_fn=<DotBackward0>)
# tensor(13.0709, grad_fn=<DotBackward0>)
# tensor(13.0706, grad_fn=<DotBackward0>)
# tensor(13.0703, grad_fn=<DotBackward0>)
# tensor(13.0701, grad_fn=<DotBackward0>)
# tensor(13.0699, grad_fn=<DotBackward0>)
# tensor(13.0696, grad_fn=<DotBackward0>)
# tensor(13.0694, grad_fn=<DotBackward0>)
# tensor(13.0692, grad_fn=<DotBackward0>)
# tensor(13.0690, grad_fn=<DotBackward0>)
# tensor(13.0688, grad_fn=<DotBackward0>)
# tensor(13.0687, grad_fn=<DotBackward0>)
# tensor(13.0685, grad_fn=<DotBackward0>)
# tensor(13.0684, grad_fn=<DotBackward0>)
# tensor(13.0683, grad_fn=<DotBackward0>)
# tensor(13.0681, grad_fn=<DotBackward0>)
# tensor(13.0680, grad_fn=<DotBackward0>)
# tensor(13.0679, grad_fn=<DotBackward0>)
# tensor(13.0678, grad_fn=<DotBackward0>)
# tensor(13.0678, grad_fn=<DotBackward0>)
# tensor(13.0677, grad_fn=<DotBackward0>)
# tensor(13.0676, grad_fn=<DotBackward0>)
# tensor(13.0676, grad_fn=<DotBackward0>)
# tensor(13.0675, grad_fn=<DotBackward0>)
# tensor(13.0675, grad_fn=<DotBackward0>)
# tensor(13.0675, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0674, grad_fn=<DotBackward0>)
# tensor(13.0673, grad_fn=<DotBackward0>)
# tensor(13.0671, grad_fn=<DotBackward0>)
# tensor(13.0669, grad_fn=<DotBackward0>)
# tensor(13.0667, grad_fn=<DotBackward0>)
# tensor(13.0665, grad_fn=<DotBackward0>)
# tensor(13.0662, grad_fn=<DotBackward0>)
# tensor(13.0660, grad_fn=<DotBackward0>)
# tensor(13.0656, grad_fn=<DotBackward0>)
# tensor(13.0653, grad_fn=<DotBackward0>)
# tensor(13.0650, grad_fn=<DotBackward0>)
# tensor(13.0646, grad_fn=<DotBackward0>)
# tensor(13.0642, grad_fn=<DotBackward0>)
# tensor(13.0638, grad_fn=<DotBackward0>)
# tensor(13.0633, grad_fn=<DotBackward0>)
# tensor(13.0628, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0598, grad_fn=<DotBackward0>)
# tensor(13.0593, grad_fn=<DotBackward0>)
# tensor(13.0588, grad_fn=<DotBackward0>)
# tensor(13.0583, grad_fn=<DotBackward0>)
# tensor(13.0577, grad_fn=<DotBackward0>)
# tensor(13.0571, grad_fn=<DotBackward0>)
# tensor(13.0566, grad_fn=<DotBackward0>)
# tensor(13.0560, grad_fn=<DotBackward0>)
# tensor(13.0554, grad_fn=<DotBackward0>)
# tensor(13.0548, grad_fn=<DotBackward0>)
# tensor(13.0542, grad_fn=<DotBackward0>)
# tensor(13.0535, grad_fn=<DotBackward0>)
# tensor(13.0529, grad_fn=<DotBackward0>)
# tensor(13.0523, grad_fn=<DotBackward0>)
# tensor(13.0519, grad_fn=<DotBackward0>)
# tensor(13.0513, grad_fn=<DotBackward0>)
# tensor(13.0508, grad_fn=<DotBackward0>)
# tensor(13.0504, grad_fn=<DotBackward0>)
# tensor(13.0499, grad_fn=<DotBackward0>)
# tensor(13.0494, grad_fn=<DotBackward0>)
# tensor(13.0489, grad_fn=<DotBackward0>)
# tensor(13.0484, grad_fn=<DotBackward0>)
# tensor(13.0479, grad_fn=<DotBackward0>)
# tensor(13.0475, grad_fn=<DotBackward0>)
# tensor(13.0470, grad_fn=<DotBackward0>)
# tensor(13.0466, grad_fn=<DotBackward0>)
# tensor(13.0463, grad_fn=<DotBackward0>)
# tensor(13.0459, grad_fn=<DotBackward0>)
# tensor(13.0456, grad_fn=<DotBackward0>)
# tensor(13.0454, grad_fn=<DotBackward0>)
# tensor(13.0453, grad_fn=<DotBackward0>)
# tensor(13.0453, grad_fn=<DotBackward0>)
# tensor(13.0452, grad_fn=<DotBackward0>)
# tensor(13.0429, grad_fn=<DotBackward0>)
# tensor(13.0427, grad_fn=<DotBackward0>)
# tensor(13.0398, grad_fn=<DotBackward0>)
# tensor(13.0375, grad_fn=<DotBackward0>)
# tensor(13.0357, grad_fn=<DotBackward0>)
# tensor(13.0324, grad_fn=<DotBackward0>)
# tensor(13.0300, grad_fn=<DotBackward0>)
# tensor(13.0269, grad_fn=<DotBackward0>)
# tensor(13.0245, grad_fn=<DotBackward0>)
# tensor(13.0233, grad_fn=<DotBackward0>)
# tensor(13.0198, grad_fn=<DotBackward0>)
# tensor(13.0157, grad_fn=<DotBackward0>)
# tensor(13.0126, grad_fn=<DotBackward0>)
# tensor(13.0105, grad_fn=<DotBackward0>)
# tensor(13.0074, grad_fn=<DotBackward0>)
# tensor(13.0029, grad_fn=<DotBackward0>)
# tensor(12.9995, grad_fn=<DotBackward0>)
# tensor(12.9970, grad_fn=<DotBackward0>)
# tensor(12.9934, grad_fn=<DotBackward0>)
# tensor(12.9894, grad_fn=<DotBackward0>)
# tensor(12.9859, grad_fn=<DotBackward0>)
# tensor(12.9827, grad_fn=<DotBackward0>)
# tensor(12.9792, grad_fn=<DotBackward0>)
# tensor(12.9752, grad_fn=<DotBackward0>)
# tensor(12.9715, grad_fn=<DotBackward0>)
# tensor(12.9684, grad_fn=<DotBackward0>)
# tensor(12.9649, grad_fn=<DotBackward0>)
# tensor(12.9610, grad_fn=<DotBackward0>)
# tensor(12.9573, grad_fn=<DotBackward0>)
# tensor(12.9539, grad_fn=<DotBackward0>)
# tensor(12.9506, grad_fn=<DotBackward0>)
# tensor(12.9469, grad_fn=<DotBackward0>)
# tensor(12.9432, grad_fn=<DotBackward0>)
# tensor(12.9398, grad_fn=<DotBackward0>)
# tensor(12.9367, grad_fn=<DotBackward0>)
# tensor(12.9335, grad_fn=<DotBackward0>)
# tensor(12.9304, grad_fn=<DotBackward0>)
# tensor(12.9274, grad_fn=<DotBackward0>)
# tensor(12.9244, grad_fn=<DotBackward0>)
# tensor(12.9213, grad_fn=<DotBackward0>)
# tensor(12.9184, grad_fn=<DotBackward0>)
# tensor(12.9158, grad_fn=<DotBackward0>)
# tensor(12.9137, grad_fn=<DotBackward0>)
# tensor(12.9134, grad_fn=<DotBackward0>)
# tensor(12.9200, grad_fn=<DotBackward0>)
# tensor(12.9469, grad_fn=<DotBackward0>)
# tensor(12.9564, grad_fn=<DotBackward0>)
# tensor(13.0033, grad_fn=<DotBackward0>)
# tensor(12.9735, grad_fn=<DotBackward0>)
# tensor(12.9919, grad_fn=<DotBackward0>)
# tensor(12.9451, grad_fn=<DotBackward0>)
# tensor(12.9417, grad_fn=<DotBackward0>)
# tensor(12.9363, grad_fn=<DotBackward0>)
# tensor(12.9702, grad_fn=<DotBackward0>)
# tensor(12.9566, grad_fn=<DotBackward0>)
# tensor(12.9830, grad_fn=<DotBackward0>)
# tensor(12.9374, grad_fn=<DotBackward0>)
# tensor(12.9331, grad_fn=<DotBackward0>)
# tensor(12.9265, grad_fn=<DotBackward0>)
# tensor(12.9563, grad_fn=<DotBackward0>)
# tensor(12.9747, grad_fn=<DotBackward0>)
# tensor(13.0438, grad_fn=<DotBackward0>)
# tensor(12.9699, grad_fn=<DotBackward0>)
# tensor(12.9427, grad_fn=<DotBackward0>)
# tensor(12.9083, grad_fn=<DotBackward0>)
# tensor(12.9022, grad_fn=<DotBackward0>)
# tensor(12.9151, grad_fn=<DotBackward0>)
# tensor(12.9596, grad_fn=<DotBackward0>)
# tensor(12.9365, grad_fn=<DotBackward0>)
# tensor(12.9373, grad_fn=<DotBackward0>)
# tensor(12.9204, grad_fn=<DotBackward0>)
# tensor(12.9342, grad_fn=<DotBackward0>)
# tensor(12.9353, grad_fn=<DotBackward0>)
# tensor(12.9694, grad_fn=<DotBackward0>)
# tensor(12.9166, grad_fn=<DotBackward0>)
# tensor(12.8921, grad_fn=<DotBackward0>)
# tensor(12.8934, grad_fn=<DotBackward0>)
# tensor(12.9018, grad_fn=<DotBackward0>)
# tensor(12.9354, grad_fn=<DotBackward0>)
# tensor(13.0080, grad_fn=<DotBackward0>)
# tensor(12.9450, grad_fn=<DotBackward0>)
# tensor(12.9111, grad_fn=<DotBackward0>)
# tensor(12.9170, grad_fn=<DotBackward0>)
# tensor(12.9455, grad_fn=<DotBackward0>)
# tensor(13.0259, grad_fn=<DotBackward0>)
# tensor(13.1539, grad_fn=<DotBackward0>)
# tensor(12.9756, grad_fn=<DotBackward0>)
# tensor(12.8746, grad_fn=<DotBackward0>)
# tensor(12.8842, grad_fn=<DotBackward0>)
# tensor(12.9335, grad_fn=<DotBackward0>)
# tensor(13.0374, grad_fn=<DotBackward0>)
# tensor(12.9998, grad_fn=<DotBackward0>)
# tensor(12.9268, grad_fn=<DotBackward0>)
# tensor(12.9227, grad_fn=<DotBackward0>)
# tensor(12.9200, grad_fn=<DotBackward0>)
# tensor(12.9020, grad_fn=<DotBackward0>)
# tensor(12.9328, grad_fn=<DotBackward0>)
# tensor(12.9325, grad_fn=<DotBackward0>)
# tensor(12.9741, grad_fn=<DotBackward0>)
# tensor(13.0378, grad_fn=<DotBackward0>)
# tensor(13.1455, grad_fn=<DotBackward0>)
# tensor(13.0110, grad_fn=<DotBackward0>)
# tensor(12.8819, grad_fn=<DotBackward0>)
# tensor(12.9057, grad_fn=<DotBackward0>)
# tensor(12.9973, grad_fn=<DotBackward0>)
# tensor(13.0809, grad_fn=<DotBackward0>)
# tensor(13.0740, grad_fn=<DotBackward0>)
# tensor(12.9577, grad_fn=<DotBackward0>)
# tensor(12.8787, grad_fn=<DotBackward0>)
# tensor(12.9473, grad_fn=<DotBackward0>)
# tensor(13.0404, grad_fn=<DotBackward0>)
# tensor(13.0679, grad_fn=<DotBackward0>)
# tensor(12.9924, grad_fn=<DotBackward0>)
# tensor(12.8723, grad_fn=<DotBackward0>)
# tensor(12.9385, grad_fn=<DotBackward0>)
# tensor(13.0620, grad_fn=<DotBackward0>)
# tensor(13.0679, grad_fn=<DotBackward0>)
# tensor(12.9930, grad_fn=<DotBackward0>)
# tensor(12.8686, grad_fn=<DotBackward0>)
# tensor(12.9716, grad_fn=<DotBackward0>)
# tensor(13.1488, grad_fn=<DotBackward0>)
# tensor(13.0768, grad_fn=<DotBackward0>)
# tensor(12.9566, grad_fn=<DotBackward0>)
# tensor(12.8823, grad_fn=<DotBackward0>)
# tensor(13.0794, grad_fn=<DotBackward0>)
# tensor(13.2884, grad_fn=<DotBackward0>)
# tensor(13.0551, grad_fn=<DotBackward0>)
# tensor(12.9052, grad_fn=<DotBackward0>)
# tensor(12.9592, grad_fn=<DotBackward0>)
# tensor(13.0792, grad_fn=<DotBackward0>)
# tensor(13.0721, grad_fn=<DotBackward0>)
# tensor(12.9031, grad_fn=<DotBackward0>)
# tensor(12.9158, grad_fn=<DotBackward0>)
# tensor(13.0203, grad_fn=<DotBackward0>)
# tensor(12.9673, grad_fn=<DotBackward0>)
# tensor(12.8875, grad_fn=<DotBackward0>)
# tensor(12.8756, grad_fn=<DotBackward0>)
# tensor(12.9222, grad_fn=<DotBackward0>)
# tensor(12.9533, grad_fn=<DotBackward0>)
# tensor(12.8900, grad_fn=<DotBackward0>)
# tensor(12.8708, grad_fn=<DotBackward0>)
# tensor(12.9055, grad_fn=<DotBackward0>)
# tensor(12.9112, grad_fn=<DotBackward0>)
# tensor(12.8934, grad_fn=<DotBackward0>)
# tensor(12.8684, grad_fn=<DotBackward0>)
# tensor(12.8803, grad_fn=<DotBackward0>)
# tensor(12.9072, grad_fn=<DotBackward0>)
# tensor(12.8939, grad_fn=<DotBackward0>)
# tensor(12.8744, grad_fn=<DotBackward0>)
# tensor(12.8661, grad_fn=<DotBackward0>)
# tensor(12.8739, grad_fn=<DotBackward0>)
# tensor(12.8844, grad_fn=<DotBackward0>)
# tensor(12.8862, grad_fn=<DotBackward0>)
# tensor(12.8778, grad_fn=<DotBackward0>)
# tensor(12.8667, grad_fn=<DotBackward0>)
# tensor(12.8633, grad_fn=<DotBackward0>)
# tensor(12.8671, grad_fn=<DotBackward0>)
# tensor(12.8725, grad_fn=<DotBackward0>)
# tensor(12.8732, grad_fn=<DotBackward0>)
# tensor(12.8678, grad_fn=<DotBackward0>)
# tensor(12.8621, grad_fn=<DotBackward0>)
# tensor(12.8593, grad_fn=<DotBackward0>)
# tensor(12.8609, grad_fn=<DotBackward0>)
# tensor(12.8636, grad_fn=<DotBackward0>)
# tensor(12.8638, grad_fn=<DotBackward0>)
# tensor(12.8614, grad_fn=<DotBackward0>)
# tensor(12.8575, grad_fn=<DotBackward0>)
# tensor(12.8553, grad_fn=<DotBackward0>)
# tensor(12.8554, grad_fn=<DotBackward0>)
# tensor(12.8564, grad_fn=<DotBackward0>)
# tensor(12.8569, grad_fn=<DotBackward0>)
# tensor(12.8555, grad_fn=<DotBackward0>)
# tensor(12.8534, grad_fn=<DotBackward0>)
# tensor(12.8514, grad_fn=<DotBackward0>)
# tensor(12.8506, grad_fn=<DotBackward0>)
# tensor(12.8507, grad_fn=<DotBackward0>)
# tensor(12.8508, grad_fn=<DotBackward0>)
# tensor(12.8503, grad_fn=<DotBackward0>)
# tensor(12.8490, grad_fn=<DotBackward0>)
# tensor(12.8475, grad_fn=<DotBackward0>)
# tensor(12.8464, grad_fn=<DotBackward0>)
# tensor(12.8457, grad_fn=<DotBackward0>)
# tensor(12.8454, grad_fn=<DotBackward0>)
# tensor(12.8451, grad_fn=<DotBackward0>)
# tensor(12.8444, grad_fn=<DotBackward0>)
# tensor(12.8434, grad_fn=<DotBackward0>)
# tensor(12.8423, grad_fn=<DotBackward0>)
# tensor(12.8414, grad_fn=<DotBackward0>)
# tensor(12.8407, grad_fn=<DotBackward0>)
# tensor(12.8401, grad_fn=<DotBackward0>)
# tensor(12.8396, grad_fn=<DotBackward0>)
# tensor(12.8390, grad_fn=<DotBackward0>)
# tensor(12.8381, grad_fn=<DotBackward0>)
# tensor(12.8372, grad_fn=<DotBackward0>)
# tensor(12.8364, grad_fn=<DotBackward0>)
# tensor(12.8356, grad_fn=<DotBackward0>)
# tensor(12.8349, grad_fn=<DotBackward0>)
# tensor(12.8343, grad_fn=<DotBackward0>)
# tensor(12.8336, grad_fn=<DotBackward0>)
# tensor(12.8329, grad_fn=<DotBackward0>)
# tensor(12.8322, grad_fn=<DotBackward0>)
# tensor(12.8315, grad_fn=<DotBackward0>)
# tensor(12.8309, grad_fn=<DotBackward0>)
# tensor(12.8304, grad_fn=<DotBackward0>)
# tensor(12.8298, grad_fn=<DotBackward0>)
# tensor(12.8293, grad_fn=<DotBackward0>)
# tensor(12.8287, grad_fn=<DotBackward0>)
# tensor(12.8282, grad_fn=<DotBackward0>)
# tensor(12.8276, grad_fn=<DotBackward0>)
# tensor(12.8271, grad_fn=<DotBackward0>)
# tensor(12.8266, grad_fn=<DotBackward0>)
# tensor(12.8260, grad_fn=<DotBackward0>)
# tensor(12.8255, grad_fn=<DotBackward0>)
# tensor(12.8250, grad_fn=<DotBackward0>)
# tensor(12.8245, grad_fn=<DotBackward0>)
# tensor(12.8240, grad_fn=<DotBackward0>)
# tensor(12.8236, grad_fn=<DotBackward0>)
# tensor(12.8233, grad_fn=<DotBackward0>)
# tensor(12.8233, grad_fn=<DotBackward0>)
# tensor(12.8234, grad_fn=<DotBackward0>)
# tensor(12.8242, grad_fn=<DotBackward0>)
# tensor(12.8257, grad_fn=<DotBackward0>)
# tensor(12.8289, grad_fn=<DotBackward0>)
# tensor(12.8343, grad_fn=<DotBackward0>)
# tensor(12.8438, grad_fn=<DotBackward0>)
# tensor(12.8521, grad_fn=<DotBackward0>)
# tensor(12.8621, grad_fn=<DotBackward0>)
# tensor(12.8682, grad_fn=<DotBackward0>)
# tensor(13.0241, grad_fn=<DotBackward0>)
# tensor(13.3105, grad_fn=<DotBackward0>)
# tensor(15.4189, grad_fn=<DotBackward0>)
# tensor(17.8260, grad_fn=<DotBackward0>)
# tensor(22.7717, grad_fn=<DotBackward0>)
# tensor(15.2166, grad_fn=<DotBackward0>)
# tensor(22.5194, grad_fn=<DotBackward0>)
# tensor(30.8026, grad_fn=<DotBackward0>)
# tensor(17.6043, grad_fn=<DotBackward0>)
# tensor(35.6346, grad_fn=<DotBackward0>)
# tensor(17.2338, grad_fn=<DotBackward0>)
# tensor(28.7958, grad_fn=<DotBackward0>)
# tensor(19.3020, grad_fn=<DotBackward0>)
# tensor(29.9404, grad_fn=<DotBackward0>)
# tensor(13.8217, grad_fn=<DotBackward0>)
# tensor(17.0783, grad_fn=<DotBackward0>)
# tensor(19.6691, grad_fn=<DotBackward0>)
# tensor(19.5826, grad_fn=<DotBackward0>)
# tensor(13.3646, grad_fn=<DotBackward0>)
# tensor(13.3543, grad_fn=<DotBackward0>)
# tensor(14.0438, grad_fn=<DotBackward0>)
# tensor(14.0754, grad_fn=<DotBackward0>)
# tensor(14.1866, grad_fn=<DotBackward0>)
# tensor(13.8644, grad_fn=<DotBackward0>)
# tensor(13.7300, grad_fn=<DotBackward0>)
# tensor(13.3168, grad_fn=<DotBackward0>)
# tensor(13.2324, grad_fn=<DotBackward0>)
# tensor(13.0040, grad_fn=<DotBackward0>)
# tensor(13.1267, grad_fn=<DotBackward0>)
# tensor(13.1062, grad_fn=<DotBackward0>)
# tensor(13.3174, grad_fn=<DotBackward0>)
# tensor(13.3108, grad_fn=<DotBackward0>)
# tensor(13.4161, grad_fn=<DotBackward0>)
# tensor(13.3054, grad_fn=<DotBackward0>)
# tensor(13.2877, grad_fn=<DotBackward0>)
# tensor(13.1421, grad_fn=<DotBackward0>)
# tensor(13.1183, grad_fn=<DotBackward0>)
# tensor(13.0497, grad_fn=<DotBackward0>)
# tensor(13.0895, grad_fn=<DotBackward0>)
# tensor(13.1016, grad_fn=<DotBackward0>)
# tensor(13.1624, grad_fn=<DotBackward0>)
# tensor(13.1855, grad_fn=<DotBackward0>)
# tensor(13.2070, grad_fn=<DotBackward0>)
# tensor(13.1962, grad_fn=<DotBackward0>)
# tensor(13.1694, grad_fn=<DotBackward0>)
# tensor(13.1414, grad_fn=<DotBackward0>)
# tensor(13.1079, grad_fn=<DotBackward0>)
# tensor(13.0991, grad_fn=<DotBackward0>)
# tensor(13.0873, grad_fn=<DotBackward0>)
# tensor(13.1045, grad_fn=<DotBackward0>)
# tensor(13.1085, grad_fn=<DotBackward0>)
# tensor(13.1295, grad_fn=<DotBackward0>)
# tensor(13.1254, grad_fn=<DotBackward0>)
# tensor(13.1310, grad_fn=<DotBackward0>)
# tensor(13.1145, grad_fn=<DotBackward0>)
# tensor(13.1103, grad_fn=<DotBackward0>)
# tensor(13.0937, grad_fn=<DotBackward0>)
# tensor(13.0930, grad_fn=<DotBackward0>)
# tensor(13.0870, grad_fn=<DotBackward0>)
# tensor(13.0938, grad_fn=<DotBackward0>)
# tensor(13.0943, grad_fn=<DotBackward0>)
# tensor(13.1000, grad_fn=<DotBackward0>)
# tensor(13.0987, grad_fn=<DotBackward0>)
# tensor(13.0982, grad_fn=<DotBackward0>)
# tensor(13.0922, grad_fn=<DotBackward0>)
# tensor(13.0869, grad_fn=<DotBackward0>)
# tensor(13.0808, grad_fn=<DotBackward0>)
# tensor(13.0768, grad_fn=<DotBackward0>)
# tensor(13.0744, grad_fn=<DotBackward0>)
# tensor(13.0731, grad_fn=<DotBackward0>)
# tensor(13.0733, grad_fn=<DotBackward0>)
# tensor(13.0730, grad_fn=<DotBackward0>)
# tensor(13.0730, grad_fn=<DotBackward0>)
# tensor(13.0709, grad_fn=<DotBackward0>)
# tensor(13.0695, grad_fn=<DotBackward0>)
# tensor(13.0669, grad_fn=<DotBackward0>)
# tensor(13.0656, grad_fn=<DotBackward0>)
# tensor(13.0636, grad_fn=<DotBackward0>)
# tensor(13.0636, grad_fn=<DotBackward0>)
# tensor(13.0630, grad_fn=<DotBackward0>)
# tensor(13.0638, grad_fn=<DotBackward0>)
# tensor(13.0633, grad_fn=<DotBackward0>)
# tensor(13.0635, grad_fn=<DotBackward0>)
# tensor(13.0626, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0593, grad_fn=<DotBackward0>)
# tensor(13.0592, grad_fn=<DotBackward0>)
# tensor(13.0588, grad_fn=<DotBackward0>)
# tensor(13.0590, grad_fn=<DotBackward0>)
# tensor(13.0589, grad_fn=<DotBackward0>)
# tensor(13.0591, grad_fn=<DotBackward0>)
# tensor(13.0590, grad_fn=<DotBackward0>)
# tensor(13.0591, grad_fn=<DotBackward0>)
# tensor(13.0590, grad_fn=<DotBackward0>)
# tensor(13.0592, grad_fn=<DotBackward0>)
# tensor(13.0592, grad_fn=<DotBackward0>)
# tensor(13.0595, grad_fn=<DotBackward0>)
# tensor(13.0598, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0618, grad_fn=<DotBackward0>)
# tensor(13.0619, grad_fn=<DotBackward0>)
# tensor(13.0620, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0625, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0624, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0623, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0622, grad_fn=<DotBackward0>)
# tensor(13.0621, grad_fn=<DotBackward0>)
# tensor(13.0621, grad_fn=<DotBackward0>)
# tensor(13.0621, grad_fn=<DotBackward0>)
# tensor(13.0620, grad_fn=<DotBackward0>)
# tensor(13.0620, grad_fn=<DotBackward0>)
# tensor(13.0619, grad_fn=<DotBackward0>)
# tensor(13.0619, grad_fn=<DotBackward0>)
# tensor(13.0619, grad_fn=<DotBackward0>)
# tensor(13.0618, grad_fn=<DotBackward0>)
# tensor(13.0618, grad_fn=<DotBackward0>)
# tensor(13.0618, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0617, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0616, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0615, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0614, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0613, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0612, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0611, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0610, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0609, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0608, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0607, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0606, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0605, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0604, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0603, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0602, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0601, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0600, grad_fn=<DotBackward0>)
# tensor(13.0599, grad_fn=<DotBackward0>)
# ...
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7299, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7302, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7302, grad_fn=<DotBackward0>)
# tensor(1.7300, grad_fn=<DotBackward0>)
# tensor(1.7303, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7303, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7303, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7304, grad_fn=<DotBackward0>)
# tensor(1.7302, grad_fn=<DotBackward0>)
# tensor(1.7306, grad_fn=<DotBackward0>)
# tensor(1.7304, grad_fn=<DotBackward0>)
# tensor(1.7309, grad_fn=<DotBackward0>)
# tensor(1.7307, grad_fn=<DotBackward0>)
# tensor(1.7314, grad_fn=<DotBackward0>)
# tensor(1.7311, grad_fn=<DotBackward0>)
# tensor(1.7321, grad_fn=<DotBackward0>)
# tensor(1.7318, grad_fn=<DotBackward0>)
# tensor(1.7331, grad_fn=<DotBackward0>)
# tensor(1.7327, grad_fn=<DotBackward0>)
# tensor(1.7344, grad_fn=<DotBackward0>)
# tensor(1.7339, grad_fn=<DotBackward0>)
# tensor(1.7358, grad_fn=<DotBackward0>)
# tensor(1.7351, grad_fn=<DotBackward0>)
# tensor(1.7366, grad_fn=<DotBackward0>)
# tensor(1.7353, grad_fn=<DotBackward0>)
# tensor(1.7363, grad_fn=<DotBackward0>)
# tensor(1.7347, grad_fn=<DotBackward0>)
# tensor(1.7358, grad_fn=<DotBackward0>)
# tensor(1.7345, grad_fn=<DotBackward0>)
# tensor(1.7357, grad_fn=<DotBackward0>)
# tensor(1.7346, grad_fn=<DotBackward0>)
# tensor(1.7356, grad_fn=<DotBackward0>)
# tensor(1.7343, grad_fn=<DotBackward0>)
# tensor(1.7351, grad_fn=<DotBackward0>)
# tensor(1.7338, grad_fn=<DotBackward0>)
# tensor(1.7350, grad_fn=<DotBackward0>)
# tensor(1.7342, grad_fn=<DotBackward0>)
# tensor(1.7359, grad_fn=<DotBackward0>)
# tensor(1.7355, grad_fn=<DotBackward0>)
# tensor(1.7382, grad_fn=<DotBackward0>)
# tensor(1.7384, grad_fn=<DotBackward0>)
# tensor(1.7425, grad_fn=<DotBackward0>)
# tensor(1.7434, grad_fn=<DotBackward0>)
# tensor(1.7483, grad_fn=<DotBackward0>)
# tensor(1.7491, grad_fn=<DotBackward0>)
# tensor(1.7547, grad_fn=<DotBackward0>)
# tensor(1.7555, grad_fn=<DotBackward0>)
# tensor(1.7642, grad_fn=<DotBackward0>)
# tensor(1.7671, grad_fn=<DotBackward0>)
# tensor(1.7768, grad_fn=<DotBackward0>)
# tensor(1.7793, grad_fn=<DotBackward0>)
# tensor(1.7930, grad_fn=<DotBackward0>)
# tensor(1.7976, grad_fn=<DotBackward0>)
# tensor(1.8098, grad_fn=<DotBackward0>)
# tensor(1.8100, grad_fn=<DotBackward0>)
# tensor(1.8170, grad_fn=<DotBackward0>)
# tensor(1.8102, grad_fn=<DotBackward0>)
# tensor(1.8092, grad_fn=<DotBackward0>)
# tensor(1.7950, grad_fn=<DotBackward0>)
# tensor(1.7867, grad_fn=<DotBackward0>)
# tensor(1.7697, grad_fn=<DotBackward0>)
# tensor(1.7598, grad_fn=<DotBackward0>)
# tensor(1.7471, grad_fn=<DotBackward0>)
# tensor(1.7411, grad_fn=<DotBackward0>)
# tensor(1.7363, grad_fn=<DotBackward0>)
# tensor(1.7355, grad_fn=<DotBackward0>)
# tensor(1.7373, grad_fn=<DotBackward0>)
# tensor(1.7393, grad_fn=<DotBackward0>)
# tensor(1.7448, grad_fn=<DotBackward0>)
# tensor(1.7474, grad_fn=<DotBackward0>)
# tensor(1.7550, grad_fn=<DotBackward0>)
# tensor(1.7576, grad_fn=<DotBackward0>)
# tensor(1.7669, grad_fn=<DotBackward0>)
# tensor(1.7689, grad_fn=<DotBackward0>)
# tensor(1.7786, grad_fn=<DotBackward0>)
# tensor(1.7783, grad_fn=<DotBackward0>)
# tensor(1.7821, grad_fn=<DotBackward0>)
# tensor(1.7750, grad_fn=<DotBackward0>)
# tensor(1.7726, grad_fn=<DotBackward0>)
# tensor(1.7616, grad_fn=<DotBackward0>)
# tensor(1.7559, grad_fn=<DotBackward0>)
# tensor(1.7454, grad_fn=<DotBackward0>)
# tensor(1.7405, grad_fn=<DotBackward0>)
# tensor(1.7343, grad_fn=<DotBackward0>)
# tensor(1.7323, grad_fn=<DotBackward0>)
# tensor(1.7312, grad_fn=<DotBackward0>)
# tensor(1.7317, grad_fn=<DotBackward0>)
# tensor(1.7339, grad_fn=<DotBackward0>)
# tensor(1.7352, grad_fn=<DotBackward0>)
# tensor(1.7387, grad_fn=<DotBackward0>)
# tensor(1.7392, grad_fn=<DotBackward0>)
# tensor(1.7424, grad_fn=<DotBackward0>)
# tensor(1.7417, grad_fn=<DotBackward0>)
# tensor(1.7452, grad_fn=<DotBackward0>)
# tensor(1.7448, grad_fn=<DotBackward0>)
# tensor(1.7494, grad_fn=<DotBackward0>)
# tensor(1.7496, grad_fn=<DotBackward0>)
# tensor(1.7557, grad_fn=<DotBackward0>)
# tensor(1.7563, grad_fn=<DotBackward0>)
# tensor(1.7637, grad_fn=<DotBackward0>)
# tensor(1.7637, grad_fn=<DotBackward0>)
# tensor(1.7683, grad_fn=<DotBackward0>)
# tensor(1.7647, grad_fn=<DotBackward0>)
# tensor(1.7658, grad_fn=<DotBackward0>)
# tensor(1.7593, grad_fn=<DotBackward0>)
# tensor(1.7577, grad_fn=<DotBackward0>)
# tensor(1.7503, grad_fn=<DotBackward0>)
# tensor(1.7476, grad_fn=<DotBackward0>)
# tensor(1.7413, grad_fn=<DotBackward0>)
# tensor(1.7390, grad_fn=<DotBackward0>)
# tensor(1.7350, grad_fn=<DotBackward0>)
# tensor(1.7338, grad_fn=<DotBackward0>)
# tensor(1.7322, grad_fn=<DotBackward0>)
# tensor(1.7320, grad_fn=<DotBackward0>)
# tensor(1.7322, grad_fn=<DotBackward0>)
# tensor(1.7324, grad_fn=<DotBackward0>)
# tensor(1.7340, grad_fn=<DotBackward0>)
# tensor(1.7345, grad_fn=<DotBackward0>)
# tensor(1.7377, grad_fn=<DotBackward0>)
# tensor(1.7395, grad_fn=<DotBackward0>)
# tensor(1.7462, grad_fn=<DotBackward0>)
# tensor(1.7514, grad_fn=<DotBackward0>)
# tensor(1.7656, grad_fn=<DotBackward0>)
# tensor(1.7770, grad_fn=<DotBackward0>)
# tensor(1.8032, grad_fn=<DotBackward0>)
# tensor(1.8235, grad_fn=<DotBackward0>)
# tensor(1.8641, grad_fn=<DotBackward0>)
# tensor(1.8884, grad_fn=<DotBackward0>)
# tensor(1.9303, grad_fn=<DotBackward0>)
# tensor(1.9355, grad_fn=<DotBackward0>)
# tensor(1.9329, grad_fn=<DotBackward0>)
# tensor(1.8861, grad_fn=<DotBackward0>)
# tensor(1.8388, grad_fn=<DotBackward0>)
# tensor(1.7812, grad_fn=<DotBackward0>)
# tensor(1.7490, grad_fn=<DotBackward0>)
# tensor(1.7392, grad_fn=<DotBackward0>)
# tensor(1.7515, grad_fn=<DotBackward0>)
# tensor(1.7785, grad_fn=<DotBackward0>)
# tensor(1.7965, grad_fn=<DotBackward0>)
# tensor(1.8103, grad_fn=<DotBackward0>)
# tensor(1.7989, grad_fn=<DotBackward0>)
# tensor(1.7844, grad_fn=<DotBackward0>)
# tensor(1.7592, grad_fn=<DotBackward0>)
# tensor(1.7444, grad_fn=<DotBackward0>)
# tensor(1.7371, grad_fn=<DotBackward0>)
# tensor(1.7397, grad_fn=<DotBackward0>)
# tensor(1.7497, grad_fn=<DotBackward0>)
# tensor(1.7559, grad_fn=<DotBackward0>)
# tensor(1.7627, grad_fn=<DotBackward0>)
# tensor(1.7579, grad_fn=<DotBackward0>)
# tensor(1.7536, grad_fn=<DotBackward0>)
# tensor(1.7424, grad_fn=<DotBackward0>)
# tensor(1.7360, grad_fn=<DotBackward0>)
# tensor(1.7305, grad_fn=<DotBackward0>)
# tensor(1.7298, grad_fn=<DotBackward0>)
# tensor(1.7325, grad_fn=<DotBackward0>)
# tensor(1.7347, grad_fn=<DotBackward0>)
# tensor(1.7391, grad_fn=<DotBackward0>)
# tensor(1.7386, grad_fn=<DotBackward0>)
# tensor(1.7396, grad_fn=<DotBackward0>)
# tensor(1.7357, grad_fn=<DotBackward0>)
# tensor(1.7342, grad_fn=<DotBackward0>)
# tensor(1.7306, grad_fn=<DotBackward0>)
# tensor(1.7295, grad_fn=<DotBackward0>)
# tensor(1.7289, grad_fn=<DotBackward0>)
# tensor(1.7294, grad_fn=<DotBackward0>)
# tensor(1.7312, grad_fn=<DotBackward0>)
# tensor(1.7319, grad_fn=<DotBackward0>)
# tensor(1.7345, grad_fn=<DotBackward0>)
# tensor(1.7351, grad_fn=<DotBackward0>)
# tensor(1.7381, grad_fn=<DotBackward0>)
# tensor(1.7382, grad_fn=<DotBackward0>)
# tensor(1.7413, grad_fn=<DotBackward0>)
# tensor(1.7411, grad_fn=<DotBackward0>)
# tensor(1.7443, grad_fn=<DotBackward0>)
# tensor(1.7437, grad_fn=<DotBackward0>)
# tensor(1.7471, grad_fn=<DotBackward0>)
# tensor(1.7463, grad_fn=<DotBackward0>)
# tensor(1.7499, grad_fn=<DotBackward0>)
# tensor(1.7490, grad_fn=<DotBackward0>)
# tensor(1.7529, grad_fn=<DotBackward0>)
# tensor(1.7521, grad_fn=<DotBackward0>)
# tensor(1.7565, grad_fn=<DotBackward0>)
# tensor(1.7557, grad_fn=<DotBackward0>)
# tensor(1.7607, grad_fn=<DotBackward0>)
# tensor(1.7601, grad_fn=<DotBackward0>)
# tensor(1.7658, grad_fn=<DotBackward0>)
# tensor(1.7653, grad_fn=<DotBackward0>)
# tensor(1.7715, grad_fn=<DotBackward0>)
# tensor(1.7709, grad_fn=<DotBackward0>)
# tensor(1.7775, grad_fn=<DotBackward0>)
# tensor(1.7764, grad_fn=<DotBackward0>)
# tensor(1.7827, grad_fn=<DotBackward0>)
# tensor(1.7807, grad_fn=<DotBackward0>)
# tensor(1.7858, grad_fn=<DotBackward0>)
# tensor(1.7821, grad_fn=<DotBackward0>)
# tensor(1.7853, grad_fn=<DotBackward0>)
# tensor(1.7794, grad_fn=<DotBackward0>)
# tensor(1.7802, grad_fn=<DotBackward0>)
# tensor(1.7724, grad_fn=<DotBackward0>)
# tensor(1.7709, grad_fn=<DotBackward0>)
# tensor(1.7622, grad_fn=<DotBackward0>)
# tensor(1.7593, grad_fn=<DotBackward0>)
# tensor(1.7512, grad_fn=<DotBackward0>)
# tensor(1.7482, grad_fn=<DotBackward0>)
# tensor(1.7419, grad_fn=<DotBackward0>)
# tensor(1.7397, grad_fn=<DotBackward0>)
# tensor(1.7356, grad_fn=<DotBackward0>)
# tensor(1.7344, grad_fn=<DotBackward0>)
# tensor(1.7325, grad_fn=<DotBackward0>)
# tensor(1.7319, grad_fn=<DotBackward0>)
# tensor(1.7315, grad_fn=<DotBackward0>)
# tensor(1.7313, grad_fn=<DotBackward0>)
# tensor(1.7319, grad_fn=<DotBackward0>)
# tensor(1.7316, grad_fn=<DotBackward0>)
# tensor(1.7327, grad_fn=<DotBackward0>)
# tensor(1.7319, grad_fn=<DotBackward0>)
# tensor(1.7326, grad_fn=<DotBackward0>)
# tensor(1.7313, grad_fn=<DotBackward0>)
# tensor(1.7314, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7293, grad_fn=<DotBackward0>)
# tensor(1.7294, grad_fn=<DotBackward0>)
# tensor(1.7292, grad_fn=<DotBackward0>)
# tensor(1.7293, grad_fn=<DotBackward0>)
# tensor(1.7293, grad_fn=<DotBackward0>)
# tensor(1.7294, grad_fn=<DotBackward0>)
# tensor(1.7297, grad_fn=<DotBackward0>)
# tensor(1.7297, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7301, grad_fn=<DotBackward0>)
# tensor(1.7307, grad_fn=<DotBackward0>)
# tensor(1.7306, grad_fn=<DotBackward0>)
# tensor(1.7315, grad_fn=<DotBackward0>)
# tensor(1.7313, grad_fn=<DotBackward0>)
# tensor(1.7325, grad_fn=<DotBackward0>)
# tensor(1.7322, grad_fn=<DotBackward0>)
# tensor(1.7337, grad_fn=<DotBackward0>)
# tensor(1.7333, grad_fn=<DotBackward0>)
# tensor(1.7350, grad_fn=<DotBackward0>)
# tensor(1.7344, grad_fn=<DotBackward0>)
# tensor(1.7358, grad_fn=<DotBackward0>)
# tensor(1.7347, grad_fn=<DotBackward0>)
# tensor(1.7357, grad_fn=<DotBackward0>)
# tensor(1.7343, grad_fn=<DotBackward0>)
# tensor(1.7351, grad_fn=<DotBackward0>)
# tensor(1.7337, grad_fn=<DotBackward0>)
# tensor(1.7347, grad_fn=<DotBackward0>)
# tensor(1.7337, grad_fn=<DotBackward0>)
# tensor(1.7351, grad_fn=<DotBackward0>)
# tensor(1.7345, grad_fn=<DotBackward0>)
# tensor(1.7366, grad_fn=<DotBackward0>)
# tensor(1.7363, grad_fn=<DotBackward0>)
# tensor(1.7394, grad_fn=<DotBackward0>)
# tensor(1.7394, grad_fn=<DotBackward0>)
# tensor(1.7428, grad_fn=<DotBackward0>)
# tensor(1.7426, grad_fn=<DotBackward0>)
# tensor(1.7463, grad_fn=<DotBackward0>)
# tensor(1.7459, grad_fn=<DotBackward0>)
# tensor(1.7514, grad_fn=<DotBackward0>)
# tensor(1.7521, grad_fn=<DotBackward0>)
# tensor(1.7582, grad_fn=<DotBackward0>)
# tensor(1.7587, grad_fn=<DotBackward0>)
# tensor(1.7654, grad_fn=<DotBackward0>)
# tensor(1.7657, grad_fn=<DotBackward0>)
# tensor(1.7759, grad_fn=<DotBackward0>)
# tensor(1.7784, grad_fn=<DotBackward0>)
# tensor(1.7885, grad_fn=<DotBackward0>)
# tensor(1.7893, grad_fn=<DotBackward0>)
# tensor(1.7977, grad_fn=<DotBackward0>)
# tensor(1.7953, grad_fn=<DotBackward0>)
# tensor(1.8000, grad_fn=<DotBackward0>)
# tensor(1.7930, grad_fn=<DotBackward0>)
# tensor(1.7974, grad_fn=<DotBackward0>)
# tensor(1.7896, grad_fn=<DotBackward0>)
# tensor(1.7878, grad_fn=<DotBackward0>)
# tensor(1.7756, grad_fn=<DotBackward0>)
# tensor(1.7696, grad_fn=<DotBackward0>)
# tensor(1.7571, grad_fn=<DotBackward0>)
# tensor(1.7510, grad_fn=<DotBackward0>)
# tensor(1.7421, grad_fn=<DotBackward0>)
# tensor(1.7385, grad_fn=<DotBackward0>)
# tensor(1.7349, grad_fn=<DotBackward0>)
# tensor(1.7341, grad_fn=<DotBackward0>)
# tensor(1.7348, grad_fn=<DotBackward0>)
# tensor(1.7354, grad_fn=<DotBackward0>)
# tensor(1.7383, grad_fn=<DotBackward0>)
# tensor(1.7389, grad_fn=<DotBackward0>)
# tensor(1.7423, grad_fn=<DotBackward0>)
# tensor(1.7421, grad_fn=<DotBackward0>)
# tensor(1.7467, grad_fn=<DotBackward0>)
# tensor(1.7471, grad_fn=<DotBackward0>)
# tensor(1.7537, grad_fn=<DotBackward0>)
# tensor(1.7553, grad_fn=<DotBackward0>)
# tensor(1.7648, grad_fn=<DotBackward0>)
# tensor(1.7674, grad_fn=<DotBackward0>)
# tensor(1.7792, grad_fn=<DotBackward0>)
# tensor(1.7815, grad_fn=<DotBackward0>)
# tensor(1.7900, grad_fn=<DotBackward0>)
# tensor(1.7871, grad_fn=<DotBackward0>)
# tensor(1.7903, grad_fn=<DotBackward0>)
# tensor(1.7818, grad_fn=<DotBackward0>)
# tensor(1.7794, grad_fn=<DotBackward0>)
# tensor(1.7675, grad_fn=<DotBackward0>)
# tensor(1.7619, grad_fn=<DotBackward0>)
# tensor(1.7506, grad_fn=<DotBackward0>)
# tensor(1.7455, grad_fn=<DotBackward0>)
# tensor(1.7384, grad_fn=<DotBackward0>)
# tensor(1.7359, grad_fn=<DotBackward0>)
# tensor(1.7339, grad_fn=<DotBackward0>)
# tensor(1.7339, grad_fn=<DotBackward0>)
# tensor(1.7357, grad_fn=<DotBackward0>)
# tensor(1.7367, grad_fn=<DotBackward0>)
# tensor(1.7400, grad_fn=<DotBackward0>)
# tensor(1.7405, grad_fn=<DotBackward0>)
# tensor(1.7437, grad_fn=<DotBackward0>)
# tensor(1.7430, grad_fn=<DotBackward0>)
# reduced chi^2 level 2 = 1.7429744005203247
# Constrained alpha: 1.0
# Constrained beta: 1.0
# Constrained gamma: 10.0
# counter = 0

# %%
closure_fit = Postfit()
# neutrino_pdfs, N_event_pred = closure_fit.apply_postfit_criteria(chi_squares,N_event_pred,neutrino_pdfs)

# %%
x_vals = x_vals.detach().numpy().flatten()
faser_pdf_mu,x_faser = read_pdf(pdf,x_vals,14) 
faser_pdf_mub,x_faser = read_pdf(pdf,x_vals,-14)
# mean_fnu = np.mean(neutrino_pdfs,axis=0) *x_vals
mean_fnu_mu = np.mean(neutrino_pdfs_mu,axis=0) 
mean_fnu_mub = np.mean(neutrino_pdfs_mub,axis=0) 

mean_pdf_preproc = np.mean(preproc_pdfs,axis=0) 
mean_nn_pdf = np.mean(nn_pdfs,axis=0)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# from lhapdf_grid import write_lhapdf_grid
# mean_fnu = np.mean(neutrino_pdfs, axis=0) * x_vals
# lhapdfpath = '/opt/anaconda3/envs/nnpdf_dev/share/LHAPDF/enu/enu_0000.dat'

# write_lhapdf_grid(x_vals,mean_fnu,lhapdfpath)

# %%
print(mean_fnu_mub.shape)
print(mean_fnu_mu.shape)
# Out:
# ()
# (250,)

# %%
# plt.plot(cont_x,mean_pdf_preproc*mean_nn_pdf*(x_alpha_more_bins.detach().numpy().flatten()),label = 'mult' )
plt.plot(x_vals,mean_fnu_mu,'o',label="fnu mu",markersize=1.5)
plt.plot(x_vals,mean_pdf_preproc,label="fpreproc",markersize=1.5)
plt.plot(x_vals,mean_nn_pdf,label="fnn",markersize=1.5)
# plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.plot(x_faser,faser_pdf_mu,label ='faserv pdf')
plt.xlabel(r"$x_{\nu}$",fontsize = 14)
plt.ylabel(r"$f_{\nu_e}(x_{\nu})$",fontsize = 14)
plt.ylim(10**-3,10**6)
plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()

# %%
# plt.plot(cont_x,mean_pdf_preproc*mean_nn_pdf*(x_alpha_more_bins.detach().numpy().flatten()),label = 'mult' )
# plt.plot(x_vals,mean_fnu_mub,'o',label="fnu mub",markersize=1.5)
# plt.plot(x_vals,mean_pdf_preproc,label="fpreproc",markersize=1.5)
# plt.plot(x_vals,mean_nn_pdf,label="fnn",markersize=1.5)
# plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.plot(x_faser,faser_pdf_mub,label ='faserv pdf')
plt.xlabel(r"$x_{\nu}$",fontsize = 14)
plt.ylabel(r"$f_{\nu_e}(x_{\nu})$",fontsize = 14)
# plt.ylim(10**-3,10**6)
# plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()

# %%
print(xvals_per_obs)
# Out:
# [100, 300, 600, 1000]

# %%
from plot_results import plot
sig_tot = np.sqrt(sig_sys+sig_stat)
xvals_per_obs = [200,450,800,1450]
xvals_per_obs = np.array(xvals_per_obs)
plot(x_vals, neutrino_pdfs_mu, level0, N_event_pred, sig_tot, xvals_per_obs,14)
plot(x_vals, neutrino_pdfs_mu, level0, N_event_pred, sig_tot, xvals_per_obs,-14)
# Out:
# [ 39.317135 349.96054  545.6213   721.8735   721.8735  ]LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# [ 27.309885 361.4327   550.5852   715.4704   715.4704  ]
#
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# [ 39.317135 349.96054  545.6213   721.8735   721.8735  ]
# [ 27.309885 361.4327   550.5852   715.4704   715.4704  ]
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: divide by zero encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:188: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: divide by zero encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:188: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
mean_N_event_fits = np.mean(N_event_pred,axis=0)
sigma_N_event_fits = np.std(N_event_pred,axis=0)

mean_N_event_fit = mean_N_event_fits.flatten()
sigma_N_event_fit = sigma_N_event_fits.flatten()
xvals_per_obs = np.array(xvals_per_obs)
sorted_indices = np.argsort(xvals_per_obs)

# Sort both arrays using the same indices
sorted_xvals_per_obs = xvals_per_obs[sorted_indices]
sorted_mean_N_event_fit = mean_N_event_fit[sorted_indices]
sorted_sigma_N_event_fit = sigma_N_event_fit[sorted_indices]
level0data = level0[0]
sorted_level0 = level0data[sorted_indices]

plt.plot(sorted_xvals_per_obs,sorted_mean_N_event_fit,label="Level 0 closure test")

plt.fill_between(sorted_xvals_per_obs,(sorted_mean_N_event_fit+sorted_sigma_N_event_fit),(sorted_mean_N_event_fit-sorted_sigma_N_event_fit),label=r"1 $\sigma$ error",color = 'red')

# plt.plot(xvals_per_obs[i],events_per_obs[i],'go',markersize=1.5)
plt.plot(sorted_xvals_per_obs,sorted_level0,'bo',markersize=1.5)
# plt.errorbar(xvals_per_obs[i],events_per_obs[i],yerr=np.sqrt(sig_tot),label='POWHEG +PY8 NLO',color = 'green',alpha=0.6 )
# plt.fill_between(xvals_per_obs[i],events_per_obs[i]+np.sqrt(sig_tot), events_per_obs[i]-np.sqrt(sig_tot),color = 'green',alpha=0.6)
plt.xlabel(r"$E_{\nu}$[GeV]",fontsize = 14)
plt.ylabel(r"$N_{int}$",fontsize = 14)
plt.grid()
plt.legend()
# plt.savefig('N_int_fit.pdf')
plt.show()
print(sorted_level0/sorted_mean_N_event_fit)
# Out:
# tensor([1.4397, 0.9683, 0.9910, 1.0089])

# %%
# Quantitative validation of PDF uncertainties in closure tests
# theoretical prediction for # of events
pdf = "faserv"
lowx = -8
n=50
# x_vals = generate_grid(lowx,n)

faser_pdf,x_faser = read_pdf(pdf,x_vals)
postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
print(f'delta chi^2 = {delta_chi}')

phi_chi_squared = postfit_measures.compute_phi(data, chi_squares)
print(f'phi level 2 = {phi_chi_squared}')

dist,xnu  = postfit_measures.compute_distance(neutrino_pdfs,x_vals)
plt.plot(xnu,dist,'o')
plt.ylabel('distance to truth')
plt.xlabel('xnu')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 8
#       5 n=50
#       6 # x_vals = generate_grid(lowx,n)
# ----> 8 faser_pdf,x_faser = read_pdf(pdf,x_vals)
#       9 postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
#      10 delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
#
# TypeError: read_pdf() missing 1 required positional argument: 'particle'

# %%
def compute_accuracy():
    log_spaced = np.logspace(np.log10(1e-5), np.log10(0.1), 10)
    linear_spaced = np.linspace(0.1, 1, 10)
    x_xi_measure = np.concatenate((log_spaced, linear_spaced))
    x_xi_measure= torch.tensor(x_xi_measure, dtype=torch.float32).view(-1,1)

    pdf = "faserv"

    faser_pdf,x_faser = read_pdf(pdf,x_xi_measure)
    faser_pdf =faser_pdf.detach().numpy().squeeze()

    arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level1,REPLICAS=  1)
    mean_neutrino_pdf =model(x_xi_measure).detach().numpy().squeeze()
    
    return mean_neutrino_pdf,faser_pdf,n

# mean_neutrino_pdf,faser_pdf,n = compute_accuracy()
# xi = np.sum(abs(mean_neutrino_pdf-faser_pdf) < error_neutrino_fit)/ n
# print(f'xi = {xi}')

# %%
def compute_bias_to_variance(num_level1_shifts,level0,level1,level2):
    biases = []
    variances = []
    level1 = np.array(level1)
    level0 = np.array(level0)
    diff_level01 = level1 - level0
    level2 -= diff_level01
    level0 = torch.tensor(level0, dtype=torch.float32)
    for i in range(num_level1_shifts):
        
        # generate level2 data with different level 1 shifts
        r_sys = np.random.normal(0, 1) * sig_sys / 10
        r_stat = np.random.normal(0, 1) * np.sqrt(data) / 10
        level2 += r_sys + r_stat
        level2 = torch.tensor(level2, dtype=torch.float32)
        
        arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level2,REPLICAS = 3)
        mean_N_events = np.mean(N_event_pred,axis=0)
        mean_N_events = torch.tensor(mean_N_events, dtype=torch.float32)
        
        mean_chi_square = raw_loss_fct(level0[0],mean_N_events,cov_matrix)
        biases.append(mean_chi_square)

        chi_square_level2 = 0
        for j in range (REPLICAS):
            chi_square_level2 += raw_loss_fct(level2[j],mean_N_events, cov_matrix)
        variances.append(chi_square_level2/REPLICAS)


    exp_bias = np.mean(biases)
    exp_variance = np.mean(variances)
    ratio = exp_bias/exp_variance
    return ratio
    
# ratio = compute_bias_to_variance(1,level0,level1,level2)
# print(f'ratio = {ratio}')


#BIAS:
    # mc reps = level 1 + level 2
    # average over level 1: keep level 2 the same, but add different level 1 shifts
    # compute reduced chi square with respect to level 0 data
    # VARIANCE:
    # mc reps = level 1 + level 2
    # average chi^2 over several level 2 shifts
    # do not average over level 1 shifts since it is expected to be constant
    # Compute reduced chi square with respect to all level 2 replics: so do not have to run a lot more fits it seems
    # however since these multiple level 1 fits have to be run anyway, it is no problemo
