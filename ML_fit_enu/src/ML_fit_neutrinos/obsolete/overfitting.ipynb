# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
# from read_fk_table import get_fk_table
from read_faserv_pdf import read_pdf
# from read_LHEF import read_LHEF_data
from data_errors import compute_errors
from MC_data_reps import generate_MC_replicas
from postfit_criteria import Postfit
from form_loss_fct import complete_loss_fct, raw_loss_fct
from postfit_measures import Measures
from logspace_grid import generate_grid
# from rebin_fk_data import rebin_fk
from read_data_with_fk import read_LHEF_data, get_fk_table

# %%
# Define global variables
num_obs = 1 #between 1 and 4
REPLICAS  = 1

#HYPERPARAMETERS
preproc = 1


fit_level = 2
# lr = 1e-3

max_counter = 100
max_Nepochs = 3500

# %%
data, data_min, data_max, xvals_per_obs, binwidths, xlabels, events_per_obs = (
        read_LHEF_data()
    )
x_alphas, fk_tables = get_fk_table()

# %%
#Get errors
sig_sys,sig_tot, cov_matrix = compute_errors(data,data_min,data_max)    

#Generate MC replicas of data
sig_stat = np.sqrt(data)
level0,level1,level2 = generate_MC_replicas(REPLICAS,data,sig_sys,sig_stat)
# Get faserv pdf
pdf = "faserv"
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
faser_pdf,x_faser = read_pdf(pdf,x_alphas.flatten(),12)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
if fit_level ==0:
    pred = level0
if fit_level ==1:
    pred = level1
if fit_level ==2:
    pred = level2

# %%
faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)
conv = torch.matmul(fk_tables,faser_pdf) * binwidths 
plt.plot(xvals_per_obs,conv)
plt.plot(xvals_per_obs,data)
# Out:
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/1261818935.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   faser_pdf = torch.tensor(faser_pdf, dtype=torch.float32).view(-1,1)

# %%
plt.plot(xvals_per_obs,events_per_obs)
plt.xlabel(xlabels)
plt.ylabel('N')
plt.title("raw data")
plt.show()

plt.plot(
    xvals_per_obs, level2[0], label="level2"
)
plt.plot(
    xvals_per_obs, level1[0], label="level1"
)
plt.plot(xvals_per_obs, events_per_obs,label="level0")
plt.xlabel(xlabels)
plt.legend()
plt.ylabel("N")
plt.title("level 2 data")
plt.show()

# %%
l1 = 20
l2 = 30
l3 = 20

class SimplePerceptron(torch.nn.Module):
    def __init__(self, l1,l2,l3):
        super(SimplePerceptron, self).__init__()
        self.linear = torch.nn.Linear(1,l1)
        self.hidden = torch.nn.Linear(l1,l2)
        self.hidden2 = torch.nn.Linear(l2,l3)
        self.hidden3 = torch.nn.Linear(l3,1)
        self.relu = torch.nn.ReLU()

    def forward(self, y):
        y = self.linear(y)
        y = self.relu(y)
        y = self.hidden(y)
        y = self.relu(y)
        y = self.hidden2(y)
        y = self.relu(y)
        y = self.hidden3(y)
        y = self.relu(y)
        # y = torch.nn.functional.softplus(y)
    
        return y

# %%
import torch.nn as nn


        
if preproc == 1:
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha,beta,gamma):
            super(CustomPreprocessing, self).__init__()

            # self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
            # self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32, requires_grad=True))
            # self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32, requires_grad=True))
            self.register_buffer("alpha", torch.tensor(alpha, dtype=torch.float32))
            self.register_buffer("beta", torch.tensor(beta, dtype=torch.float32))
            self.register_buffer("gamma", torch.tensor(gamma, dtype=torch.float32))


        def forward(self, x):
            # return self.gamma*(1 - x) ** abs(self.beta) * x ** (1-self.alpha)
            # alpha = (0.8*torch.tanh(self.alpha))
            # alpha = (0.8 - 0.2)/2 *torch.tanh(self.alpha) + (0.8+ 0.2)/2
            # beta = (1.9 - 0.1)/2 *torch.tanh(self.alpha) + (1.9 + 0.1)/2
            # beta = abs(self.beta)
            # return self.gamma * (1 - x) ** beta * x**(1-alpha) 
            # alpha = 1 - torch.nn.functional.softplus(self.alpha)
            # beta = torch.nn.functional.softmax(self.beta)
            return  self.gamma*(1 - x) ** self.beta * x**(1-self.alpha) 
            # return  (1 - x) * x 
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha, beta, gamma,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha, beta,gamma)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            f_preproc = self.preprocessing(x)
            f_NN = self.mlp(x)
            f_nu = f_preproc * f_NN
            return f_NN
        
        def neuralnet(self, x):
            f_NN = self.mlp(x)
            return f_NN
        
        def preproc(self, x):
            f_preproc = self.preprocessing(x)
            return f_preproc

# %%
# def raw_loss_fct(pred, data, cov_matrix, point1):
#     lag_mult = 0.1
#     diff = pred - data
#     # loss = (1 / pred.size(0)) * torch.sum(diff**2) + torch.sum(abs(last_point)) * 0.0
#     diffcov = torch.matmul(cov_matrix, diff)
#     # loss = (1 / pred.size(0)) * torch.dot(diff.view(-1), diffcov.view(-1))
#     # print(point1)
#     # print(point2)

#     # print(target.shape)
#     # print(point1.shape)
#     # print(point2.shape)
#     # print(diff[5])
#     # model = model.flatten()
#     # print((model * point2).shape)
#     # print((torch.sum((model * point2) ** 2) * 10).shape)
#     # print(model.shape)
#     # print(point1.shape)
#     # print((model * point2) ** 2)
#     # print(torch.sum((model * point2) ** 2) * 10)
#     loss = (
#         torch.dot(diff.view(-1), diffcov.view(-1))
#     )
#     return loss
#     # if loss < 5:

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss,self).__init__()

    def forward(self,pred,
    data,
    cov_matrix, network_params,x_int1,x_int2
    ):
        loss = raw_loss_fct(pred,
    data,
    cov_matrix, network_params,x_int1,x_int2)
        return loss

# %%
#Define variables for fit
# x_alpha_more_bins = np.logspace(-5,0,250)
# x_alpha_more_bins = torch.tensor(x_alpha_more_bins, dtype=torch.float32).view(-1,1)
# lowx = -8
# n=250
x_vals = generate_grid(lowx,n)
x_vals = torch.tensor(x_vals, dtype=torch.float32).view(-1,1)
# x_vals = x_alphas
neutrino_pdfs,N_event_pred, arc_lenghts, chi_squares, int_penaltys,pos_penaltys, preproc_pdfs, nn_pdfs  = [],[],[],[],[],[],[],[]

# %%
lr = 0.001
def perform_fit(pred,REPLICAS):
    for i in range(REPLICAS):
        losses = []
        if preproc == 1:
            alpha,beta,gamma = 1,1,10
            model = PreprocessedMLP(alpha, beta, gamma,l1, l2, l3)


        criterion = CustomLoss()
        # criterion = torch.nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr,weight_decay=0.1)
        # optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        # optimizer = torch.optim.SGD(model.parameters(), lr=lr,momentum=.9)
        pred[i] = pred[i].squeeze()

        model.train()

        best_loss = 1e13 # initial loss
        counter = 0
        # num_epochs = 200

        # dataset_size = data.shape[0]
        # validation_split = 0  # 20% validation
        # indices = np.arange(dataset_size)
        # np.random.shuffle(indices)  # Shuffle indices randomly
        # val_size = int(dataset_size * validation_split)
        # train_indices, val_indices = indices[val_size:], indices[:val_size]
        # pred_t = pred[i][train_indices]
        # cov_matrix_train = cov_matrix[train_indices][:, train_indices]

        nbatch = 30
        num_epochs = 0
        # for ep in range(num_epochs):
        #     shuffle = np.random.permutation(len(xvals_per_obs))
        while counter < max_counter:  
        #     if num_epochs>max_Nepochs:
        #         break
            
            num_epochs+=1
            
            # last_point = model(x_vals).squeeze()[-1]
            # for j in range(len(xvals_per_obs)//nbatch):
            optimizer.zero_grad()
            y_pred =  model(x_alphas) 
            # print(y_pred[-1])
            y_preds = torch.matmul(fk_tables,y_pred) * binwidths 
            y_preds = y_preds.squeeze()


            # y_shuffle = y_preds[shuffle]
            # pred_shuffle = pred[i][shuffle]
            # cov_matrix_shuffle = cov_matrix[shuffle][:, shuffle]


            # y_batch = y_shuffle[j*nbatch:(j+1)*nbatch]
            # pred_batch = pred_shuffle[j*nbatch:(j+1)*nbatch]

            # cov_matrix_batch = cov_matrix_shuffle[j * nbatch:(j + 1) * nbatch, j * nbatch:(j + 1) * nbatch]
            

            # integrability_points = model(x_vals)[0]
            integrability_points = 0.
            # print(integrability_points)
            x_int1 = torch.tensor([1.], dtype=torch.float32).view(-1,1)
            loss= criterion(y_preds, pred[i],cov_matrix, integrability_points,x_int1,x_int1)
            print(loss)
    
            # losses.append(loss.detach().numpy())
            loss.backward()
            optimizer.step()

            if loss < best_loss:
                best_loss = loss
                counter = 0
            else:
                counter +=1  

        
        # if ep % 100 == 0:
        #     print(loss)
            # cov_matrix_val = cov_matrix[val_indices][:, val_indices]
            # y_val = y_preds[val_indices]
            # pred_val = pred[i][val_indices]
            # loss_val = criterion(y_val, pred_val, cov_matrix_val,network_params)
            # print(f'loss val = {loss_val}')

        # print(loss.detach().numpy())   
        if loss <.00001:
            break
        # if loss < best_loss:
        #     best_loss = loss
        #     counter = 0
        # else:
        #     counter +=1   

        if loss < 600:    
            print(num_epochs) 
        
            print(f"Constrained alpha: {(model.preprocessing.alpha.item())}")
            print(f"Constrained beta: {(model.preprocessing.beta.item())}")
            # print(f"Constrained gamma: {model.preprocessing.gamma.item()}") 


            # closure_fit = Postfit()
            # arc_lenghts.append(closure_fit.compute_arc_length(model))
            # chi_squares.append(loss.detach().numpy())

            f_nu = model(x_vals).detach().numpy().flatten() 

            preproc_pdfs.append(model.preproc(x_vals).detach().numpy().flatten())
            nn_pdfs.append(model.neuralnet(x_vals).detach().numpy().flatten())

            N_event_pred.append(y_preds.detach().numpy())
            plt.rcParams.update(
                {
                    "font.family": "serif",
                    "font.serif": ["cmr10"],  # Computer Modern
                }
            )
            plt.grid(color="grey", linestyle="-", linewidth=0.25)
            plt.plot(xvals_per_obs,y_preds.detach().numpy().flatten(),label = r"$\mathrm{NN}(x_\nu)$")
            plt.plot(xvals_per_obs,pred[i],label = 'Level 2 simulated data')
            plt.xlabel(r"$E_\nu$")
            plt.ylabel(r"$\mathrm{N}_{\mathrm{int}}$")
            plt.legend()
            plt.savefig('no_wd_events.pdf')
            plt.show()
            

            plt.plot(x_vals,f_nu,label='mu')
            plt.xlabel(r"$f_{\nu_\mu}(x_\nu)$")
            plt.ylabel(r"$\mathrm{N}_{\mathrm{int}}$")
            plt.xscale('log')
            plt.yscale('log')
            plt.ylim(10**-3,10**4)
            plt.legend()
            plt.savefig('wd_flux.pdf')
            plt.show()
            

            neutrino_pdfs.append(f_nu)
            plt.yscale('log')
            print(f'counter = {counter}')
            plt.plot(range(1, len(losses) + 1), losses)
            plt.xlabel('#epochs')
            plt.ylabel('loss')
            plt.title('level 0 closure test, no preprocessing')
            plt.show()
            # plt.plot(x_alpha_more_bins,preproc_pdf)
            # plt.xscale('log')
            # plt.yscale('log')
            # plt.show()
    return arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model

# %%
arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(pred,REPLICAS)
# Out:
# tensor(532.8999, grad_fn=<AddBackward0>)
# tensor(532.8348, grad_fn=<AddBackward0>)
# tensor(532.7714, grad_fn=<AddBackward0>)
# tensor(532.7121, grad_fn=<AddBackward0>)
# tensor(532.6570, grad_fn=<AddBackward0>)
# tensor(532.6049, grad_fn=<AddBackward0>)
# tensor(532.5548, grad_fn=<AddBackward0>)
# tensor(532.5080, grad_fn=<AddBackward0>)
# tensor(532.4629, grad_fn=<AddBackward0>)
# tensor(532.4190, grad_fn=<AddBackward0>)
# tensor(532.3761, grad_fn=<AddBackward0>)
# tensor(532.3335, grad_fn=<AddBackward0>)
# tensor(532.2910, grad_fn=<AddBackward0>)
# tensor(532.2485, grad_fn=<AddBackward0>)
# tensor(532.2058, grad_fn=<AddBackward0>)
# tensor(532.1636, grad_fn=<AddBackward0>)
# tensor(532.1221, grad_fn=<AddBackward0>)
# tensor(532.0818, grad_fn=<AddBackward0>)
# tensor(532.0422, grad_fn=<AddBackward0>)
# tensor(532.0032, grad_fn=<AddBackward0>)
# tensor(531.9640, grad_fn=<AddBackward0>)
# tensor(531.9248, grad_fn=<AddBackward0>)
# tensor(531.8856, grad_fn=<AddBackward0>)
# tensor(531.8466, grad_fn=<AddBackward0>)
# tensor(531.8073, grad_fn=<AddBackward0>)
# tensor(531.7679, grad_fn=<AddBackward0>)
# tensor(531.7285, grad_fn=<AddBackward0>)
# tensor(531.6887, grad_fn=<AddBackward0>)
# tensor(531.6486, grad_fn=<AddBackward0>)
# tensor(531.6082, grad_fn=<AddBackward0>)
# tensor(531.5675, grad_fn=<AddBackward0>)
# tensor(531.5264, grad_fn=<AddBackward0>)
# tensor(531.4851, grad_fn=<AddBackward0>)
# tensor(531.4429, grad_fn=<AddBackward0>)
# tensor(531.4003, grad_fn=<AddBackward0>)
# tensor(531.3573, grad_fn=<AddBackward0>)
# tensor(531.3142, grad_fn=<AddBackward0>)
# tensor(525.5163, grad_fn=<AddBackward0>)
# tensor(525.3246, grad_fn=<AddBackward0>)
# tensor(525.1284, grad_fn=<AddBackward0>)
# tensor(524.9273, grad_fn=<AddBackward0>)
# tensor(524.7214, grad_fn=<AddBackward0>)
# tensor(524.5107, grad_fn=<AddBackward0>)
# tensor(524.2950, grad_fn=<AddBackward0>)
# tensor(524.0746, grad_fn=<AddBackward0>)
# tensor(523.8490, grad_fn=<AddBackward0>)
# tensor(523.6187, grad_fn=<AddBackward0>)
# tensor(523.3831, grad_fn=<AddBackward0>)
# tensor(523.1425, grad_fn=<AddBackward0>)
# tensor(522.8969, grad_fn=<AddBackward0>)
# tensor(522.6463, grad_fn=<AddBackward0>)
# tensor(522.3907, grad_fn=<AddBackward0>)
# tensor(522.1302, grad_fn=<AddBackward0>)
# tensor(521.8649, grad_fn=<AddBackward0>)
# tensor(521.5945, grad_fn=<AddBackward0>)
# tensor(521.3193, grad_fn=<AddBackward0>)
# tensor(521.0393, grad_fn=<AddBackward0>)
# tensor(520.7545, grad_fn=<AddBackward0>)
# tensor(520.4650, grad_fn=<AddBackward0>)
# tensor(520.1709, grad_fn=<AddBackward0>)
# tensor(519.8724, grad_fn=<AddBackward0>)
# tensor(519.5693, grad_fn=<AddBackward0>)
# tensor(519.2621, grad_fn=<AddBackward0>)
# tensor(518.9507, grad_fn=<AddBackward0>)
# tensor(518.6351, grad_fn=<AddBackward0>)
# tensor(518.3151, grad_fn=<AddBackward0>)
# tensor(517.9911, grad_fn=<AddBackward0>)
# tensor(517.6628, grad_fn=<AddBackward0>)
# tensor(517.3308, grad_fn=<AddBackward0>)
# tensor(516.9950, grad_fn=<AddBackward0>)
# tensor(516.6555, grad_fn=<AddBackward0>)
# tensor(516.3127, grad_fn=<AddBackward0>)
# tensor(515.9668, grad_fn=<AddBackward0>)
# tensor(515.6181, grad_fn=<AddBackward0>)
# tensor(515.2669, grad_fn=<AddBackward0>)
# tensor(514.9137, grad_fn=<AddBackward0>)
# tensor(514.5589, grad_fn=<AddBackward0>)
# tensor(514.2028, grad_fn=<AddBackward0>)
# tensor(513.8461, grad_fn=<AddBackward0>)
# tensor(513.4890, grad_fn=<AddBackward0>)
# tensor(513.1325, grad_fn=<AddBackward0>)
# tensor(512.7769, grad_fn=<AddBackward0>)
# tensor(512.4228, grad_fn=<AddBackward0>)
# tensor(512.0709, grad_fn=<AddBackward0>)
# tensor(511.7218, grad_fn=<AddBackward0>)
# tensor(511.3762, grad_fn=<AddBackward0>)
# tensor(511.0349, grad_fn=<AddBackward0>)
# tensor(510.6984, grad_fn=<AddBackward0>)
# tensor(510.3677, grad_fn=<AddBackward0>)
# tensor(510.0433, grad_fn=<AddBackward0>)
# tensor(509.7259, grad_fn=<AddBackward0>)
# tensor(509.4164, grad_fn=<AddBackward0>)
# tensor(509.1155, grad_fn=<AddBackward0>)
# tensor(508.8238, grad_fn=<AddBackward0>)
# tensor(508.5420, grad_fn=<AddBackward0>)
# tensor(508.2706, grad_fn=<AddBackward0>)
# tensor(435.1166, grad_fn=<AddBackward0>)
# tensor(434.3174, grad_fn=<AddBackward0>)
# tensor(433.5218, grad_fn=<AddBackward0>)
# tensor(432.7318, grad_fn=<AddBackward0>)
# tensor(431.9447, grad_fn=<AddBackward0>)
# tensor(431.1617, grad_fn=<AddBackward0>)
# tensor(430.3830, grad_fn=<AddBackward0>)
# tensor(429.6085, grad_fn=<AddBackward0>)
# tensor(428.8383, grad_fn=<AddBackward0>)
# tensor(428.0731, grad_fn=<AddBackward0>)
# tensor(427.3134, grad_fn=<AddBackward0>)
# tensor(426.5595, grad_fn=<AddBackward0>)
# tensor(425.8118, grad_fn=<AddBackward0>)
# tensor(425.0707, grad_fn=<AddBackward0>)
# tensor(424.3368, grad_fn=<AddBackward0>)
# tensor(423.6103, grad_fn=<AddBackward0>)
# tensor(422.8917, grad_fn=<AddBackward0>)
# tensor(422.1815, grad_fn=<AddBackward0>)
# tensor(421.4800, grad_fn=<AddBackward0>)
# tensor(420.7875, grad_fn=<AddBackward0>)
# tensor(420.1045, grad_fn=<AddBackward0>)
# tensor(419.4313, grad_fn=<AddBackward0>)
# tensor(418.7682, grad_fn=<AddBackward0>)
# tensor(418.1160, grad_fn=<AddBackward0>)
# tensor(417.4760, grad_fn=<AddBackward0>)
# tensor(416.8475, grad_fn=<AddBackward0>)
# tensor(416.2284, grad_fn=<AddBackward0>)
# tensor(415.6185, grad_fn=<AddBackward0>)
# tensor(415.0197, grad_fn=<AddBackward0>)
# tensor(414.4318, grad_fn=<AddBackward0>)
# tensor(413.8569, grad_fn=<AddBackward0>)
# tensor(413.2927, grad_fn=<AddBackward0>)
# tensor(412.7404, grad_fn=<AddBackward0>)
# tensor(412.1984, grad_fn=<AddBackward0>)
# tensor(411.6674, grad_fn=<AddBackward0>)
# tensor(411.1416, grad_fn=<AddBackward0>)
# tensor(410.6218, grad_fn=<AddBackward0>)
# tensor(410.1126, grad_fn=<AddBackward0>)
# tensor(409.6128, grad_fn=<AddBackward0>)
# tensor(409.1195, grad_fn=<AddBackward0>)
# tensor(408.6342, grad_fn=<AddBackward0>)
# tensor(408.1580, grad_fn=<AddBackward0>)
# tensor(407.6809, grad_fn=<AddBackward0>)
# tensor(407.1880, grad_fn=<AddBackward0>)
# tensor(406.7078, grad_fn=<AddBackward0>)
# tensor(406.2502, grad_fn=<AddBackward0>)
# tensor(405.7905, grad_fn=<AddBackward0>)
# tensor(405.3216, grad_fn=<AddBackward0>)
# tensor(404.8643, grad_fn=<AddBackward0>)
# tensor(404.4239, grad_fn=<AddBackward0>)
# tensor(403.9829, grad_fn=<AddBackward0>)
# tensor(403.5368, grad_fn=<AddBackward0>)
# tensor(403.0994, grad_fn=<AddBackward0>)
# tensor(402.6744, grad_fn=<AddBackward0>)
# tensor(402.2501, grad_fn=<AddBackward0>)
# tensor(401.8230, grad_fn=<AddBackward0>)
# tensor(401.4042, grad_fn=<AddBackward0>)
# tensor(400.9975, grad_fn=<AddBackward0>)
# tensor(400.5937, grad_fn=<AddBackward0>)
# tensor(400.1908, grad_fn=<AddBackward0>)
# tensor(313.3352, grad_fn=<AddBackward0>)
# tensor(313.1899, grad_fn=<AddBackward0>)
# tensor(313.0460, grad_fn=<AddBackward0>)
# tensor(312.8981, grad_fn=<AddBackward0>)
# tensor(312.7516, grad_fn=<AddBackward0>)
# tensor(312.6046, grad_fn=<AddBackward0>)
# tensor(312.4636, grad_fn=<AddBackward0>)
# tensor(312.3267, grad_fn=<AddBackward0>)
# tensor(312.1835, grad_fn=<AddBackward0>)
# tensor(312.0434, grad_fn=<AddBackward0>)
# tensor(311.9078, grad_fn=<AddBackward0>)
# tensor(311.7680, grad_fn=<AddBackward0>)
# tensor(311.6391, grad_fn=<AddBackward0>)
# tensor(311.4995, grad_fn=<AddBackward0>)
# tensor(311.3677, grad_fn=<AddBackward0>)
# tensor(311.2375, grad_fn=<AddBackward0>)
# tensor(311.0971, grad_fn=<AddBackward0>)
# tensor(310.9769, grad_fn=<AddBackward0>)
# tensor(310.8487, grad_fn=<AddBackward0>)
# tensor(310.7078, grad_fn=<AddBackward0>)
# tensor(310.5880, grad_fn=<AddBackward0>)
# tensor(310.4627, grad_fn=<AddBackward0>)
# tensor(310.3260, grad_fn=<AddBackward0>)
# tensor(310.2076, grad_fn=<AddBackward0>)
# tensor(310.0890, grad_fn=<AddBackward0>)
# tensor(309.9561, grad_fn=<AddBackward0>)
# tensor(309.8263, grad_fn=<AddBackward0>)
# tensor(309.7089, grad_fn=<AddBackward0>)
# tensor(309.5813, grad_fn=<AddBackward0>)
# tensor(309.4700, grad_fn=<AddBackward0>)
# tensor(309.3508, grad_fn=<AddBackward0>)
# tensor(309.2194, grad_fn=<AddBackward0>)
# tensor(309.1159, grad_fn=<AddBackward0>)
# tensor(309.0026, grad_fn=<AddBackward0>)
# tensor(308.8765, grad_fn=<AddBackward0>)
# tensor(308.7552, grad_fn=<AddBackward0>)
# tensor(308.6401, grad_fn=<AddBackward0>)
# tensor(308.5238, grad_fn=<AddBackward0>)
# tensor(308.4136, grad_fn=<AddBackward0>)
# tensor(308.2965, grad_fn=<AddBackward0>)
# tensor(308.1906, grad_fn=<AddBackward0>)
# tensor(308.0834, grad_fn=<AddBackward0>)
# tensor(307.9659, grad_fn=<AddBackward0>)
# tensor(307.8540, grad_fn=<AddBackward0>)
# tensor(307.7496, grad_fn=<AddBackward0>)
# tensor(307.6384, grad_fn=<AddBackward0>)
# tensor(307.5283, grad_fn=<AddBackward0>)
# tensor(307.4318, grad_fn=<AddBackward0>)
# tensor(307.3153, grad_fn=<AddBackward0>)
# tensor(307.2171, grad_fn=<AddBackward0>)
# tensor(307.1205, grad_fn=<AddBackward0>)
# tensor(307.0079, grad_fn=<AddBackward0>)
# tensor(306.8956, grad_fn=<AddBackward0>)
# tensor(306.8165, grad_fn=<AddBackward0>)
# tensor(306.7067, grad_fn=<AddBackward0>)
# tensor(306.5934, grad_fn=<AddBackward0>)
# tensor(306.5042, grad_fn=<AddBackward0>)
# tensor(306.4041, grad_fn=<AddBackward0>)
# tensor(306.2958, grad_fn=<AddBackward0>)
# tensor(306.2020, grad_fn=<AddBackward0>)
# tensor(306.1060, grad_fn=<AddBackward0>)
# tensor(306.0026, grad_fn=<AddBackward0>)
# tensor(305.9109, grad_fn=<AddBackward0>)
# tensor(305.8163, grad_fn=<AddBackward0>)
# tensor(305.7174, grad_fn=<AddBackward0>)
# tensor(305.6256, grad_fn=<AddBackward0>)
# tensor(305.5288, grad_fn=<AddBackward0>)
# tensor(305.4363, grad_fn=<AddBackward0>)
# tensor(305.3444, grad_fn=<AddBackward0>)
# tensor(305.2529, grad_fn=<AddBackward0>)
# tensor(305.1661, grad_fn=<AddBackward0>)
# tensor(305.0752, grad_fn=<AddBackward0>)
# tensor(304.9866, grad_fn=<AddBackward0>)
# tensor(304.8959, grad_fn=<AddBackward0>)
# tensor(304.8134, grad_fn=<AddBackward0>)
# tensor(304.7212, grad_fn=<AddBackward0>)
# tensor(304.6354, grad_fn=<AddBackward0>)
# tensor(304.5491, grad_fn=<AddBackward0>)
# tensor(304.4637, grad_fn=<AddBackward0>)
# tensor(304.3797, grad_fn=<AddBackward0>)
# tensor(304.2956, grad_fn=<AddBackward0>)
# tensor(304.2113, grad_fn=<AddBackward0>)
# tensor(304.1318, grad_fn=<AddBackward0>)
# tensor(304.0479, grad_fn=<AddBackward0>)
# tensor(303.9741, grad_fn=<AddBackward0>)
# tensor(303.8936, grad_fn=<AddBackward0>)
# tensor(303.8119, grad_fn=<AddBackward0>)
# tensor(303.7354, grad_fn=<AddBackward0>)
# tensor(303.6599, grad_fn=<AddBackward0>)
# tensor(303.5783, grad_fn=<AddBackward0>)
# tensor(303.5085, grad_fn=<AddBackward0>)
# tensor(303.4296, grad_fn=<AddBackward0>)
# tensor(303.3594, grad_fn=<AddBackward0>)
# tensor(303.2901, grad_fn=<AddBackward0>)
# tensor(303.2019, grad_fn=<AddBackward0>)
# tensor(303.1388, grad_fn=<AddBackward0>)
# tensor(303.0761, grad_fn=<AddBackward0>)
# tensor(302.9994, grad_fn=<AddBackward0>)
# tensor(302.9292, grad_fn=<AddBackward0>)
# tensor(302.8564, grad_fn=<AddBackward0>)
# tensor(302.7880, grad_fn=<AddBackward0>)
# tensor(302.7123, grad_fn=<AddBackward0>)
# tensor(302.6478, grad_fn=<AddBackward0>)
# tensor(302.5785, grad_fn=<AddBackward0>)
# tensor(302.4736, grad_fn=<AddBackward0>)
# tensor(302.3773, grad_fn=<AddBackward0>)
# tensor(302.2938, grad_fn=<AddBackward0>)
# tensor(302.2043, grad_fn=<AddBackward0>)
# tensor(302.0969, grad_fn=<AddBackward0>)
# tensor(301.9871, grad_fn=<AddBackward0>)
# tensor(301.8804, grad_fn=<AddBackward0>)
# tensor(301.7851, grad_fn=<AddBackward0>)
# tensor(301.6827, grad_fn=<AddBackward0>)
# tensor(301.5643, grad_fn=<AddBackward0>)
# tensor(301.4547, grad_fn=<AddBackward0>)
# tensor(301.3577, grad_fn=<AddBackward0>)
# tensor(301.2509, grad_fn=<AddBackward0>)
# tensor(301.1335, grad_fn=<AddBackward0>)
# tensor(301.0245, grad_fn=<AddBackward0>)
# tensor(300.9162, grad_fn=<AddBackward0>)
# tensor(300.8064, grad_fn=<AddBackward0>)
# tensor(300.6752, grad_fn=<AddBackward0>)
# tensor(300.5103, grad_fn=<AddBackward0>)
# tensor(300.2855, grad_fn=<AddBackward0>)
# tensor(300.0695, grad_fn=<AddBackward0>)
# tensor(299.9052, grad_fn=<AddBackward0>)
# tensor(299.7530, grad_fn=<AddBackward0>)
# tensor(299.5637, grad_fn=<AddBackward0>)
# tensor(299.3276, grad_fn=<AddBackward0>)
# tensor(299.0859, grad_fn=<AddBackward0>)
# tensor(298.8510, grad_fn=<AddBackward0>)
# tensor(298.6417, grad_fn=<AddBackward0>)
# tensor(298.4448, grad_fn=<AddBackward0>)
# tensor(298.2220, grad_fn=<AddBackward0>)
# tensor(297.9770, grad_fn=<AddBackward0>)
# tensor(297.7372, grad_fn=<AddBackward0>)
# tensor(297.5417, grad_fn=<AddBackward0>)
# tensor(297.3397, grad_fn=<AddBackward0>)
# tensor(297.1400, grad_fn=<AddBackward0>)
# tensor(296.9459, grad_fn=<AddBackward0>)
# tensor(296.7466, grad_fn=<AddBackward0>)
# tensor(296.5378, grad_fn=<AddBackward0>)
# tensor(296.3289, grad_fn=<AddBackward0>)
# tensor(296.1262, grad_fn=<AddBackward0>)
# tensor(295.9270, grad_fn=<AddBackward0>)
# tensor(295.7304, grad_fn=<AddBackward0>)
# tensor(295.5269, grad_fn=<AddBackward0>)
# tensor(295.3217, grad_fn=<AddBackward0>)
# tensor(295.1162, grad_fn=<AddBackward0>)
# tensor(294.9202, grad_fn=<AddBackward0>)
# tensor(294.7225, grad_fn=<AddBackward0>)
# tensor(294.5208, grad_fn=<AddBackward0>)
# tensor(294.3364, grad_fn=<AddBackward0>)
# tensor(294.1450, grad_fn=<AddBackward0>)
# tensor(293.9548, grad_fn=<AddBackward0>)
# tensor(293.7776, grad_fn=<AddBackward0>)
# tensor(293.5962, grad_fn=<AddBackward0>)
# tensor(293.4263, grad_fn=<AddBackward0>)
# tensor(293.2541, grad_fn=<AddBackward0>)
# tensor(293.0792, grad_fn=<AddBackward0>)
# tensor(292.9020, grad_fn=<AddBackward0>)
# tensor(292.7324, grad_fn=<AddBackward0>)
# tensor(292.5610, grad_fn=<AddBackward0>)
# tensor(292.3868, grad_fn=<AddBackward0>)
# tensor(292.2128, grad_fn=<AddBackward0>)
# tensor(292.0360, grad_fn=<AddBackward0>)
# tensor(291.8614, grad_fn=<AddBackward0>)
# tensor(291.6863, grad_fn=<AddBackward0>)
# tensor(291.5220, grad_fn=<AddBackward0>)
# tensor(291.3464, grad_fn=<AddBackward0>)
# tensor(291.1677, grad_fn=<AddBackward0>)
# tensor(290.9981, grad_fn=<AddBackward0>)
# tensor(290.8245, grad_fn=<AddBackward0>)
# tensor(290.6517, grad_fn=<AddBackward0>)
# tensor(290.4662, grad_fn=<AddBackward0>)
# tensor(290.2927, grad_fn=<AddBackward0>)
# tensor(290.1186, grad_fn=<AddBackward0>)
# tensor(289.9429, grad_fn=<AddBackward0>)
# tensor(289.7783, grad_fn=<AddBackward0>)
# tensor(289.6184, grad_fn=<AddBackward0>)
# tensor(289.4669, grad_fn=<AddBackward0>)
# tensor(289.3149, grad_fn=<AddBackward0>)
# tensor(289.1589, grad_fn=<AddBackward0>)
# tensor(289.0092, grad_fn=<AddBackward0>)
# tensor(288.8575, grad_fn=<AddBackward0>)
# tensor(288.7033, grad_fn=<AddBackward0>)
# tensor(288.5550, grad_fn=<AddBackward0>)
# tensor(288.4045, grad_fn=<AddBackward0>)
# tensor(288.2472, grad_fn=<AddBackward0>)
# tensor(288.0984, grad_fn=<AddBackward0>)
# tensor(287.9500, grad_fn=<AddBackward0>)
# tensor(287.8036, grad_fn=<AddBackward0>)
# tensor(287.6552, grad_fn=<AddBackward0>)
# tensor(287.5039, grad_fn=<AddBackward0>)
# tensor(287.3495, grad_fn=<AddBackward0>)
# tensor(287.1964, grad_fn=<AddBackward0>)
# tensor(287.0440, grad_fn=<AddBackward0>)
# tensor(286.8948, grad_fn=<AddBackward0>)
# tensor(286.7471, grad_fn=<AddBackward0>)
# tensor(286.5970, grad_fn=<AddBackward0>)
# tensor(286.4472, grad_fn=<AddBackward0>)
# tensor(286.2897, grad_fn=<AddBackward0>)
# tensor(286.1460, grad_fn=<AddBackward0>)
# tensor(285.9890, grad_fn=<AddBackward0>)
# tensor(285.8425, grad_fn=<AddBackward0>)
# tensor(285.6851, grad_fn=<AddBackward0>)
# tensor(285.5294, grad_fn=<AddBackward0>)
# tensor(285.3718, grad_fn=<AddBackward0>)
# tensor(285.2189, grad_fn=<AddBackward0>)
# tensor(285.0699, grad_fn=<AddBackward0>)
# tensor(284.9132, grad_fn=<AddBackward0>)
# tensor(284.7474, grad_fn=<AddBackward0>)
# tensor(284.5890, grad_fn=<AddBackward0>)
# tensor(284.3947, grad_fn=<AddBackward0>)
# tensor(284.2228, grad_fn=<AddBackward0>)
# tensor(284.0409, grad_fn=<AddBackward0>)
# tensor(283.8854, grad_fn=<AddBackward0>)
# tensor(283.6768, grad_fn=<AddBackward0>)
# tensor(283.5047, grad_fn=<AddBackward0>)
# tensor(283.3420, grad_fn=<AddBackward0>)
# tensor(283.1642, grad_fn=<AddBackward0>)
# tensor(282.9740, grad_fn=<AddBackward0>)
# tensor(282.7917, grad_fn=<AddBackward0>)
# tensor(282.6146, grad_fn=<AddBackward0>)
# tensor(282.4340, grad_fn=<AddBackward0>)
# tensor(282.2546, grad_fn=<AddBackward0>)
# tensor(282.0563, grad_fn=<AddBackward0>)
# tensor(281.8661, grad_fn=<AddBackward0>)
# tensor(281.6807, grad_fn=<AddBackward0>)
# tensor(281.4871, grad_fn=<AddBackward0>)
# tensor(281.3198, grad_fn=<AddBackward0>)
# tensor(281.1489, grad_fn=<AddBackward0>)
# tensor(280.9737, grad_fn=<AddBackward0>)
# tensor(280.8531, grad_fn=<AddBackward0>)
# tensor(280.6784, grad_fn=<AddBackward0>)
# tensor(280.5377, grad_fn=<AddBackward0>)
# tensor(280.4019, grad_fn=<AddBackward0>)
# tensor(280.2660, grad_fn=<AddBackward0>)
# tensor(280.1277, grad_fn=<AddBackward0>)
# tensor(279.9836, grad_fn=<AddBackward0>)
# tensor(259.4701, grad_fn=<AddBackward0>)
# tensor(259.2561, grad_fn=<AddBackward0>)
# tensor(259.1146, grad_fn=<AddBackward0>)
# tensor(258.9496, grad_fn=<AddBackward0>)
# tensor(258.7731, grad_fn=<AddBackward0>)
# tensor(258.6186, grad_fn=<AddBackward0>)
# tensor(258.4561, grad_fn=<AddBackward0>)
# tensor(258.2861, grad_fn=<AddBackward0>)
# tensor(258.1580, grad_fn=<AddBackward0>)
# tensor(257.9748, grad_fn=<AddBackward0>)
# tensor(257.8285, grad_fn=<AddBackward0>)
# tensor(257.6606, grad_fn=<AddBackward0>)
# tensor(257.5034, grad_fn=<AddBackward0>)
# tensor(257.3658, grad_fn=<AddBackward0>)
# tensor(257.1907, grad_fn=<AddBackward0>)
# tensor(257.0320, grad_fn=<AddBackward0>)
# tensor(256.8964, grad_fn=<AddBackward0>)
# tensor(256.7239, grad_fn=<AddBackward0>)
# tensor(256.5954, grad_fn=<AddBackward0>)
# tensor(256.4312, grad_fn=<AddBackward0>)
# tensor(256.2720, grad_fn=<AddBackward0>)
# tensor(256.1497, grad_fn=<AddBackward0>)
# tensor(255.9892, grad_fn=<AddBackward0>)
# tensor(255.8659, grad_fn=<AddBackward0>)
# tensor(255.7306, grad_fn=<AddBackward0>)
# tensor(255.5675, grad_fn=<AddBackward0>)
# tensor(255.4265, grad_fn=<AddBackward0>)
# tensor(255.3121, grad_fn=<AddBackward0>)
# tensor(255.1424, grad_fn=<AddBackward0>)
# tensor(255.0258, grad_fn=<AddBackward0>)
# tensor(254.8757, grad_fn=<AddBackward0>)
# tensor(254.7184, grad_fn=<AddBackward0>)
# tensor(254.6111, grad_fn=<AddBackward0>)
# tensor(254.4390, grad_fn=<AddBackward0>)
# tensor(254.3129, grad_fn=<AddBackward0>)
# tensor(254.1788, grad_fn=<AddBackward0>)
# tensor(254.0243, grad_fn=<AddBackward0>)
# tensor(253.9040, grad_fn=<AddBackward0>)
# tensor(253.7538, grad_fn=<AddBackward0>)
# tensor(253.6288, grad_fn=<AddBackward0>)
# tensor(253.4898, grad_fn=<AddBackward0>)
# tensor(253.3501, grad_fn=<AddBackward0>)
# tensor(253.2223, grad_fn=<AddBackward0>)
# tensor(253.0940, grad_fn=<AddBackward0>)
# tensor(252.9636, grad_fn=<AddBackward0>)
# tensor(252.8436, grad_fn=<AddBackward0>)
# tensor(252.7029, grad_fn=<AddBackward0>)
# tensor(252.5632, grad_fn=<AddBackward0>)
# tensor(252.4407, grad_fn=<AddBackward0>)
# tensor(252.3034, grad_fn=<AddBackward0>)
# tensor(252.1853, grad_fn=<AddBackward0>)
# tensor(252.0427, grad_fn=<AddBackward0>)
# tensor(251.9228, grad_fn=<AddBackward0>)
# tensor(251.7996, grad_fn=<AddBackward0>)
# tensor(251.6639, grad_fn=<AddBackward0>)
# ...
# tensor(211.3087, grad_fn=<AddBackward0>)
# tensor(211.3089, grad_fn=<AddBackward0>)
# tensor(211.3091, grad_fn=<AddBackward0>)
# tensor(211.3092, grad_fn=<AddBackward0>)
# tensor(211.3113, grad_fn=<AddBackward0>)
# tensor(211.3109, grad_fn=<AddBackward0>)
# tensor(211.3111, grad_fn=<AddBackward0>)
# tensor(211.3109, grad_fn=<AddBackward0>)
# tensor(211.3110, grad_fn=<AddBackward0>)
# tensor(211.3106, grad_fn=<AddBackward0>)
# tensor(211.3107, grad_fn=<AddBackward0>)
# tensor(211.3113, grad_fn=<AddBackward0>)
# tensor(211.3115, grad_fn=<AddBackward0>)
# tensor(211.3113, grad_fn=<AddBackward0>)
# tensor(211.3114, grad_fn=<AddBackward0>)
# tensor(211.3114, grad_fn=<AddBackward0>)
# tensor(211.3116, grad_fn=<AddBackward0>)
# tensor(211.3126, grad_fn=<AddBackward0>)
# tensor(211.3145, grad_fn=<AddBackward0>)
# tensor(211.3106, grad_fn=<AddBackward0>)
# tensor(211.3108, grad_fn=<AddBackward0>)
# tensor(211.3098, grad_fn=<AddBackward0>)
# tensor(211.3091, grad_fn=<AddBackward0>)
# tensor(211.3107, grad_fn=<AddBackward0>)
# tensor(211.3088, grad_fn=<AddBackward0>)
# tensor(211.3088, grad_fn=<AddBackward0>)
# tensor(211.3073, grad_fn=<AddBackward0>)
# tensor(211.3074, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3076, grad_fn=<AddBackward0>)
# tensor(211.3081, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3086, grad_fn=<AddBackward0>)
# tensor(211.3081, grad_fn=<AddBackward0>)
# tensor(211.3087, grad_fn=<AddBackward0>)
# tensor(211.3085, grad_fn=<AddBackward0>)
# tensor(211.3082, grad_fn=<AddBackward0>)
# tensor(211.3082, grad_fn=<AddBackward0>)
# tensor(211.3082, grad_fn=<AddBackward0>)
# tensor(211.3089, grad_fn=<AddBackward0>)
# tensor(211.3092, grad_fn=<AddBackward0>)
# tensor(211.3101, grad_fn=<AddBackward0>)
# tensor(211.3106, grad_fn=<AddBackward0>)
# tensor(211.3094, grad_fn=<AddBackward0>)
# tensor(211.3101, grad_fn=<AddBackward0>)
# tensor(211.3095, grad_fn=<AddBackward0>)
# tensor(211.3096, grad_fn=<AddBackward0>)
# tensor(211.3104, grad_fn=<AddBackward0>)
# tensor(211.3093, grad_fn=<AddBackward0>)
# tensor(211.3103, grad_fn=<AddBackward0>)
# tensor(211.3093, grad_fn=<AddBackward0>)
# tensor(211.3097, grad_fn=<AddBackward0>)
# tensor(211.3096, grad_fn=<AddBackward0>)
# tensor(211.3093, grad_fn=<AddBackward0>)
# tensor(211.3101, grad_fn=<AddBackward0>)
# tensor(211.3100, grad_fn=<AddBackward0>)
# tensor(211.3107, grad_fn=<AddBackward0>)
# tensor(211.3106, grad_fn=<AddBackward0>)
# tensor(211.3112, grad_fn=<AddBackward0>)
# tensor(211.3115, grad_fn=<AddBackward0>)
# tensor(211.3114, grad_fn=<AddBackward0>)
# tensor(211.3120, grad_fn=<AddBackward0>)
# tensor(211.3128, grad_fn=<AddBackward0>)
# tensor(211.3097, grad_fn=<AddBackward0>)
# tensor(211.3114, grad_fn=<AddBackward0>)
# tensor(211.3094, grad_fn=<AddBackward0>)
# tensor(211.3094, grad_fn=<AddBackward0>)
# tensor(211.3107, grad_fn=<AddBackward0>)
# tensor(211.3091, grad_fn=<AddBackward0>)
# tensor(211.3095, grad_fn=<AddBackward0>)
# tensor(211.3070, grad_fn=<AddBackward0>)
# tensor(211.3075, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.
grad_fn=<AddBackward0>)
# tensor(211.3083, grad_fn=<AddBackward0>)
# tensor(211.3079, grad_fn=<AddBackward0>)
# tensor(211.3071, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3063, grad_fn=<AddBackward0>)
# tensor(211.3051, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3049, grad_fn=<AddBackward0>)
# tensor(211.3046, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3052, grad_fn=<AddBackward0>)
# tensor(211.3059, grad_fn=<AddBackward0>)
# tensor(211.3061, grad_fn=<AddBackward0>)
# tensor(211.3062, grad_fn=<AddBackward0>)
# tensor(211.3059, grad_fn=<AddBackward0>)
# tensor(211.3058, grad_fn=<AddBackward0>)
# tensor(211.3059, grad_fn=<AddBackward0>)
# tensor(211.3059, grad_fn=<AddBackward0>)
# tensor(211.3058, grad_fn=<AddBackward0>)
# tensor(211.3059, grad_fn=<AddBackward0>)
# tensor(211.3065, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3069, grad_fn=<AddBackward0>)
# tensor(211.3066, grad_fn=<AddBackward0>)
# tensor(211.3074, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3065, grad_fn=<AddBackward0>)
# tensor(211.3064, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3064, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3070, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3083, grad_fn=<AddBackward0>)
# tensor(211.3083, grad_fn=<AddBackward0>)
# tensor(211.3090, grad_fn=<AddBackward0>)
# tensor(211.3097, grad_fn=<AddBackward0>)
# tensor(211.3108, grad_fn=<AddBackward0>)
# tensor(211.3081, grad_fn=<AddBackward0>)
# tensor(211.3085, grad_fn=<AddBackward0>)
# tensor(211.3071, grad_fn=<AddBackward0>)
# tensor(211.3075, grad_fn=<AddBackward0>)
# tensor(211.3087, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3073, grad_fn=<AddBackward0>)
# tensor(211.3047, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3045, grad_fn=<AddBackward0>)
# tensor(211.3048, grad_fn=<AddBackward0>)
# tensor(211.3042, grad_fn=<AddBackward0>)
# tensor(211.3054, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3055, grad_fn=<AddBackward0>)
# tensor(211.3056, grad_fn=<AddBackward0>)
# tensor(211.3053, grad_fn=<AddBackward0>)
# tensor(211.3060, grad_fn=<AddBackward0>)
# tensor(211.3061, grad_fn=<AddBackward0>)
# tensor(211.3064, grad_fn=<AddBackward0>)
# tensor(211.3075, grad_fn=<AddBackward0>)
# tensor(211.3064, grad_fn=<AddBackward0>)
# tensor(211.3060, grad_fn=<AddBackward0>)
# tensor(211.3057, grad_fn=<AddBackward0>)
# tensor(211.3051, grad_fn=<AddBackward0>)
# tensor(211.3053, grad_fn=<AddBackward0>)
# tensor(211.3056, grad_fn=<AddBackward0>)
# tensor(211.3058, grad_fn=<AddBackward0>)
# tensor(211.3053, grad_fn=<AddBackward0>)
# tensor(211.3057, grad_fn=<AddBackward0>)
# tensor(211.3056, grad_fn=<AddBackward0>)
# tensor(211.3061, grad_fn=<AddBackward0>)
# tensor(211.3065, grad_fn=<AddBackward0>)
# tensor(211.3066, grad_fn=<AddBackward0>)
# tensor(211.3070, grad_fn=<AddBackward0>)
# tensor(211.3072, grad_fn=<AddBackward0>)
# tensor(211.3081, grad_fn=<AddBackward0>)
# tensor(211.3085, grad_fn=<AddBackward0>)
# tensor(211.3100, grad_fn=<AddBackward0>)
# tensor(211.3080, grad_fn=<AddBackward0>)
# tensor(211.3085, grad_fn=<AddBackward0>)
# tensor(211.3080, grad_fn=<AddBackward0>)
# tensor(211.3072, grad_fn=<AddBackward0>)
# tensor(211.3085, grad_fn=<AddBackward0>)
# tensor(211.3280, grad_fn=<AddBackward0>)
# tensor(211.3109, grad_fn=<AddBackward0>)
# tensor(211.3185, grad_fn=<AddBackward0>)
# tensor(211.3156, grad_fn=<AddBackward0>)
# tensor(211.3092, grad_fn=<AddBackward0>)
# tensor(211.3124, grad_fn=<AddBackward0>)
# tensor(211.3082, grad_fn=<AddBackward0>)
# tensor(211.3133, grad_fn=<AddBackward0>)
# tensor(211.3114, grad_fn=<AddBackward0>)
# tensor(211.3145, grad_fn=<AddBackward0>)
# tensor(211.3112, grad_fn=<AddBackward0>)
# tensor(211.3155, grad_fn=<AddBackward0>)
# tensor(211.3132, grad_fn=<AddBackward0>)
# tensor(211.3141, grad_fn=<AddBackward0>)
# tensor(211.3133, grad_fn=<AddBackward0>)
# tensor(211.3106, grad_fn=<AddBackward0>)
# tensor(211.3099, grad_fn=<AddBackward0>)
# tensor(211.3092, grad_fn=<AddBackward0>)
# tensor(211.3105, grad_fn=<AddBackward0>)
# tensor(211.3089, grad_fn=<AddBackward0>)
# tensor(211.3094, grad_fn=<AddBackward0>)
# tensor(211.3103, grad_fn=<AddBackward0>)
# tensor(211.3103, grad_fn=<AddBackward0>)
# tensor(211.3120, grad_fn=<AddBackward0>)
# tensor(211.3121, grad_fn=<AddBackward0>)
# tensor(211.3074, grad_fn=<AddBackward0>)
# tensor(211.3095, grad_fn=<AddBackward0>)
# tensor(211.3065, grad_fn=<AddBackward0>)
# tensor(211.3073, grad_fn=<AddBackward0>)
# tensor(211.3066, grad_fn=<AddBackward0>)
# tensor(211.3063, grad_fn=<AddBackward0>)
# tensor(211.3074, grad_fn=<AddBackward0>)
# tensor(211.3053, grad_fn=<AddBackward0>)
# tensor(211.3062, grad_fn=<AddBackward0>)
# tensor(211.3048, grad_fn=<AddBackward0>)
# tensor(211.3049, grad_fn=<AddBackward0>)
# tensor(211.3047, grad_fn=<AddBackward0>)
# tensor(211.3051, grad_fn=<AddBackward0>)
# tensor(211.3063, grad_fn=<AddBackward0>)
# tensor(211.3069, grad_fn=<AddBackward0>)
# tensor(211.3073, grad_fn=<AddBackward0>)
# tensor(211.3068, grad_fn=<AddBackward0>)
# tensor(211.3077, grad_fn=<AddBackward0>)
# tensor(211.3073, grad_fn=<AddBackward0>)
# tensor(211.3075, grad_fn=<AddBackward0>)
# tensor(211.3069, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3069, grad_fn=<AddBackward0>)
# tensor(211.3069, grad_fn=<AddBackward0>)
# tensor(211.3075, grad_fn=<AddBackward0>)
# tensor(211.3072, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3064, grad_fn=<AddBackward0>)
# tensor(211.3063, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3067, grad_fn=<AddBackward0>)
# tensor(211.3061, grad_fn=<AddBackward0>)
# tensor(211.3058, grad_fn=<AddBackward0>)
# tensor(211.3054, grad_fn=<AddBackward0>)
# tensor(211.3052, grad_fn=<AddBackward0>)
# tensor(211.3048, grad_fn=<AddBackward0>)
# tensor(211.3050, grad_fn=<AddBackward0>)
# tensor(211.3051, grad_fn=<AddBackward0>)
# tensor(211.3055, grad_fn=<AddBackward0>)
# tensor(211.3060, grad_fn=<AddBackward0>)
# tensor(211.3065, grad_fn=<AddBackward0>)
# 10970
# Constrained alpha: 1.0
# Constrained beta: 1.0
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/2195929899.py:121: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.grid(color="grey", linestyle="-", linewidth=0.25)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/2195929899.py:131: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(x_vals,f_nu,label='mu')
# counter = 100
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/2195929899.py:143: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.yscale('log')
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) cmr10.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
closure_fit = Postfit()
neutrino_pdfs, N_event_pred = closure_fit.apply_postfit_criteria(chi_squares,N_event_pred,neutrino_pdfs)
# Out:
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/envs/ML_fit/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
# x_vals = x_vals.detach().numpy().flatten()
x_vals = x_vals.detach().numpy().flatten()
faser_pdf,x_faser = read_pdf(pdf,x_vals,12) 
mean_fnu = np.mean(neutrino_pdfs,axis=0) *x_vals

mean_pdf_preproc = np.mean(preproc_pdfs,axis=0) 
mean_nn_pdf = np.mean(nn_pdfs,axis=0)
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
# from lhapdf_grid import write_lhapdf_grid
# mean_fnu = np.mean(neutrino_pdfs, axis=0) * x_vals
# lhapdfpath = '/opt/anaconda3/envs/nnpdf_dev/share/LHAPDF/enu/enu_0000.dat'

# write_lhapdf_grid(x_vals,mean_fnu,lhapdfpath)

# %%
# plt.plot(cont_x,mean_pdf_preproc*mean_nn_pdf*(x_alpha_more_bins.detach().numpy().flatten()),label = 'mult' )
plt.plot(x_vals,mean_fnu/x_vals,'o',label="fnu",markersize=1.5)
plt.plot(x_vals,mean_pdf_preproc,label="fpreproc",markersize=1.5)
plt.plot(x_vals,mean_nn_pdf,label="fnn",markersize=1.5)
# plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.plot(x_faser,faser_pdf,label ='faserv pdf')
plt.xlabel(r"$x_{\nu}$",fontsize = 14)
plt.ylabel(r"$f_{\nu_e}(x_{\nu})$",fontsize = 14)
plt.ylim(10**-3,10**5)
plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.grid()
plt.legend()
plt.show()
# Out:
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/676687337.py:2: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:35: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   axR = fig.add_subplot(gs[0, 1])
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:36: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   axrL = fig.add_subplot(gs[1, 0])
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:37: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   axrR = fig.add_subplot(gs[1, 1])
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: divide by zero encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:82: RuntimeWarning: invalid value encountered in divide
#   ratio_center = mean_fnu / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:83: RuntimeWarning: invalid value encountered in divide
#   ratio_lower = (mean_fnu - error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:84: RuntimeWarning: invalid value encountered in divide
#   ratio_upper = (mean_fnu + error_fnu) / faser_pdf
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:157: RuntimeWarning: invalid value encountered in divide
#   ratio_center_pred = preds_Enu / simulated_Enu
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:158: RuntimeWarning: invalid value encountered in divide
#   ratio_lower_pred = (preds_Enu - pred_stds_Enu) / simulated_Enu
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:159: RuntimeWarning: invalid value encountered in divide
#   ratio_upper_pred = (preds_Enu + pred_stds_Enu) / simulated_Enu
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:160: RuntimeWarning: divide by zero encountered in divide
#   ratio_upper_sim = (simulated_Enu + errors_enu) / simulated_Enu
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:161: RuntimeWarning: divide by zero encountered in divide
#   ratio_lower_sim = (simulated_Enu + errors_enu) / simulated_Enu
# /Users/jukkajohn/Masterscriptie/faser_nufluxes_ml/ML_fit_enu/src/ML_fit_neutrinos/plot_results.py:188: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
mean_N_event_fits = np.mean(N_event_pred,axis=0)
sigma_N_event_fits = np.std(N_event_pred,axis=0)

mean_N_event_fit = mean_N_event_fits.flatten()
sigma_N_event_fit = sigma_N_event_fits.flatten()
plt.plot(xvals_per_obs,mean_N_event_fit,label="Level 0 closure test")

plt.fill_between(xvals_per_obs,(mean_N_event_fit+sigma_N_event_fit),(mean_N_event_fit-sigma_N_event_fit),label=r"1 $\sigma$ error",color = 'red')

# plt.plot(xvals_per_obs[i],events_per_obs[i],'go',markersize=1.5)
plt.plot(xvals_per_obs,level0[0],'bo',markersize=1.5)
# plt.errorbar(xvals_per_obs[i],events_per_obs[i],yerr=np.sqrt(sig_tot),label='POWHEG +PY8 NLO',color = 'green',alpha=0.6 )
# plt.fill_between(xvals_per_obs[i],events_per_obs[i]+np.sqrt(sig_tot), events_per_obs[i]-np.sqrt(sig_tot),color = 'green',alpha=0.6)
plt.xlabel(r"$E_{\nu}$[GeV]",fontsize = 14)
plt.ylabel(r"$N_{int}$",fontsize = 14)
plt.grid()
plt.legend()
# plt.savefig('N_int_fit.pdf')
plt.show()
# Out:
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_67019/3347743561.py:6: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   plt.plot(xvals_per_obs,mean_N_event_fit,label="Level 0 closure test")

# %%
# Quantitative validation of PDF uncertainties in closure tests
# theoretical prediction for # of events
pdf = "faserv"
lowx = -8
n=50
# x_vals = generate_grid(lowx,n)

faser_pdf,x_faser = read_pdf(pdf,x_vals)
postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
print(f'delta chi^2 = {delta_chi}')

phi_chi_squared = postfit_measures.compute_phi(data, chi_squares)
print(f'phi level 2 = {phi_chi_squared}')

dist,xnu  = postfit_measures.compute_distance(neutrino_pdfs,x_vals)
plt.plot(xnu,dist,'o')
plt.ylabel('distance to truth')
plt.xlabel('xnu')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 n=50
#       6 # x_vals = generate_grid(lowx,n)
# ----> 8 faser_pdf,x_faser = read_pdf(pdf,x_vals)
#       9 postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
#      10 delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, level1[0],x_vals)
#
# TypeError: read_pdf() missing 1 required positional argument: 'particle'

# %%
def compute_accuracy():
    log_spaced = np.logspace(np.log10(1e-5), np.log10(0.1), 10)
    linear_spaced = np.linspace(0.1, 1, 10)
    x_xi_measure = np.concatenate((log_spaced, linear_spaced))
    x_xi_measure= torch.tensor(x_xi_measure, dtype=torch.float32).view(-1,1)

    pdf = "faserv"

    faser_pdf,x_faser = read_pdf(pdf,x_xi_measure)
    faser_pdf =faser_pdf.detach().numpy().squeeze()

    arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level1,REPLICAS=  1)
    mean_neutrino_pdf =model(x_xi_measure).detach().numpy().squeeze()
    
    return mean_neutrino_pdf,faser_pdf,n

# mean_neutrino_pdf,faser_pdf,n = compute_accuracy()
# xi = np.sum(abs(mean_neutrino_pdf-faser_pdf) < error_neutrino_fit)/ n
# print(f'xi = {xi}')

# %%
def compute_bias_to_variance(num_level1_shifts,level0,level1,level2):
    biases = []
    variances = []
    level1 = np.array(level1)
    level0 = np.array(level0)
    diff_level01 = level1 - level0
    level2 -= diff_level01
    level0 = torch.tensor(level0, dtype=torch.float32)
    for i in range(num_level1_shifts):
        
        # generate level2 data with different level 1 shifts
        r_sys = np.random.normal(0, 1) * sig_sys / 10
        r_stat = np.random.normal(0, 1) * np.sqrt(data) / 10
        level2 += r_sys + r_stat
        level2 = torch.tensor(level2, dtype=torch.float32)
        
        arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level2,REPLICAS = 3)
        mean_N_events = np.mean(N_event_pred,axis=0)
        mean_N_events = torch.tensor(mean_N_events, dtype=torch.float32)
        
        mean_chi_square = raw_loss_fct(level0[0],mean_N_events,cov_matrix)
        biases.append(mean_chi_square)

        chi_square_level2 = 0
        for j in range (REPLICAS):
            chi_square_level2 += raw_loss_fct(level2[j],mean_N_events, cov_matrix)
        variances.append(chi_square_level2/REPLICAS)


    exp_bias = np.mean(biases)
    exp_variance = np.mean(variances)
    ratio = exp_bias/exp_variance
    return ratio
    
# ratio = compute_bias_to_variance(1,level0,level1,level2)
# print(f'ratio = {ratio}')


#BIAS:
    # mc reps = level 1 + level 2
    # average over level 1: keep level 2 the same, but add different level 1 shifts
    # compute reduced chi square with respect to level 0 data
    # VARIANCE:
    # mc reps = level 1 + level 2
    # average chi^2 over several level 2 shifts
    # do not average over level 1 shifts since it is expected to be constant
    # Compute reduced chi square with respect to all level 2 replics: so do not have to run a lot more fits it seems
    # however since these multiple level 1 fits have to be run anyway, it is no problemo
