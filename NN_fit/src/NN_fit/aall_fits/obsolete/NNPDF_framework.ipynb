# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from read_fk_table import get_fk_table
from read_faserv_pdf import read_pdf
from ML_fit_enu.src.ML_fit_neutrinos.multiple_obs_fit.read_LHEF import read_LHEF_data
from data_errors import compute_errors
from MC_data_reps import generate_MC_replicas
from postfit_criteria import Postfit
from form_loss_fct import complete_loss_fct, raw_loss_fct
from postfit_measures import Measures
from logspace_grid import generate_grid

# %%
# Define global variables
num_obs = 1 #between 1 and 4
REPLICAS  = 3

#HYPERPARAMETERS

# x_integrability = np.array((1e-6,1e-5,1e-7,1,1.1,1.2))
# x_integrability = np.array((1e-6,1e-5,1e-4,0.7))
x_integrability = np.array((10**-5,10**-4,0.7,0.8))
x_integrability = torch.tensor(x_integrability, dtype=torch.float32).view(-1,1)
integrability = True
positivity = True
preproc = 1
# l1 = 20
# l2 = 40
# l3 = 20
l1 = 4
l2 = 8
l3 = 4

lag_mult_int = 0
lag_mult_pos = 0
fit_level = 0
lr = 0.001
max_counter = 100
max_Nepochs = 4500

# %%
# Read data
data, data_min,data_max ,xvals_per_obs, binwidths,xlabels, events_per_obs =read_LHEF_data(0,num_obs)

#Get errors
sig_sys,sig_tot, cov_matrix = compute_errors(data,data_min,data_max,num_obs)    

#Generate MC replicas of data
level0,level1,level2 = generate_MC_replicas(REPLICAS,num_obs,data,sig_sys)

# Get FK tables
x_alphas, fk_tables,mask = get_fk_table(0,num_obs)

# Get faserv pdf
pdf = "faserv"
lowx = -8
n=250
x_vals = generate_grid(lowx,n)
faser_pdf,x_faser = read_pdf(pdf,x_vals)

print(level1[0])
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# tensor([0.0000, 0.0000, 0.0000, 0.0584, 0.8391, 2.3259, 3.7047, 4.9701, 6.1104,
#         6.7662, 7.2508, 7.5641, 7.4252, 7.4811, 7.4971, 7.5051, 7.1667, 7.2729,
#         7.0401, 7.1085, 6.8975, 6.9343, 6.7908, 6.4252, 6.4705, 6.5737, 6.2988,
#         5.9616, 5.9941, 5.8187, 5.5596, 5.2845, 5.0916, 4.7937, 4.9002, 4.7497,
#         4.4452, 4.3407, 4.2349, 3.8251, 3.8111, 3.5100, 3.2778, 3.3553, 3.1259,
#         2.7512, 2.8987, 2.6370, 2.5760, 2.4358, 2.4231, 2.2971, 2.0617, 2.1291,
#         1.9654, 1.8725, 1.6615, 1.6666, 1.5431, 1.6168, 1.3350, 1.4013, 1.4138,
#         1.2436, 1.1476, 1.1124, 1.0992, 1.0299, 0.9268, 0.8529, 0.8868, 0.7818,
#         0.7297, 0.7696, 0.6123, 0.6279, 0.6321, 0.6396, 0.5942, 0.5489, 0.4912,
#         0.5014, 0.4194, 0.3940, 0.4333, 0.3824, 0.3390, 0.3293, 0.3432, 0.2354,
#         0.2253, 0.2611, 0.2056, 0.1960, 0.2247, 0.1815, 0.1982, 0.1672, 0.1577,
#         0.1248, 0.1483, 0.1178, 0.1412, 0.1202, 0.1063, 0.0925, 0.1017, 0.0880,
#         0.0789, 0.0857, 0.0925, 0.0699, 0.0394, 0.0458, 0.0290, 0.0394, 0.0523,
#         0.0290, 0.0589, 0.0394])

# %%
if fit_level ==0:
    pred = level0
if fit_level ==1:
    pred = level1
if fit_level ==2:
    pred = level2

# %%
for i in range(num_obs):
    plt.plot(xvals_per_obs[i],events_per_obs[i])
    plt.xlabel(xlabels[i])
    plt.ylabel('N')
    plt.title("raw data")
    plt.show()

start = 0
for i in range(num_obs):
    plt.plot(
        xvals_per_obs[i], level2[0][start : len(events_per_obs[i]) + start], label="level2"
    )
    plt.plot(xvals_per_obs[i], events_per_obs[i],label="level0")
    plt.xlabel(xlabels[i])
    plt.legend()
    plt.ylabel("N")
    plt.title("level 2 data")
    plt.show()
    start += len(events_per_obs[i])

# %%
class SimplePerceptron(torch.nn.Module):
    def __init__(self, l1,l2,l3):
        super(SimplePerceptron, self).__init__()
        self.linear = torch.nn.Linear(1,l1)
        self.hidden = torch.nn.Linear(l1,l2)
        self.hidden2 = torch.nn.Linear(l2,l3)
        self.hidden3 = torch.nn.Linear(l3,1)
        self.relu = torch.nn.ReLU()

    def forward(self, y):
        y = self.linear(y)
        y = self.relu(y)
        y = self.hidden(y)
        y = self.relu(y)
        y = self.hidden2(y)
        y = self.relu(y)
        y = self.hidden3(y)
    
        return y

# %%
import torch.nn as nn

if preproc == 0:
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha):
            super(CustomPreprocessing, self).__init__()
            self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
        def forward(self, x):
            return self.alpha*x
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            x = self.preprocessing(x)
            x = self.mlp(x)
            return x
        
if preproc == 1:
    print('if')
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha,beta,gamma):
            super(CustomPreprocessing, self).__init__()
            self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
            self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32, requires_grad=True))
            self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32, requires_grad=True))

        def forward(self, x):
            return self.gamma*(1 - x) ** self.beta * x ** (1 - self.alpha) 
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha, beta, gamma,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha, beta,gamma)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            # x = self.preprocessing(x)
            x = self.mlp(x)
            return x
        
if preproc == 2:
    class CustomPreprocessing(nn.Module):
        def __init__(self, alpha,beta,gamma,a,epsilon):
            super(CustomPreprocessing, self).__init__()
            self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
            self.beta = nn.Parameter(torch.tensor(beta, dtype=torch.float32, requires_grad=True))
            self.gamma = nn.Parameter(torch.tensor(gamma, dtype=torch.float32, requires_grad=True))
            self.a = nn.Parameter(torch.tensor(a, dtype=torch.float32, requires_grad=True))
            self.epsilon = nn.Parameter(torch.tensor(epsilon, dtype=torch.float32, requires_grad=True))

        def forward(self, x):
            return self.a * x**(-self.alpha) * (1-x)**self.beta * (1+self.epsilon*x**0.5 + self.gamma*x)
        
    class PreprocessedMLP(nn.Module):
        def __init__(self, alpha, beta, gamma,a,epsilon,l1, l2, l3):
            super(PreprocessedMLP, self).__init__()
            self.preprocessing = CustomPreprocessing(alpha, beta,gamma,a,epsilon)
            self.mlp = SimplePerceptron(l1, l2, l3)

        def forward(self, x):
            # x = self.preprocessing(x)
            x = self.mlp(x)
            return x
# else:
#     print('else')
#     class CustomPreprocessing(nn.Module):
#         def __init__(self, alpha):
#             super(CustomPreprocessing, self).__init__()
#             self.alpha = nn.Parameter(torch.tensor(alpha, dtype=torch.float32, requires_grad=True))
#         def forward(self, x):
#             return self.alpha*x
        
#     class PreprocessedMLP(nn.Module):
#         def __init__(self, alpha,l1, l2, l3):
#             super(PreprocessedMLP, self).__init__()
#             self.preprocessing = CustomPreprocessing(alpha)
#             self.mlp = SimplePerceptron(l1, l2, l3)

#         def forward(self, x):
#             x = self.preprocessing(x)
#             x = self.mlp(x)
#             return x
# Out:
# if

# %%
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss,self).__init__()

    def forward(self,pred,
    data,
    cov_matrix,
    positivity,
    lag_mult_pos,
    integrability,
    x_integrability,
    y_integrability,):
        loss = complete_loss_fct(pred,
    data,
    cov_matrix,
    positivity,
    lag_mult_pos,
    integrability,
    x_integrability,
    y_integrability,
    lag_mult_int)
        return loss

# %%
#Define variables for fit
x_alpha_more_bins = np.logspace(-8,0,1000)
x_alpha_more_bins = torch.tensor(x_alpha_more_bins, dtype=torch.float32).view(-1,1)
neutrino_pdfs,N_event_pred, arc_lenghts, chi_squares, int_penaltys,pos_penaltys  = [],[],[],[],[],[],

# %%
def perform_fit(pred,REPLICAS):
    for i in range(REPLICAS):

        if preproc == 0:
            alpha = 10
            model = PreprocessedMLP(alpha,l1, l2, l3)

        if preproc == 1:
            alpha,beta,gamma = -2.6,100,1000000
            model = PreprocessedMLP(alpha, beta, gamma,l1, l2, l3)

        if preproc == 2:    
            # alpha,beta,gamma,epsilon, a= -1.5,26,1,2000,2000
            alpha, beta, gamma, epsilon, a = 0.7, 30, 40000, -800, 0.6
            model = PreprocessedMLP(alpha, beta, gamma,a,epsilon,l1, l2, l3)
            
        # else:
        #     alpha = 10
        #     model = PreprocessedMLP(alpha,l1, l2, l3)
            
        # Loss and optimizer
        criterion = CustomLoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)
        pred[i] = pred[i].squeeze()

        model.train()

        best_loss = 1e13 # initial loss
        counter = 0
        num_epochs = 0

        while counter < max_counter:  
            if num_epochs>max_Nepochs:
                break 
            num_epochs+=1
            
            optimizer.zero_grad()

            y_pred =  model(torch.stack(x_alphas))
            y_preds = torch.matmul(fk_tables,y_pred)  * binwidths[:,None,None]
            # y_preds = torch.matmul(fk_tables,y_pred)  
            y_preds = y_preds[mask]
            y_integrability =  model(x_integrability)
            loss,pos_penalty,*_ = criterion(y_preds, pred[i],cov_matrix, positivity,lag_mult_pos, integrability,x_integrability, y_integrability)
            loss.backward()
            optimizer.step()
            print(loss)   

            if pos_penalty < 10**-6:
                if loss < best_loss:
                    best_loss = loss
                    counter = 0
                else:
                    counter +=1    
            else:
                counter +=1

        print(num_epochs) 
    
        loss, pos_penalty, int_penalty = criterion(y_preds, pred[i],cov_matrix, positivity,lag_mult_pos, integrability,x_integrability, y_integrability)
        red_chi_square_level1,*_ = criterion(y_preds, level1[0],cov_matrix, positivity,lag_mult_pos, integrability,x_integrability, y_integrability)

        print(f"reduced chi^2 level 2 = {loss}")
        print(f"reduced chi^2 level 1 = {red_chi_square_level1}")
        print(f"Constrained alpha: {model.preprocessing.alpha.item()}")
        # print(f"Constrained beta: {model.preprocessing.beta.item()}")
        # print(f"Constrained gamma: {model.preprocessing.gamma.item()}") 

        # print('max_alpha,min_alpha,max_beta,min_beta')
        # print(compute_effective_coeff(model))

        # save outcome of fit and its measures for postfit selection criteria
        closure_fit = Postfit()
        arc_lenghts.append(closure_fit.compute_arc_length(model))
        chi_squares.append(loss.detach().numpy())
        pos_penaltys.append(pos_penalty.detach().numpy())
        int_penaltys.append(np.sqrt(int_penalty.detach().numpy()))
        N_event_pred.append(y_preds.detach().numpy())
        cont_pred = model(x_alpha_more_bins).detach().numpy().flatten()
        neutrino_pdfs.append(cont_pred)
    return arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model

# %%
arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(pred,REPLICAS=1)
# Out:
# tensor(2.5483, grad_fn=<AddBackward0>)
# tensor(2.5482, grad_fn=<AddBackward0>)
# tensor(2.5481, grad_fn=<AddBackward0>)
# tensor(2.5480, grad_fn=<AddBackward0>)
# tensor(2.5479, grad_fn=<AddBackward0>)
# tensor(2.5479, grad_fn=<AddBackward0>)
# tensor(2.5478, grad_fn=<AddBackward0>)
# tensor(2.5477, grad_fn=<AddBackward0>)
# tensor(2.5476, grad_fn=<AddBackward0>)
# tensor(2.5475, grad_fn=<AddBackward0>)
# tensor(2.5474, grad_fn=<AddBackward0>)
# tensor(2.5474, grad_fn=<AddBackward0>)
# tensor(2.5473, grad_fn=<AddBackward0>)
# tensor(2.5472, grad_fn=<AddBackward0>)
# tensor(2.5471, grad_fn=<AddBackward0>)
# tensor(2.5470, grad_fn=<AddBackward0>)
# tensor(2.5469, grad_fn=<AddBackward0>)
# tensor(2.5468, grad_fn=<AddBackward0>)
# tensor(2.5468, grad_fn=<AddBackward0>)
# tensor(2.5467, grad_fn=<AddBackward0>)
# tensor(2.5466, grad_fn=<AddBackward0>)
# tensor(2.5465, grad_fn=<AddBackward0>)
# tensor(2.5464, grad_fn=<AddBackward0>)
# tensor(2.5463, grad_fn=<AddBackward0>)
# tensor(2.5463, grad_fn=<AddBackward0>)
# tensor(2.5462, grad_fn=<AddBackward0>)
# tensor(2.5461, grad_fn=<AddBackward0>)
# tensor(2.5460, grad_fn=<AddBackward0>)
# tensor(2.5459, grad_fn=<AddBackward0>)
# tensor(2.5458, grad_fn=<AddBackward0>)
# tensor(2.5458, grad_fn=<AddBackward0>)
# tensor(2.5457, grad_fn=<AddBackward0>)
# tensor(2.5456, grad_fn=<AddBackward0>)
# tensor(2.5455, grad_fn=<AddBackward0>)
# tensor(2.5454, grad_fn=<AddBackward0>)
# tensor(2.5453, grad_fn=<AddBackward0>)
# tensor(2.5452, grad_fn=<AddBackward0>)
# tensor(2.5452, grad_fn=<AddBackward0>)
# tensor(2.5451, grad_fn=<AddBackward0>)
# tensor(2.5450, grad_fn=<AddBackward0>)
# tensor(2.5449, grad_fn=<AddBackward0>)
# tensor(2.5448, grad_fn=<AddBackward0>)
# tensor(2.5447, grad_fn=<AddBackward0>)
# tensor(2.5447, grad_fn=<AddBackward0>)
# tensor(2.5446, grad_fn=<AddBackward0>)
# tensor(2.5445, grad_fn=<AddBackward0>)
# tensor(2.5444, grad_fn=<AddBackward0>)
# tensor(2.5443, grad_fn=<AddBackward0>)
# tensor(2.5442, grad_fn=<AddBackward0>)
# tensor(2.5442, grad_fn=<AddBackward0>)
# tensor(2.5441, grad_fn=<AddBackward0>)
# tensor(2.5440, grad_fn=<AddBackward0>)
# tensor(2.5439, grad_fn=<AddBackward0>)
# tensor(2.5438, grad_fn=<AddBackward0>)
# tensor(2.5437, grad_fn=<AddBackward0>)
# tensor(2.5437, grad_fn=<AddBackward0>)
# tensor(2.5436, grad_fn=<AddBackward0>)
# tensor(2.5435, grad_fn=<AddBackward0>)
# tensor(2.5434, grad_fn=<AddBackward0>)
# tensor(2.5433, grad_fn=<AddBackward0>)
# tensor(2.5432, grad_fn=<AddBackward0>)
# tensor(2.5432, grad_fn=<AddBackward0>)
# tensor(2.5431, grad_fn=<AddBackward0>)
# tensor(2.5430, grad_fn=<AddBackward0>)
# tensor(2.5429, grad_fn=<AddBackward0>)
# tensor(2.5428, grad_fn=<AddBackward0>)
# tensor(2.5427, grad_fn=<AddBackward0>)
# tensor(2.5427, grad_fn=<AddBackward0>)
# tensor(2.5426, grad_fn=<AddBackward0>)
# tensor(2.5425, grad_fn=<AddBackward0>)
# tensor(2.5424, grad_fn=<AddBackward0>)
# tensor(2.5423, grad_fn=<AddBackward0>)
# tensor(2.5422, grad_fn=<AddBackward0>)
# tensor(2.5422, grad_fn=<AddBackward0>)
# tensor(2.5421, grad_fn=<AddBackward0>)
# tensor(2.5420, grad_fn=<AddBackward0>)
# tensor(2.5419, grad_fn=<AddBackward0>)
# tensor(2.5418, grad_fn=<AddBackward0>)
# tensor(2.5417, grad_fn=<AddBackward0>)
# tensor(2.5417, grad_fn=<AddBackward0>)
# tensor(2.5416, grad_fn=<AddBackward0>)
# tensor(2.5415, grad_fn=<AddBackward0>)
# tensor(2.5414, grad_fn=<AddBackward0>)
# tensor(2.5413, grad_fn=<AddBackward0>)
# tensor(2.5413, grad_fn=<AddBackward0>)
# tensor(2.5412, grad_fn=<AddBackward0>)
# tensor(2.5411, grad_fn=<AddBackward0>)
# tensor(2.5410, grad_fn=<AddBackward0>)
# tensor(2.5409, grad_fn=<AddBackward0>)
# tensor(2.5408, grad_fn=<AddBackward0>)
# tensor(2.5408, grad_fn=<AddBackward0>)
# tensor(2.5407, grad_fn=<AddBackward0>)
# tensor(2.5406, grad_fn=<AddBackward0>)
# tensor(2.5405, grad_fn=<AddBackward0>)
# tensor(2.5404, grad_fn=<AddBackward0>)
# tensor(2.5404, grad_fn=<AddBackward0>)
# tensor(2.5403, grad_fn=<AddBackward0>)
# tensor(2.5402, grad_fn=<AddBackward0>)
# tensor(2.5401, grad_fn=<AddBackward0>)
# tensor(2.5400, grad_fn=<AddBackward0>)
# tensor(2.5399, grad_fn=<AddBackward0>)
# tensor(2.5399, grad_fn=<AddBackward0>)
# tensor(2.5398, grad_fn=<AddBackward0>)
# tensor(2.5397, grad_fn=<AddBackward0>)
# tensor(2.5396, grad_fn=<AddBackward0>)
# tensor(2.5395, grad_fn=<AddBackward0>)
# tensor(2.5395, grad_fn=<AddBackward0>)
# tensor(2.5394, grad_fn=<AddBackward0>)
# tensor(2.5393, grad_fn=<AddBackward0>)
# tensor(2.5392, grad_fn=<AddBackward0>)
# tensor(2.5391, grad_fn=<AddBackward0>)
# tensor(2.5390, grad_fn=<AddBackward0>)
# tensor(2.5390, grad_fn=<AddBackward0>)
# tensor(2.5389, grad_fn=<AddBackward0>)
# tensor(2.5388, grad_fn=<AddBackward0>)
# tensor(2.5387, grad_fn=<AddBackward0>)
# tensor(2.5386, grad_fn=<AddBackward0>)
# tensor(2.5386, grad_fn=<AddBackward0>)
# tensor(2.5385, grad_fn=<AddBackward0>)
# tensor(2.5384, grad_fn=<AddBackward0>)
# tensor(2.5383, grad_fn=<AddBackward0>)
# tensor(2.5382, grad_fn=<AddBackward0>)
# tensor(2.5382, grad_fn=<AddBackward0>)
# tensor(2.5381, grad_fn=<AddBackward0>)
# tensor(2.5380, grad_fn=<AddBackward0>)
# tensor(2.5379, grad_fn=<AddBackward0>)
# tensor(2.5378, grad_fn=<AddBackward0>)
# tensor(2.5377, grad_fn=<AddBackward0>)
# tensor(2.5377, grad_fn=<AddBackward0>)
# tensor(2.5376, grad_fn=<AddBackward0>)
# tensor(2.5375, grad_fn=<AddBackward0>)
# tensor(2.5374, grad_fn=<AddBackward0>)
# tensor(2.5373, grad_fn=<AddBackward0>)
# tensor(2.5373, grad_fn=<AddBackward0>)
# tensor(2.5372, grad_fn=<AddBackward0>)
# tensor(2.5371, grad_fn=<AddBackward0>)
# tensor(2.5370, grad_fn=<AddBackward0>)
# tensor(2.5369, grad_fn=<AddBackward0>)
# tensor(2.5369, grad_fn=<AddBackward0>)
# tensor(2.5368, grad_fn=<AddBackward0>)
# tensor(2.5367, grad_fn=<AddBackward0>)
# tensor(2.5366, grad_fn=<AddBackward0>)
# tensor(2.5365, grad_fn=<AddBackward0>)
# tensor(2.5365, grad_fn=<AddBackward0>)
# tensor(2.5364, grad_fn=<AddBackward0>)
# tensor(2.5363, grad_fn=<AddBackward0>)
# tensor(2.5362, grad_fn=<AddBackward0>)
# tensor(2.5361, grad_fn=<AddBackward0>)
# tensor(2.5361, grad_fn=<AddBackward0>)
# tensor(2.5360, grad_fn=<AddBackward0>)
# tensor(2.5359, grad_fn=<AddBackward0>)
# tensor(2.5358, grad_fn=<AddBackward0>)
# tensor(2.5357, grad_fn=<AddBackward0>)
# tensor(2.5357, grad_fn=<AddBackward0>)
# tensor(2.5356, grad_fn=<AddBackward0>)
# tensor(2.5355, grad_fn=<AddBackward0>)
# tensor(2.5354, grad_fn=<AddBackward0>)
# tensor(2.5353, grad_fn=<AddBackward0>)
# tensor(2.5353, grad_fn=<AddBackward0>)
# tensor(2.5352, grad_fn=<AddBackward0>)
# tensor(2.5351, grad_fn=<AddBackward0>)
# tensor(2.5350, grad_fn=<AddBackward0>)
# tensor(2.5349, grad_fn=<AddBackward0>)
# tensor(2.5349, grad_fn=<AddBackward0>)
# tensor(2.5348, grad_fn=<AddBackward0>)
# tensor(2.5347, grad_fn=<AddBackward0>)
# tensor(2.5346, grad_fn=<AddBackward0>)
# tensor(2.5345, grad_fn=<AddBackward0>)
# tensor(2.5345, grad_fn=<AddBackward0>)
# tensor(2.5344, grad_fn=<AddBackward0>)
# tensor(2.5343, grad_fn=<AddBackward0>)
# tensor(2.5342, grad_fn=<AddBackward0>)
# tensor(2.5341, grad_fn=<AddBackward0>)
# tensor(2.5341, grad_fn=<AddBackward0>)
# tensor(2.5340, grad_fn=<AddBackward0>)
# tensor(2.5339, grad_fn=<AddBackward0>)
# tensor(2.5338, grad_fn=<AddBackward0>)
# tensor(2.5337, grad_fn=<AddBackward0>)
# tensor(2.5337, grad_fn=<AddBackward0>)
# tensor(2.5336, grad_fn=<AddBackward0>)
# tensor(2.5335, grad_fn=<AddBackward0>)
# tensor(2.5334, grad_fn=<AddBackward0>)
# tensor(2.5334, grad_fn=<AddBackward0>)
# tensor(2.5333, grad_fn=<AddBackward0>)
# tensor(2.5332, grad_fn=<AddBackward0>)
# tensor(2.5331, grad_fn=<AddBackward0>)
# tensor(2.5330, grad_fn=<AddBackward0>)
# tensor(2.5330, grad_fn=<AddBackward0>)
# tensor(2.5329, grad_fn=<AddBackward0>)
# tensor(2.5328, grad_fn=<AddBackward0>)
# tensor(2.5327, grad_fn=<AddBackward0>)
# tensor(2.5326, grad_fn=<AddBackward0>)
# tensor(2.5326, grad_fn=<AddBackward0>)
# tensor(2.5325, grad_fn=<AddBackward0>)
# tensor(2.5324, grad_fn=<AddBackward0>)
# tensor(2.5323, grad_fn=<AddBackward0>)
# tensor(2.5323, grad_fn=<AddBackward0>)
# tensor(2.5322, grad_fn=<AddBackward0>)
# tensor(2.5321, grad_fn=<AddBackward0>)
# tensor(2.5320, grad_fn=<AddBackward0>)
# tensor(2.5319, grad_fn=<AddBackward0>)
# tensor(2.5319, grad_fn=<AddBackward0>)
# tensor(2.5318, grad_fn=<AddBackward0>)
# tensor(2.5317, grad_fn=<AddBackward0>)
# tensor(2.5316, grad_fn=<AddBackward0>)
# tensor(2.5315, grad_fn=<AddBackward0>)
# tensor(2.5315, grad_fn=<AddBackward0>)
# tensor(2.5314, grad_fn=<AddBackward0>)
# tensor(2.5313, grad_fn=<AddBackward0>)
# tensor(2.5312, grad_fn=<AddBackward0>)
# tensor(2.5312, grad_fn=<AddBackward0>)
# tensor(2.5311, grad_fn=<AddBackward0>)
# tensor(2.5310, grad_fn=<AddBackward0>)
# tensor(2.5309, grad_fn=<AddBackward0>)
# tensor(2.5308, grad_fn=<AddBackward0>)
# tensor(2.5308, grad_fn=<AddBackward0>)
# tensor(2.5307, grad_fn=<AddBackward0>)
# tensor(2.5306, grad_fn=<AddBackward0>)
# tensor(2.5305, grad_fn=<AddBackward0>)
# tensor(2.5305, grad_fn=<AddBackward0>)
# tensor(2.5304, grad_fn=<AddBackward0>)
# tensor(2.5303, grad_fn=<AddBackward0>)
# tensor(2.5302, grad_fn=<AddBackward0>)
# tensor(2.5301, grad_fn=<AddBackward0>)
# tensor(2.5301, grad_fn=<AddBackward0>)
# tensor(2.5300, grad_fn=<AddBackward0>)
# tensor(2.5299, grad_fn=<AddBackward0>)
# tensor(2.5298, grad_fn=<AddBackward0>)
# tensor(2.5298, grad_fn=<AddBackward0>)
# tensor(2.5297, grad_fn=<AddBackward0>)
# tensor(2.5296, grad_fn=<AddBackward0>)
# tensor(2.5295, grad_fn=<AddBackward0>)
# tensor(2.5294, grad_fn=<AddBackward0>)
# tensor(2.5294, grad_fn=<AddBackward0>)
# tensor(2.5293, grad_fn=<AddBackward0>)
# tensor(2.5292, grad_fn=<AddBackward0>)
# tensor(2.5291, grad_fn=<AddBackward0>)
# tensor(2.5291, grad_fn=<AddBackward0>)
# tensor(2.5290, grad_fn=<AddBackward0>)
# tensor(2.5289, grad_fn=<AddBackward0>)
# tensor(2.5288, grad_fn=<AddBackward0>)
# tensor(2.5288, grad_fn=<AddBackward0>)
# tensor(2.5287, grad_fn=<AddBackward0>)
# tensor(2.5286, grad_fn=<AddBackward0>)
# tensor(2.5285, grad_fn=<AddBackward0>)
# tensor(2.5284, grad_fn=<AddBackward0>)
# tensor(2.5284, grad_fn=<AddBackward0>)
# tensor(2.5283, grad_fn=<AddBackward0>)
# tensor(2.5282, grad_fn=<AddBackward0>)
# tensor(2.5281, grad_fn=<AddBackward0>)
# tensor(2.5281, grad_fn=<AddBackward0>)
# tensor(2.5280, grad_fn=<AddBackward0>)
# tensor(2.5279, grad_fn=<AddBackward0>)
# tensor(2.5278, grad_fn=<AddBackward0>)
# tensor(2.5278, grad_fn=<AddBackward0>)
# tensor(2.5277, grad_fn=<AddBackward0>)
# tensor(2.5276, grad_fn=<AddBackward0>)
# tensor(2.5275, grad_fn=<AddBackward0>)
# tensor(2.5275, grad_fn=<AddBackward0>)
# tensor(2.5274, grad_fn=<AddBackward0>)
# tensor(2.5273, grad_fn=<AddBackward0>)
# tensor(2.5272, grad_fn=<AddBackward0>)
# tensor(2.5271, grad_fn=<AddBackward0>)
# tensor(2.5271, grad_fn=<AddBackward0>)
# tensor(2.5270, grad_fn=<AddBackward0>)
# tensor(2.5269, grad_fn=<AddBackward0>)
# tensor(2.5268, grad_fn=<AddBackward0>)
# tensor(2.5268, grad_fn=<AddBackward0>)
# tensor(2.5267, grad_fn=<AddBackward0>)
# tensor(2.5266, grad_fn=<AddBackward0>)
# tensor(2.5265, grad_fn=<AddBackward0>)
# tensor(2.5265, grad_fn=<AddBackward0>)
# tensor(2.5264, grad_fn=<AddBackward0>)
# tensor(2.5263, grad_fn=<AddBackward0>)
# tensor(2.5262, grad_fn=<AddBackward0>)
# tensor(2.5262, grad_fn=<AddBackward0>)
# tensor(2.5261, grad_fn=<AddBackward0>)
# tensor(2.5260, grad_fn=<AddBackward0>)
# tensor(2.5259, grad_fn=<AddBackward0>)
# tensor(2.5259, grad_fn=<AddBackward0>)
# tensor(2.5258, grad_fn=<AddBackward0>)
# tensor(2.5257, grad_fn=<AddBackward0>)
# tensor(2.5256, grad_fn=<AddBackward0>)
# tensor(2.5256, grad_fn=<AddBackward0>)
# tensor(2.5255, grad_fn=<AddBackward0>)
# tensor(2.5254, grad_fn=<AddBackward0>)
# tensor(2.5253, grad_fn=<AddBackward0>)
# tensor(2.5252, grad_fn=<AddBackward0>)
# tensor(2.5252, grad_fn=<AddBackward0>)
# tensor(2.5251, grad_fn=<AddBackward0>)
# tensor(2.5250, grad_fn=<AddBackward0>)
# tensor(2.5249, grad_fn=<AddBackward0>)
# tensor(2.5249, grad_fn=<AddBackward0>)
# tensor(2.5248, grad_fn=<AddBackward0>)
# tensor(2.5247, grad_fn=<AddBackward0>)
# tensor(2.5246, grad_fn=<AddBackward0>)
# tensor(2.5246, grad_fn=<AddBackward0>)
# tensor(2.5245, grad_fn=<AddBackward0>)
# tensor(2.5244, grad_fn=<AddBackward0>)
# tensor(2.5243, grad_fn=<AddBackward0>)
# tensor(2.5243, grad_fn=<AddBackward0>)
# tensor(2.5242, grad_fn=<AddBackward0>)
# tensor(2.5241, grad_fn=<AddBackward0>)
# tensor(2.5240, grad_fn=<AddBackward0>)
# tensor(2.5240, grad_fn=<AddBackward0>)
# tensor(2.5239, grad_fn=<AddBackward0>)
# tensor(2.5238, grad_fn=<AddBackward0>)
# tensor(2.5237, grad_fn=<AddBackward0>)
# tensor(2.5237, grad_fn=<AddBackward0>)
# tensor(2.5236, grad_fn=<AddBackward0>)
# tensor(2.5235, grad_fn=<AddBackward0>)
# tensor(2.5234, grad_fn=<AddBackward0>)
# tensor(2.5234, grad_fn=<AddBackward0>)
# tensor(2.5233, grad_fn=<AddBackward0>)
# tensor(2.5232, grad_fn=<AddBackward0>)
# tensor(2.5231, grad_fn=<AddBackward0>)
# tensor(2.5231, grad_fn=<AddBackward0>)
# tensor(2.5230, grad_fn=<AddBackward0>)
# tensor(2.5229, grad_fn=<AddBackward0>)
# tensor(2.5229, grad_fn=<AddBackward0>)
# tensor(2.5228, grad_fn=<AddBackward0>)
# tensor(2.5227, grad_fn=<AddBackward0>)
# tensor(2.5226, grad_fn=<AddBackward0>)
# tensor(2.5226, grad_fn=<AddBackward0>)
# tensor(2.5225, grad_fn=<AddBackward0>)
# tensor(2.5224, grad_fn=<AddBackward0>)
# tensor(2.5223, grad_fn=<AddBackward0>)
# tensor(2.5223, grad_fn=<AddBackward0>)
# tensor(2.5222, grad_fn=<AddBackward0>)
# tensor(2.5221, grad_fn=<AddBackward0>)
# tensor(2.5220, grad_fn=<AddBackward0>)
# tensor(2.5220, grad_fn=<AddBackward0>)
# tensor(2.5219, grad_fn=<AddBackward0>)
# tensor(2.5218, grad_fn=<AddBackward0>)
# tensor(2.5217, grad_fn=<AddBackward0>)
# tensor(2.5217, grad_fn=<AddBackward0>)
# tensor(2.5216, grad_fn=<AddBackward0>)
# tensor(2.5215, grad_fn=<AddBackward0>)
# tensor(2.5214, grad_fn=<AddBackward0>)
# tensor(2.5214, grad_fn=<AddBackward0>)
# tensor(2.5213, grad_fn=<AddBackward0>)
# tensor(2.5212, grad_fn=<AddBackward0>)
# tensor(2.5211, grad_fn=<AddBackward0>)
# tensor(2.5211, grad_fn=<AddBackward0>)
# tensor(2.5210, grad_fn=<AddBackward0>)
# tensor(2.5209, grad_fn=<AddBackward0>)
# tensor(2.5209, grad_fn=<AddBackward0>)
# tensor(2.5208, grad_fn=<AddBackward0>)
# tensor(2.5207, grad_fn=<AddBackward0>)
# tensor(2.5206, grad_fn=<AddBackward0>)
# tensor(2.5206, grad_fn=<AddBackward0>)
# tensor(2.5205, grad_fn=<AddBackward0>)
# tensor(2.5204, grad_fn=<AddBackward0>)
# tensor(2.5203, grad_fn=<AddBackward0>)
# tensor(2.5203, grad_fn=<AddBackward0>)
# tensor(2.5202, grad_fn=<AddBackward0>)
# tensor(2.5201, grad_fn=<AddBackward0>)
# tensor(2.5200, grad_fn=<AddBackward0>)
# tensor(2.5200, grad_fn=<AddBackward0>)
# tensor(2.5199, grad_fn=<AddBackward0>)
# tensor(2.5198, grad_fn=<AddBackward0>)
# tensor(2.5198, grad_fn=<AddBackward0>)
# tensor(2.5197, grad_fn=<AddBackward0>)
# tensor(2.5196, grad_fn=<AddBackward0>)
# tensor(2.5195, grad_fn=<AddBackward0>)
# tensor(2.5195, grad_fn=<AddBackward0>)
# tensor(2.5194, grad_fn=<AddBackward0>)
# tensor(2.5193, grad_fn=<AddBackward0>)
# tensor(2.5192, grad_fn=<AddBackward0>)
# tensor(2.5192, grad_fn=<AddBackward0>)
# tensor(2.5191, grad_fn=<AddBackward0>)
# tensor(2.5190, grad_fn=<AddBackward0>)
# tensor(2.5190, grad_fn=<AddBackward0>)
# tensor(2.5189, grad_fn=<AddBackward0>)
# tensor(2.5188, grad_fn=<AddBackward0>)
# tensor(2.5187, grad_fn=<AddBackward0>)
# tensor(2.5187, grad_fn=<AddBackward0>)
# tensor(2.5186, grad_fn=<AddBackward0>)
# tensor(2.5185, grad_fn=<AddBackward0>)
# tensor(2.5184, grad_fn=<AddBackward0>)
# tensor(2.5184, grad_fn=<AddBackward0>)
# tensor(2.5183, grad_fn=<AddBackward0>)
# tensor(2.5182, grad_fn=<AddBackward0>)
# tensor(2.5182, grad_fn=<AddBackward0>)
# tensor(2.5181, grad_fn=<AddBackward0>)
# tensor(2.5180, grad_fn=<AddBackward0>)
# tensor(2.5179, grad_fn=<AddBackward0>)
# tensor(2.5179, grad_fn=<AddBackward0>)
# tensor(2.5178, grad_fn=<AddBackward0>)
# tensor(2.5177, grad_fn=<AddBackward0>)
# tensor(2.5176, grad_fn=<AddBackward0>)
# tensor(2.5176, grad_fn=<AddBackward0>)
# tensor(2.5175, grad_fn=<AddBackward0>)
# tensor(2.5174, grad_fn=<AddBackward0>)
# tensor(2.5174, grad_fn=<AddBackward0>)
# tensor(2.5173, grad_fn=<AddBackward0>)
# tensor(2.5172, grad_fn=<AddBackward0>)
# tensor(2.5171, grad_fn=<AddBackward0>)
# tensor(2.5171, grad_fn=<AddBackward0>)
# tensor(2.5170, grad_fn=<AddBackward0>)
# tensor(2.5169, grad_fn=<AddBackward0>)
# tensor(2.5169, grad_fn=<AddBackward0>)
# tensor(2.5168, grad_fn=<AddBackward0>)
# tensor(2.5167, grad_fn=<AddBackward0>)
# tensor(2.5166, grad_fn=<AddBackward0>)
# tensor(2.5166, grad_fn=<AddBackward0>)
# tensor(2.5165, grad_fn=<AddBackward0>)
# tensor(2.5164, grad_fn=<AddBackward0>)
# tensor(2.5164, grad_fn=<AddBackward0>)
# tensor(2.5163, grad_fn=<AddBackward0>)
# tensor(2.5162, grad_fn=<AddBackward0>)
# tensor(2.5161, grad_fn=<AddBackward0>)
# tensor(2.5161, grad_fn=<AddBackward0>)
# tensor(2.5160, grad_fn=<AddBackward0>)
# tensor(2.5159, grad_fn=<AddBackward0>)
# tensor(2.5159, grad_fn=<AddBackward0>)
# tensor(2.5158, grad_fn=<AddBackward0>)
# tensor(2.5157, grad_fn=<AddBackward0>)
# tensor(2.5156, grad_fn=<AddBackward0>)
# tensor(2.5156, grad_fn=<AddBackward0>)
# tensor(2.5155, grad_fn=<AddBackward0>)
# tensor(2.5154, grad_fn=<AddBackward0>)
# tensor(2.5154, grad_fn=<AddBackward0>)
# tensor(2.5153, grad_fn=<AddBackward0>)
# tensor(2.5152, grad_fn=<AddBackward0>)
# tensor(2.5151, grad_fn=<AddBackward0>)
# tensor(2.5151, grad_fn=<AddBackward0>)
# tensor(2.5150, grad_fn=<AddBackward0>)
# tensor(2.5149, grad_fn=<AddBackward0>)
# tensor(2.5149, grad_fn=<AddBackward0>)
# tensor(2.5148, grad_fn=<AddBackward0>)
# tensor(2.5147, grad_fn=<AddBackward0>)
# tensor(2.5146, grad_fn=<AddBackward0>)
# tensor(2.5146, grad_fn=<AddBackward0>)
# tensor(2.5145, grad_fn=<AddBackward0>)
# tensor(2.5144, grad_fn=<AddBackward0>)
# tensor(2.5144, grad_fn=<AddBackward0>)
# tensor(2.5143, grad_fn=<AddBackward0>)
# tensor(2.5142, grad_fn=<AddBackward0>)
# tensor(2.5142, grad_fn=<AddBackward0>)
# tensor(2.5141, grad_fn=<AddBackward0>)
# tensor(2.5140, grad_fn=<AddBackward0>)
# tensor(2.5139, grad_fn=<AddBackward0>)
# tensor(2.5139, grad_fn=<AddBackward0>)
# tensor(2.5138, grad_fn=<AddBackward0>)
# tensor(2.5137, grad_fn=<AddBackward0>)
# tensor(2.5137, grad_fn=<AddBackward0>)
# tensor(2.5136, grad_fn=<AddBackward0>)
# tensor(2.5135, grad_fn=<AddBackward0>)
# tensor(2.5134, grad_fn=<AddBackward0>)
# tensor(2.5134, grad_fn=<AddBackward0>)
# tensor(2.5133, grad_fn=<AddBackward0>)
# tensor(2.5132, grad_fn=<AddBackward0>)
# tensor(2.5132, grad_fn=<AddBackward0>)
# tensor(2.5131, grad_fn=<AddBackward0>)
# tensor(2.5130, grad_fn=<AddBackward0>)
# tensor(2.5130, grad_fn=<AddBackward0>)
# tensor(2.5129, grad_fn=<AddBackward0>)
# tensor(2.5128, grad_fn=<AddBackward0>)
# tensor(2.5127, grad_fn=<AddBackward0>)
# tensor(2.5127, grad_fn=<AddBackward0>)
# tensor(2.5126, grad_fn=<AddBackward0>)
# tensor(2.5125, grad_fn=<AddBackward0>)
# tensor(2.5125, grad_fn=<AddBackward0>)
# tensor(2.5124, grad_fn=<AddBackward0>)
# tensor(2.5123, grad_fn=<AddBackward0>)
# tensor(2.5123, grad_fn=<AddBackward0>)
# tensor(2.5122, grad_fn=<AddBackward0>)
# tensor(2.5121, grad_fn=<AddBackward0>)
# tensor(2.5120, grad_fn=<AddBackward0>)
# tensor(2.5120, grad_fn=<AddBackward0>)
# tensor(2.5119, grad_fn=<AddBackward0>)
# tensor(2.5118, grad_fn=<AddBackward0>)
# tensor(2.5118, grad_fn=<AddBackward0>)
# tensor(2.5117, grad_fn=<AddBackward0>)
# tensor(2.5116, grad_fn=<AddBackward0>)
# tensor(2.5116, grad_fn=<AddBackward0>)
# tensor(2.5115, grad_fn=<AddBackward0>)
# tensor(2.5114, grad_fn=<AddBackward0>)
# tensor(2.5114, grad_fn=<AddBackward0>)
# tensor(2.5113, grad_fn=<AddBackward0>)
# tensor(2.5112, grad_fn=<AddBackward0>)
# tensor(2.5111, grad_fn=<AddBackward0>)
# tensor(2.5111, grad_fn=<AddBackward0>)
# tensor(2.5110, grad_fn=<AddBackward0>)
# tensor(2.5109, grad_fn=<AddBackward0>)
# tensor(2.5109, grad_fn=<AddBackward0>)
# tensor(2.5108, grad_fn=<AddBackward0>)
# tensor(2.5107, grad_fn=<AddBackward0>)
# tensor(2.5107, grad_fn=<AddBackward0>)
# tensor(2.5106, grad_fn=<AddBackward0>)
# tensor(2.5105, grad_fn=<AddBackward0>)
# tensor(2.5105, grad_fn=<AddBackward0>)
# tensor(2.5104, grad_fn=<AddBackward0>)
# tensor(2.5103, grad_fn=<AddBackward0>)
# tensor(2.5102, grad_fn=<AddBackward0>)
# tensor(2.5102, grad_fn=<AddBackward0>)
# tensor(2.5101, grad_fn=<AddBackward0>)
# tensor(2.5100, grad_fn=<AddBackward0>)
# tensor(2.5100, grad_fn=<AddBackward0>)
# tensor(2.5099, grad_fn=<AddBackward0>)
# tensor(2.5098, grad_fn=<AddBackward0>)
# tensor(2.5098, grad_fn=<AddBackward0>)
# tensor(2.5097, grad_fn=<AddBackward0>)
# tensor(2.5096, grad_fn=<AddBackward0>)
# tensor(2.5096, grad_fn=<AddBackward0>)
# tensor(2.5095, grad_fn=<AddBackward0>)
# tensor(2.5094, grad_fn=<AddBackward0>)
# tensor(2.5094, grad_fn=<AddBackward0>)
# tensor(2.5093, grad_fn=<AddBackward0>)
# tensor(2.5092, grad_fn=<AddBackward0>)
# tensor(2.5091, grad_fn=<AddBackward0>)
# tensor(2.5091, grad_fn=<AddBackward0>)
# tensor(2.5090, grad_fn=<AddBackward0>)
# tensor(2.5089, grad_fn=<AddBackward0>)
# tensor(2.5089, grad_fn=<AddBackward0>)
# tensor(2.5088, grad_fn=<AddBackward0>)
# tensor(2.5087, grad_fn=<AddBackward0>)
# tensor(2.5087, grad_fn=<AddBackward0>)
# tensor(2.5086, grad_fn=<AddBackward0>)
# tensor(2.5085, grad_fn=<AddBackward0>)
# tensor(2.5085, grad_fn=<AddBackward0>)
# tensor(2.5084, grad_fn=<AddBackward0>)
# tensor(2.5083, grad_fn=<AddBackward0>)
# tensor(2.5083, grad_fn=<AddBackward0>)
# tensor(2.5082, grad_fn=<AddBackward0>)
# tensor(2.5081, grad_fn=<AddBackward0>)
# tensor(2.5081, grad_fn=<AddBackward0>)
# tensor(2.5080, grad_fn=<AddBackward0>)
# tensor(2.5079, grad_fn=<AddBackward0>)
# tensor(2.5079, grad_fn=<AddBackward0>)
# tensor(2.5078, grad_fn=<AddBackward0>)
# tensor(2.5077, grad_fn=<AddBackward0>)
# tensor(2.5076, grad_fn=<AddBackward0>)
# tensor(2.5076, grad_fn=<AddBackward0>)
# tensor(2.5075, grad_fn=<AddBackward0>)
# tensor(2.5074, grad_fn=<AddBackward0>)
# tensor(2.5074, grad_fn=<AddBackward0>)
# tensor(2.5073, grad_fn=<AddBackward0>)
# tensor(2.5072, grad_fn=<AddBackward0>)
# tensor(2.5072, grad_fn=<AddBackward0>)
# tensor(2.5071, grad_fn=<AddBackward0>)
# tensor(2.5070, grad_fn=<AddBackward0>)
# tensor(2.5070, grad_fn=<AddBackward0>)
# tensor(2.5069, grad_fn=<AddBackward0>)
# tensor(2.5068, grad_fn=<AddBackward0>)
# tensor(2.5068, grad_fn=<AddBackward0>)
# tensor(2.5067, grad_fn=<AddBackward0>)
# tensor(2.5066, grad_fn=<AddBackward0>)
# tensor(2.5066, grad_fn=<AddBackward0>)
# tensor(2.5065, grad_fn=<AddBackward0>)
# tensor(2.5064, grad_fn=<AddBackward0>)
# tensor(2.5064, grad_fn=<AddBackward0>)
# tensor(2.5063, grad_fn=<AddBackward0>)
# tensor(2.5062, grad_fn=<AddBackward0>)
# tensor(2.5062, grad_fn=<AddBackward0>)
# tensor(2.5061, grad_fn=<AddBackward0>)
# tensor(2.5060, grad_fn=<AddBackward0>)
# tensor(2.5060, grad_fn=<AddBackward0>)
# tensor(2.5059, grad_fn=<AddBackward0>)
# tensor(2.5058, grad_fn=<AddBackward0>)
# tensor(2.5058, grad_fn=<AddBackward0>)
# tensor(2.5057, grad_fn=<AddBackward0>)
# tensor(2.5056, grad_fn=<AddBackward0>)
# tensor(2.5056, grad_fn=<AddBackward0>)
# tensor(2.5055, grad_fn=<AddBackward0>)
# tensor(2.5054, grad_fn=<AddBackward0>)
# tensor(2.5054, grad_fn=<AddBackward0>)
# tensor(2.5053, grad_fn=<AddBackward0>)
# tensor(2.5052, grad_fn=<AddBackward0>)
# tensor(2.5052, grad_fn=<AddBackward0>)
# tensor(2.5051, grad_fn=<AddBackward0>)
# tensor(2.5050, grad_fn=<AddBackward0>)
# tensor(2.5050, grad_fn=<AddBackward0>)
# tensor(2.5049, grad_fn=<AddBackward0>)
# tensor(2.5048, grad_fn=<AddBackward0>)
# tensor(2.5048, grad_fn=<AddBackward0>)
# tensor(2.5047, grad_fn=<AddBackward0>)
# tensor(2.5046, grad_fn=<AddBackward0>)
# tensor(2.5046, grad_fn=<AddBackward0>)
# tensor(2.5045, grad_fn=<AddBackward0>)
# tensor(2.5044, grad_fn=<AddBackward0>)
# tensor(2.5044, grad_fn=<AddBackward0>)
# tensor(2.5043, grad_fn=<AddBackward0>)
# tensor(2.5042, grad_fn=<AddBackward0>)
# tensor(2.5042, grad_fn=<AddBackward0>)
# tensor(2.5041, grad_fn=<AddBackward0>)
# tensor(2.5040, grad_fn=<AddBackward0>)
# tensor(2.5040, grad_fn=<AddBackward0>)
# tensor(2.5039, grad_fn=<AddBackward0>)
# tensor(2.5038, grad_fn=<AddBackward0>)
# tensor(2.5038, grad_fn=<AddBackward0>)
# tensor(2.5037, grad_fn=<AddBackward0>)
# tensor(2.5036, grad_fn=<AddBackward0>)
# tensor(2.5036, grad_fn=<AddBackward0>)
# tensor(2.5035, grad_fn=<AddBackward0>)
# tensor(2.5034, grad_fn=<AddBackward0>)
# tensor(2.5034, grad_fn=<AddBackward0>)
# tensor(2.5033, grad_fn=<AddBackward0>)
# tensor(2.5032, grad_fn=<AddBackward0>)
# tensor(2.5032, grad_fn=<AddBackward0>)
# tensor(2.5031, grad_fn=<AddBackward0>)
# tensor(2.5030, grad_fn=<AddBackward0>)
# tensor(2.5030, grad_fn=<AddBackward0>)
# tensor(2.5029, grad_fn=<AddBackward0>)
# tensor(2.5028, grad_fn=<AddBackward0>)
# tensor(2.5028, grad_fn=<AddBackward0>)
# tensor(2.5027, grad_fn=<AddBackward0>)
# tensor(2.5027, grad_fn=<AddBackward0>)
# tensor(2.5026, grad_fn=<AddBackward0>)
# tensor(2.5025, grad_fn=<AddBackward0>)
# tensor(2.5025, grad_fn=<AddBackward0>)
# tensor(2.5024, grad_fn=<AddBackward0>)
# tensor(2.5023, grad_fn=<AddBackward0>)
# tensor(2.5023, grad_fn=<AddBackward0>)
# tensor(2.5022, grad_fn=<AddBackward0>)
# tensor(2.5021, grad_fn=<AddBackward0>)
# tensor(2.5021, grad_fn=<AddBackward0>)
# tensor(2.5020, grad_fn=<AddBackward0>)
# tensor(2.5019, grad_fn=<AddBackward0>)
# tensor(2.5019, grad_fn=<AddBackward0>)
# tensor(2.5018, grad_fn=<AddBackward0>)
# tensor(2.5017, grad_fn=<AddBackward0>)
# tensor(2.5017, grad_fn=<AddBackward0>)
# tensor(2.5016, grad_fn=<AddBackward0>)
# tensor(2.5015, grad_fn=<AddBackward0>)
# tensor(2.5015, grad_fn=<AddBackward0>)
# tensor(2.5014, grad_fn=<AddBackward0>)
# tensor(2.5013, grad_fn=<AddBackward0>)
# tensor(2.5013, grad_fn=<AddBackward0>)
# tensor(2.5012, grad_fn=<AddBackward0>)
# tensor(2.5012, grad_fn=<AddBackward0>)
# tensor(2.5011, grad_fn=<AddBackward0>)
# tensor(2.5010, grad_fn=<AddBackward0>)
# tensor(2.5010, grad_fn=<AddBackward0>)
# tensor(2.5009, grad_fn=<AddBackward0>)
# tensor(2.5008, grad_fn=<AddBackward0>)
# tensor(2.5008, grad_fn=<AddBackward0>)
# tensor(2.5007, grad_fn=<AddBackward0>)
# tensor(2.5006, grad_fn=<AddBackward0>)
# tensor(2.5006, grad_fn=<AddBackward0>)
# tensor(2.5005, grad_fn=<AddBackward0>)
# tensor(2.5004, grad_fn=<AddBackward0>)
# tensor(2.5004, grad_fn=<AddBackward0>)
# tensor(2.5003, grad_fn=<AddBackward0>)
# tensor(2.5002, grad_fn=<AddBackward0>)
# tensor(2.5002, grad_fn=<AddBackward0>)
# tensor(2.5001, grad_fn=<AddBackward0>)
# tensor(2.5001, grad_fn=<AddBackward0>)
# tensor(2.5000, grad_fn=<AddBackward0>)
# tensor(2.4999, grad_fn=<AddBackward0>)
# tensor(2.4999, grad_fn=<AddBackward0>)
# tensor(2.4998, grad_fn=<AddBackward0>)
# tensor(2.4997, grad_fn=<AddBackward0>)
# tensor(2.4997, grad_fn=<AddBackward0>)
# tensor(2.4996, grad_fn=<AddBackward0>)
# tensor(2.4995, grad_fn=<AddBackward0>)
# tensor(2.4995, grad_fn=<AddBackward0>)
# tensor(2.4994, grad_fn=<AddBackward0>)
# tensor(2.4993, grad_fn=<AddBackward0>)
# tensor(2.4993, grad_fn=<AddBackward0>)
# tensor(2.4992, grad_fn=<AddBackward0>)
# tensor(2.4992, grad_fn=<AddBackward0>)
# tensor(2.4991, grad_fn=<AddBackward0>)
# tensor(2.4990, grad_fn=<AddBackward0>)
# tensor(2.4990, grad_fn=<AddBackward0>)
# tensor(2.4989, grad_fn=<AddBackward0>)
# tensor(2.4988, grad_fn=<AddBackward0>)
# tensor(2.4988, grad_fn=<AddBackward0>)
# tensor(2.4987, grad_fn=<AddBackward0>)
# tensor(2.4986, grad_fn=<AddBackward0>)
# tensor(2.4986, grad_fn=<AddBackward0>)
# tensor(2.4985, grad_fn=<AddBackward0>)
# tensor(2.4985, grad_fn=<AddBackward0>)
# tensor(2.4984, grad_fn=<AddBackward0>)
# tensor(2.4983, grad_fn=<AddBackward0>)
# tensor(2.4983, grad_fn=<AddBackward0>)
# tensor(2.4982, grad_fn=<AddBackward0>)
# tensor(2.4981, grad_fn=<AddBackward0>)
# tensor(2.4981, grad_fn=<AddBackward0>)
# tensor(2.4980, grad_fn=<AddBackward0>)
# tensor(2.4979, grad_fn=<AddBackward0>)
# tensor(2.4979, grad_fn=<AddBackward0>)
# tensor(2.4978, grad_fn=<AddBackward0>)
# tensor(2.4978, grad_fn=<AddBackward0>)
# tensor(2.4977, grad_fn=<AddBackward0>)
# tensor(2.4976, grad_fn=<AddBackward0>)
# tensor(2.4976, grad_fn=<AddBackward0>)
# tensor(2.4975, grad_fn=<AddBackward0>)
# tensor(2.4974, grad_fn=<AddBackward0>)
# tensor(2.4974, grad_fn=<AddBackward0>)
# tensor(2.4973, grad_fn=<AddBackward0>)
# tensor(2.4973, grad_fn=<AddBackward0>)
# tensor(2.4972, grad_fn=<AddBackward0>)
# tensor(2.4971, grad_fn=<AddBackward0>)
# tensor(2.4971, grad_fn=<AddBackward0>)
# tensor(2.4970, grad_fn=<AddBackward0>)
# tensor(2.4969, grad_fn=<AddBackward0>)
# tensor(2.4969, grad_fn=<AddBackward0>)
# tensor(2.4968, grad_fn=<AddBackward0>)
# tensor(2.4967, grad_fn=<AddBackward0>)
# tensor(2.4967, grad_fn=<AddBackward0>)
# tensor(2.4966, grad_fn=<AddBackward0>)
# tensor(2.4966, grad_fn=<AddBackward0>)
# tensor(2.4965, grad_fn=<AddBackward0>)
# tensor(2.4964, grad_fn=<AddBackward0>)
# tensor(2.4964, grad_fn=<AddBackward0>)
# tensor(2.4963, grad_fn=<AddBackward0>)
# tensor(2.4962, grad_fn=<AddBackward0>)
# tensor(2.4962, grad_fn=<AddBackward0>)
# tensor(2.4961, grad_fn=<AddBackward0>)
# tensor(2.4961, grad_fn=<AddBackward0>)
# tensor(2.4960, grad_fn=<AddBackward0>)
# tensor(2.4959, grad_fn=<AddBackward0>)
# tensor(2.4959, grad_fn=<AddBackward0>)
# tensor(2.4958, grad_fn=<AddBackward0>)
# tensor(2.4957, grad_fn=<AddBackward0>)
# tensor(2.4957, grad_fn=<AddBackward0>)
# tensor(2.4956, grad_fn=<AddBackward0>)
# tensor(2.4956, grad_fn=<AddBackward0>)
# tensor(2.4955, grad_fn=<AddBackward0>)
# tensor(2.4954, grad_fn=<AddBackward0>)
# tensor(2.4954, grad_fn=<AddBackward0>)
# tensor(2.4953, grad_fn=<AddBackward0>)
# tensor(2.4952, grad_fn=<AddBackward0>)
# tensor(2.4952, grad_fn=<AddBackward0>)
# tensor(2.4951, grad_fn=<AddBackward0>)
# tensor(2.4951, grad_fn=<AddBackward0>)
# tensor(2.4950, grad_fn=<AddBackward0>)
# tensor(2.4949, grad_fn=<AddBackward0>)
# tensor(2.4949, grad_fn=<AddBackward0>)
# tensor(2.4948, grad_fn=<AddBackward0>)
# tensor(2.4947, grad_fn=<AddBackward0>)
# tensor(2.4947, grad_fn=<AddBackward0>)
# tensor(2.4946, grad_fn=<AddBackward0>)
# tensor(2.4946, grad_fn=<AddBackward0>)
# tensor(2.4945, grad_fn=<AddBackward0>)
# tensor(2.4944, grad_fn=<AddBackward0>)
# tensor(2.4944, grad_fn=<AddBackward0>)
# tensor(2.4943, grad_fn=<AddBackward0>)
# tensor(2.4943, grad_fn=<AddBackward0>)
# tensor(2.4942, grad_fn=<AddBackward0>)
# tensor(2.4941, grad_fn=<AddBackward0>)
# tensor(2.4941, grad_fn=<AddBackward0>)
# tensor(2.4940, grad_fn=<AddBackward0>)
# tensor(2.4939, grad_fn=<AddBackward0>)
# tensor(2.4939, grad_fn=<AddBackward0>)
# tensor(2.4938, grad_fn=<AddBackward0>)
# tensor(2.4938, grad_fn=<AddBackward0>)
# tensor(2.4937, grad_fn=<AddBackward0>)
# tensor(2.4936, grad_fn=<AddBackward0>)
# tensor(2.4936, grad_fn=<AddBackward0>)
# tensor(2.4935, grad_fn=<AddBackward0>)
# tensor(2.4935, grad_fn=<AddBackward0>)
# tensor(2.4934, grad_fn=<AddBackward0>)
# tensor(2.4933, grad_fn=<AddBackward0>)
# tensor(2.4933, grad_fn=<AddBackward0>)
# tensor(2.4932, grad_fn=<AddBackward0>)
# tensor(2.4931, grad_fn=<AddBackward0>)
# tensor(2.4931, grad_fn=<AddBackward0>)
# tensor(2.4930, grad_fn=<AddBackward0>)
# tensor(2.4930, grad_fn=<AddBackward0>)
# tensor(2.4929, grad_fn=<AddBackward0>)
# tensor(2.4928, grad_fn=<AddBackward0>)
# tensor(2.4928, grad_fn=<AddBackward0>)
# tensor(2.4927, grad_fn=<AddBackward0>)
# tensor(2.4927, grad_fn=<AddBackward0>)
# tensor(2.4926, grad_fn=<AddBackward0>)
# tensor(2.4925, grad_fn=<AddBackward0>)
# tensor(2.4925, grad_fn=<AddBackward0>)
# tensor(2.4924, grad_fn=<AddBackward0>)
# tensor(2.4924, grad_fn=<AddBackward0>)
# tensor(2.4923, grad_fn=<AddBackward0>)
# tensor(2.4922, grad_fn=<AddBackward0>)
# tensor(2.4922, grad_fn=<AddBackward0>)
# tensor(2.4921, grad_fn=<AddBackward0>)
# tensor(2.4921, grad_fn=<AddBackward0>)
# tensor(2.4920, grad_fn=<AddBackward0>)
# tensor(2.4919, grad_fn=<AddBackward0>)
# tensor(2.4919, grad_fn=<AddBackward0>)
# tensor(2.4918, grad_fn=<AddBackward0>)
# tensor(2.4917, grad_fn=<AddBackward0>)
# tensor(2.4917, grad_fn=<AddBackward0>)
# tensor(2.4916, grad_fn=<AddBackward0>)
# tensor(2.4916, grad_fn=<AddBackward0>)
# tensor(2.4915, grad_fn=<AddBackward0>)
# tensor(2.4914, grad_fn=<AddBackward0>)
# tensor(2.4914, grad_fn=<AddBackward0>)
# tensor(2.4913, grad_fn=<AddBackward0>)
# tensor(2.4913, grad_fn=<AddBackward0>)
# tensor(2.4912, grad_fn=<AddBackward0>)
# tensor(2.4911, grad_fn=<AddBackward0>)
# tensor(2.4911, grad_fn=<AddBackward0>)
# tensor(2.4910, grad_fn=<AddBackward0>)
# tensor(2.4910, grad_fn=<AddBackward0>)
# tensor(2.4909, grad_fn=<AddBackward0>)
# tensor(2.4908, grad_fn=<AddBackward0>)
# tensor(2.4908, grad_fn=<AddBackward0>)
# tensor(2.4907, grad_fn=<AddBackward0>)
# tensor(2.4907, grad_fn=<AddBackward0>)
# tensor(2.4906, grad_fn=<AddBackward0>)
# tensor(2.4905, grad_fn=<AddBackward0>)
# tensor(2.4905, grad_fn=<AddBackward0>)
# tensor(2.4904, grad_fn=<AddBackward0>)
# tensor(2.4904, grad_fn=<AddBackward0>)
# tensor(2.4903, grad_fn=<AddBackward0>)
# tensor(2.4902, grad_fn=<AddBackward0>)
# tensor(2.4902, grad_fn=<AddBackward0>)
# tensor(2.4901, grad_fn=<AddBackward0>)
# tensor(2.4901, grad_fn=<AddBackward0>)
# tensor(2.4900, grad_fn=<AddBackward0>)
# tensor(2.4899, grad_fn=<AddBackward0>)
# tensor(2.4899, grad_fn=<AddBackward0>)
# tensor(2.4898, grad_fn=<AddBackward0>)
# tensor(2.4898, grad_fn=<AddBackward0>)
# tensor(2.4897, grad_fn=<AddBackward0>)
# tensor(2.4896, grad_fn=<AddBackward0>)
# tensor(2.4896, grad_fn=<AddBackward0>)
# tensor(2.4895, grad_fn=<AddBackward0>)
# tensor(2.4895, grad_fn=<AddBackward0>)
# tensor(2.4894, grad_fn=<AddBackward0>)
# tensor(2.4893, grad_fn=<AddBackward0>)
# tensor(2.4893, grad_fn=<AddBackward0>)
# tensor(2.4892, grad_fn=<AddBackward0>)
# tensor(2.4892, grad_fn=<AddBackward0>)
# tensor(2.4891, grad_fn=<AddBackward0>)
# tensor(2.4890, grad_fn=<AddBackward0>)
# tensor(2.4890, grad_fn=<AddBackward0>)
# tensor(2.4889, grad_fn=<AddBackward0>)
# tensor(2.4889, grad_fn=<AddBackward0>)
# tensor(2.4888, grad_fn=<AddBackward0>)
# tensor(2.4888, grad_fn=<AddBackward0>)
# tensor(2.4887, grad_fn=<AddBackward0>)
# tensor(2.4886, grad_fn=<AddBackward0>)
# tensor(2.4886, grad_fn=<AddBackward0>)
# tensor(2.4885, grad_fn=<AddBackward0>)
# tensor(2.4885, grad_fn=<AddBackward0>)
# tensor(2.4884, grad_fn=<AddBackward0>)
# tensor(2.4883, grad_fn=<AddBackward0>)
# tensor(2.4883, grad_fn=<AddBackward0>)
# tensor(2.4882, grad_fn=<AddBackward0>)
# tensor(2.4882, grad_fn=<AddBackward0>)
# tensor(2.4881, grad_fn=<AddBackward0>)
# tensor(2.4880, grad_fn=<AddBackward0>)
# tensor(2.4880, grad_fn=<AddBackward0>)
# tensor(2.4879, grad_fn=<AddBackward0>)
# tensor(2.4879, grad_fn=<AddBackward0>)
# tensor(2.4878, grad_fn=<AddBackward0>)
# tensor(2.4877, grad_fn=<AddBackward0>)
# tensor(2.4877, grad_fn=<AddBackward0>)
# tensor(2.4876, grad_fn=<AddBackward0>)
# tensor(2.4876, grad_fn=<AddBackward0>)
# tensor(2.4875, grad_fn=<AddBackward0>)
# tensor(2.4875, grad_fn=<AddBackward0>)
# tensor(2.4874, grad_fn=<AddBackward0>)
# tensor(2.4873, grad_fn=<AddBackward0>)
# tensor(2.4873, grad_fn=<AddBackward0>)
# tensor(2.4872, grad_fn=<AddBackward0>)
# tensor(2.4872, grad_fn=<AddBackward0>)
# tensor(2.4871, grad_fn=<AddBackward0>)
# tensor(2.4870, grad_fn=<AddBackward0>)
# tensor(2.4870, grad_fn=<AddBackward0>)
# tensor(2.4869, grad_fn=<AddBackward0>)
# tensor(2.4869, grad_fn=<AddBackward0>)
# tensor(2.4868, grad_fn=<AddBackward0>)
# tensor(2.4868, grad_fn=<AddBackward0>)
# tensor(2.4867, grad_fn=<AddBackward0>)
# tensor(2.4866, grad_fn=<AddBackward0>)
# tensor(2.4866, grad_fn=<AddBackward0>)
# tensor(2.4865, grad_fn=<AddBackward0>)
# tensor(2.4865, grad_fn=<AddBackward0>)
# tensor(2.4864, grad_fn=<AddBackward0>)
# tensor(2.4863, grad_fn=<AddBackward0>)
# tensor(2.4863, grad_fn=<AddBackward0>)
# tensor(2.4862, grad_fn=<AddBackward0>)
# tensor(2.4862, grad_fn=<AddBackward0>)
# tensor(2.4861, grad_fn=<AddBackward0>)
# tensor(2.4861, grad_fn=<AddBackward0>)
# tensor(2.4860, grad_fn=<AddBackward0>)
# tensor(2.4859, grad_fn=<AddBackward0>)
# tensor(2.4859, grad_fn=<AddBackward0>)
# tensor(2.4858, grad_fn=<AddBackward0>)
# tensor(2.4858, grad_fn=<AddBackward0>)
# tensor(2.4857, grad_fn=<AddBackward0>)
# tensor(2.4857, grad_fn=<AddBackward0>)
# tensor(2.4856, grad_fn=<AddBackward0>)
# tensor(2.4855, grad_fn=<AddBackward0>)
# tensor(2.4855, grad_fn=<AddBackward0>)
# tensor(2.4854, grad_fn=<AddBackward0>)
# tensor(2.4854, grad_fn=<AddBackward0>)
# tensor(2.4853, grad_fn=<AddBackward0>)
# tensor(2.4852, grad_fn=<AddBackward0>)
# tensor(2.4852, grad_fn=<AddBackward0>)
# tensor(2.4851, grad_fn=<AddBackward0>)
# tensor(2.4851, grad_fn=<AddBackward0>)
# tensor(2.4850, grad_fn=<AddBackward0>)
# tensor(2.4850, grad_fn=<AddBackward0>)
# tensor(2.4849, grad_fn=<AddBackward0>)
# tensor(2.4848, grad_fn=<AddBackward0>)
# tensor(2.4848, grad_fn=<AddBackward0>)
# tensor(2.4847, grad_fn=<AddBackward0>)
# tensor(2.4847, grad_fn=<AddBackward0>)
# tensor(2.4846, grad_fn=<AddBackward0>)
# tensor(2.4846, grad_fn=<AddBackward0>)
# tensor(2.4845, grad_fn=<AddBackward0>)
# tensor(2.4844, grad_fn=<AddBackward0>)
# tensor(2.4844, grad_fn=<AddBackward0>)
# tensor(2.4843, grad_fn=<AddBackward0>)
# tensor(2.4843, grad_fn=<AddBackward0>)
# tensor(2.4842, grad_fn=<AddBackward0>)
# tensor(2.4842, grad_fn=<AddBackward0>)
# tensor(2.4841, grad_fn=<AddBackward0>)
# tensor(2.4840, grad_fn=<AddBackward0>)
# tensor(2.4840, grad_fn=<AddBackward0>)
# tensor(2.4839, grad_fn=<AddBackward0>)
# tensor(2.4839, grad_fn=<AddBackward0>)
# tensor(2.4838, grad_fn=<AddBackward0>)
# tensor(2.4838, grad_fn=<AddBackward0>)
# tensor(2.4837, grad_fn=<AddBackward0>)
# tensor(2.4836, grad_fn=<AddBackward0>)
# tensor(2.4836, grad_fn=<AddBackward0>)
# tensor(2.4835, grad_fn=<AddBackward0>)
# tensor(2.4835, grad_fn=<AddBackward0>)
# tensor(2.4834, grad_fn=<AddBackward0>)
# tensor(2.4834, grad_fn=<AddBackward0>)
# tensor(2.4833, grad_fn=<AddBackward0>)
# tensor(2.4832, grad_fn=<AddBackward0>)
# tensor(2.4832, grad_fn=<AddBackward0>)
# tensor(2.4831, grad_fn=<AddBackward0>)
# tensor(2.4831, grad_fn=<AddBackward0>)
# tensor(2.4830, grad_fn=<AddBackward0>)
# tensor(2.4830, grad_fn=<AddBackward0>)
# tensor(2.4829, grad_fn=<AddBackward0>)
# tensor(2.4829, grad_fn=<AddBackward0>)
# tensor(2.4828, grad_fn=<AddBackward0>)
# tensor(2.4827, grad_fn=<AddBackward0>)
# tensor(2.4827, grad_fn=<AddBackward0>)
# tensor(2.4826, grad_fn=<AddBackward0>)
# tensor(2.4826, grad_fn=<AddBackward0>)
# tensor(2.4825, grad_fn=<AddBackward0>)
# tensor(2.4825, grad_fn=<AddBackward0>)
# tensor(2.4824, grad_fn=<AddBackward0>)
# tensor(2.4823, grad_fn=<AddBackward0>)
# tensor(2.4823, grad_fn=<AddBackward0>)
# tensor(2.4822, grad_fn=<AddBackward0>)
# tensor(2.4822, grad_fn=<AddBackward0>)
# tensor(2.4821, grad_fn=<AddBackward0>)
# tensor(2.4821, grad_fn=<AddBackward0>)
# tensor(2.4820, grad_fn=<AddBackward0>)
# tensor(2.4820, grad_fn=<AddBackward0>)
# tensor(2.4819, grad_fn=<AddBackward0>)
# tensor(2.4818, grad_fn=<AddBackward0>)
# tensor(2.4818, grad_fn=<AddBackward0>)
# tensor(2.4817, grad_fn=<AddBackward0>)
# tensor(2.4817, grad_fn=<AddBackward0>)
# tensor(2.4816, grad_fn=<AddBackward0>)
# tensor(2.4816, grad_fn=<AddBackward0>)
# tensor(2.4815, grad_fn=<AddBackward0>)
# tensor(2.4814, grad_fn=<AddBackward0>)
# tensor(2.4814, grad_fn=<AddBackward0>)
# tensor(2.4813, grad_fn=<AddBackward0>)
# tensor(2.4813, grad_fn=<AddBackward0>)
# tensor(2.4812, grad_fn=<AddBackward0>)
# tensor(2.4812, grad_fn=<AddBackward0>)
# tensor(2.4811, grad_fn=<AddBackward0>)
# tensor(2.4811, grad_fn=<AddBackward0>)
# tensor(2.4810, grad_fn=<AddBackward0>)
# tensor(2.4809, grad_fn=<AddBackward0>)
# tensor(2.4809, grad_fn=<AddBackward0>)
# tensor(2.4808, grad_fn=<AddBackward0>)
# tensor(2.4808, grad_fn=<AddBackward0>)
# tensor(2.4807, grad_fn=<AddBackward0>)
# tensor(2.4807, grad_fn=<AddBackward0>)
# tensor(2.4806, grad_fn=<AddBackward0>)
# tensor(2.4806, grad_fn=<AddBackward0>)
# tensor(2.4805, grad_fn=<AddBackward0>)
# tensor(2.4804, grad_fn=<AddBackward0>)
# tensor(2.4804, grad_fn=<AddBackward0>)
# tensor(2.4803, grad_fn=<AddBackward0>)
# tensor(2.4803, grad_fn=<AddBackward0>)
# tensor(2.4802, grad_fn=<AddBackward0>)
# tensor(2.4802, grad_fn=<AddBackward0>)
# tensor(2.4801, grad_fn=<AddBackward0>)
# tensor(2.4801, grad_fn=<AddBackward0>)
# tensor(2.4800, grad_fn=<AddBackward0>)
# tensor(2.4800, grad_fn=<AddBackward0>)
# tensor(2.4799, grad_fn=<AddBackward0>)
# tensor(2.4798, grad_fn=<AddBackward0>)
# tensor(2.4798, grad_fn=<AddBackward0>)
# tensor(2.4797, grad_fn=<AddBackward0>)
# tensor(2.4797, grad_fn=<AddBackward0>)
# tensor(2.4796, grad_fn=<AddBackward0>)
# tensor(2.4796, grad_fn=<AddBackward0>)
# tensor(2.4795, grad_fn=<AddBackward0>)
# tensor(2.4795, grad_fn=<AddBackward0>)
# tensor(2.4794, grad_fn=<AddBackward0>)
# tensor(2.4793, grad_fn=<AddBackward0>)
# tensor(2.4793, grad_fn=<AddBackward0>)
# tensor(2.4792, grad_fn=<AddBackward0>)
# tensor(2.4792, grad_fn=<AddBackward0>)
# tensor(2.4791, grad_fn=<AddBackward0>)
# tensor(2.4791, grad_fn=<AddBackward0>)
# tensor(2.4790, grad_fn=<AddBackward0>)
# tensor(2.4790, grad_fn=<AddBackward0>)
# tensor(2.4789, grad_fn=<AddBackward0>)
# tensor(2.4789, grad_fn=<AddBackward0>)
# tensor(2.4788, grad_fn=<AddBackward0>)
# tensor(2.4787, grad_fn=<AddBackward0>)
# tensor(2.4787, grad_fn=<AddBackward0>)
# tensor(2.4786, grad_fn=<AddBackward0>)
# tensor(2.4786, grad_fn=<AddBackward0>)
# tensor(2.4785, grad_fn=<AddBackward0>)
# tensor(2.4785, grad_fn=<AddBackward0>)
# tensor(2.4784, grad_fn=<AddBackward0>)
# tensor(2.4784, grad_fn=<AddBackward0>)
# tensor(2.4783, grad_fn=<AddBackward0>)
# tensor(2.4783, grad_fn=<AddBackward0>)
# tensor(2.4782, grad_fn=<AddBackward0>)
# tensor(2.4781, grad_fn=<AddBackward0>)
# tensor(2.4781, grad_fn=<AddBackward0>)
# tensor(2.4780, grad_fn=<AddBackward0>)
# tensor(2.4780, grad_fn=<AddBackward0>)
# tensor(2.4779, grad_fn=<AddBackward0>)
# tensor(2.4779, grad_fn=<AddBackward0>)
# tensor(2.4778, grad_fn=<AddBackward0>)
# tensor(2.4778, grad_fn=<AddBackward0>)
# tensor(2.4777, grad_fn=<AddBackward0>)
# tensor(2.4777, grad_fn=<AddBackward0>)
# tensor(2.4776, grad_fn=<AddBackward0>)
# tensor(2.4776, grad_fn=<AddBackward0>)
# tensor(2.4775, grad_fn=<AddBackward0>)
# tensor(2.4774, grad_fn=<AddBackward0>)
# tensor(2.4774, grad_fn=<AddBackward0>)
# tensor(2.4773, grad_fn=<AddBackward0>)
# tensor(2.4773, grad_fn=<AddBackward0>)
# tensor(2.4772, grad_fn=<AddBackward0>)
# tensor(2.4772, grad_fn=<AddBackward0>)
# tensor(2.4771, grad_fn=<AddBackward0>)
# tensor(2.4771, grad_fn=<AddBackward0>)
# tensor(2.4770, grad_fn=<AddBackward0>)
# tensor(2.4770, grad_fn=<AddBackward0>)
# tensor(2.4769, grad_fn=<AddBackward0>)
# tensor(2.4769, grad_fn=<AddBackward0>)
# tensor(2.4768, grad_fn=<AddBackward0>)
# tensor(2.4767, grad_fn=<AddBackward0>)
# tensor(2.4767, grad_fn=<AddBackward0>)
# tensor(2.4766, grad_fn=<AddBackward0>)
# tensor(2.4766, grad_fn=<AddBackward0>)
# tensor(2.4765, grad_fn=<AddBackward0>)
# tensor(2.4765, grad_fn=<AddBackward0>)
# tensor(2.4764, grad_fn=<AddBackward0>)
# tensor(2.4764, grad_fn=<AddBackward0>)
# tensor(2.4763, grad_fn=<AddBackward0>)
# tensor(2.4763, grad_fn=<AddBackward0>)
# tensor(2.4762, grad_fn=<AddBackward0>)
# tensor(2.4762, grad_fn=<AddBackward0>)
# tensor(2.4761, grad_fn=<AddBackward0>)
# tensor(2.4761, grad_fn=<AddBackward0>)
# tensor(2.4760, grad_fn=<AddBackward0>)
# tensor(2.4759, grad_fn=<AddBackward0>)
# tensor(2.4759, grad_fn=<AddBackward0>)
# tensor(2.4758, grad_fn=<AddBackward0>)
# tensor(2.4758, grad_fn=<AddBackward0>)
# tensor(2.4757, grad_fn=<AddBackward0>)
# tensor(2.4757, grad_fn=<AddBackward0>)
# tensor(2.4756, grad_fn=<AddBackward0>)
# tensor(2.4756, grad_fn=<AddBackward0>)
# tensor(2.4755, grad_fn=<AddBackward0>)
# tensor(2.4755, grad_fn=<AddBackward0>)
# tensor(2.4754, grad_fn=<AddBackward0>)
# tensor(2.4754, grad_fn=<AddBackward0>)
# tensor(2.4753, grad_fn=<AddBackward0>)
# tensor(2.4753, grad_fn=<AddBackward0>)
# tensor(2.4752, grad_fn=<AddBackward0>)
# tensor(2.4751, grad_fn=<AddBackward0>)
# tensor(2.4751, grad_fn=<AddBackward0>)
# tensor(2.4750, grad_fn=<AddBackward0>)
# tensor(2.4750, grad_fn=<AddBackward0>)
# tensor(2.4749, grad_fn=<AddBackward0>)
# tensor(2.4749, grad_fn=<AddBackward0>)
# tensor(2.4748, grad_fn=<AddBackward0>)
# tensor(2.4748, grad_fn=<AddBackward0>)
# tensor(2.4747, grad_fn=<AddBackward0>)
# tensor(2.4747, grad_fn=<AddBackward0>)
# tensor(2.4746, grad_fn=<AddBackward0>)
# tensor(2.4746, grad_fn=<AddBackward0>)
# tensor(2.4745, grad_fn=<AddBackward0>)
# tensor(2.4745, grad_fn=<AddBackward0>)
# tensor(2.4744, grad_fn=<AddBackward0>)
# tensor(2.4744, grad_fn=<AddBackward0>)
# tensor(2.4743, grad_fn=<AddBackward0>)
# tensor(2.4743, grad_fn=<AddBackward0>)
# tensor(2.4742, grad_fn=<AddBackward0>)
# tensor(2.4741, grad_fn=<AddBackward0>)
# tensor(2.4741, grad_fn=<AddBackward0>)
# tensor(2.4740, grad_fn=<AddBackward0>)
# tensor(2.4740, grad_fn=<AddBackward0>)
# tensor(2.4739, grad_fn=<AddBackward0>)
# tensor(2.4739, grad_fn=<AddBackward0>)
# tensor(2.4738, grad_fn=<AddBackward0>)
# tensor(2.4738, grad_fn=<AddBackward0>)
# tensor(2.4737, grad_fn=<AddBackward0>)
# tensor(2.4737, grad_fn=<AddBackward0>)
# tensor(2.4736, grad_fn=<AddBackward0>)
# tensor(2.4736, grad_fn=<AddBackward0>)
# tensor(2.4735, grad_fn=<AddBackward0>)
# tensor(2.4735, grad_fn=<AddBackward0>)
# tensor(2.4734, grad_fn=<AddBackward0>)
# tensor(2.4734, grad_fn=<AddBackward0>)
# tensor(2.4733, grad_fn=<AddBackward0>)
# tensor(2.4733, grad_fn=<AddBackward0>)
# tensor(2.4732, grad_fn=<AddBackward0>)
# tensor(2.4732, grad_fn=<AddBackward0>)
# tensor(2.4731, grad_fn=<AddBackward0>)
# tensor(2.4731, grad_fn=<AddBackward0>)
# tensor(2.4730, grad_fn=<AddBackward0>)
# tensor(2.4730, grad_fn=<AddBackward0>)
# tensor(2.4729, grad_fn=<AddBackward0>)
# tensor(2.4728, grad_fn=<AddBackward0>)
# tensor(2.4728, grad_fn=<AddBackward0>)
# tensor(2.4727, grad_fn=<AddBackward0>)
# tensor(2.4727, grad_fn=<AddBackward0>)
# tensor(2.4726, grad_fn=<AddBackward0>)
# tensor(2.4726, grad_fn=<AddBackward0>)
# tensor(2.4725, grad_fn=<AddBackward0>)
# tensor(2.4725, grad_fn=<AddBackward0>)
# tensor(2.4724, grad_fn=<AddBackward0>)
# tensor(2.4724, grad_fn=<AddBackward0>)
# tensor(2.4723, grad_fn=<AddBackward0>)
# tensor(2.4723, grad_fn=<AddBackward0>)
# tensor(2.4722, grad_fn=<AddBackward0>)
# tensor(2.4722, grad_fn=<AddBackward0>)
# tensor(2.4721, grad_fn=<AddBackward0>)
# tensor(2.4721, grad_fn=<AddBackward0>)
# tensor(2.4720, grad_fn=<AddBackward0>)
# tensor(2.4720, grad_fn=<AddBackward0>)
# tensor(2.4719, grad_fn=<AddBackward0>)
# tensor(2.4719, grad_fn=<AddBackward0>)
# tensor(2.4718, grad_fn=<AddBackward0>)
# tensor(2.4718, grad_fn=<AddBackward0>)
# tensor(2.4717, grad_fn=<AddBackward0>)
# tensor(2.4717, grad_fn=<AddBackward0>)
# tensor(2.4716, grad_fn=<AddBackward0>)
# tensor(2.4716, grad_fn=<AddBackward0>)
# tensor(2.4715, grad_fn=<AddBackward0>)
# tensor(2.4715, grad_fn=<AddBackward0>)
# tensor(2.4714, grad_fn=<AddBackward0>)
# tensor(2.4714, grad_fn=<AddBackward0>)
# tensor(2.4713, grad_fn=<AddBackward0>)
# tensor(2.4713, grad_fn=<AddBackward0>)
# tensor(2.4712, grad_fn=<AddBackward0>)
# tensor(2.4712, grad_fn=<AddBackward0>)
# tensor(2.4711, grad_fn=<AddBackward0>)
# tensor(2.4711, grad_fn=<AddBackward0>)
# tensor(2.4710, grad_fn=<AddBackward0>)
# tensor(2.4710, grad_fn=<AddBackward0>)
# tensor(2.4709, grad_fn=<AddBackward0>)
# tensor(2.4708, grad_fn=<AddBackward0>)
# tensor(2.4708, grad_fn=<AddBackward0>)
# tensor(2.4707, grad_fn=<AddBackward0>)
# tensor(2.4707, grad_fn=<AddBackward0>)
# tensor(2.4706, grad_fn=<AddBackward0>)
# tensor(2.4706, grad_fn=<AddBackward0>)
# tensor(2.4705, grad_fn=<AddBackward0>)
# tensor(2.4705, grad_fn=<AddBackward0>)
# tensor(2.4704, grad_fn=<AddBackward0>)
# tensor(2.4704, grad_fn=<AddBackward0>)
# tensor(2.4703, grad_fn=<AddBackward0>)
# tensor(2.4703, grad_fn=<AddBackward0>)
# tensor(2.4702, grad_fn=<AddBackward0>)
# tensor(2.4702, grad_fn=<AddBackward0>)
# tensor(2.4701, grad_fn=<AddBackward0>)
# tensor(2.4701, grad_fn=<AddBackward0>)
# tensor(2.4700, grad_fn=<AddBackward0>)
# tensor(2.4700, grad_fn=<AddBackward0>)
# tensor(2.4699, grad_fn=<AddBackward0>)
# tensor(2.4699, grad_fn=<AddBackward0>)
# tensor(2.4698, grad_fn=<AddBackward0>)
# tensor(2.4698, grad_fn=<AddBackward0>)
# tensor(2.4697, grad_fn=<AddBackward0>)
# tensor(2.4697, grad_fn=<AddBackward0>)
# tensor(2.4696, grad_fn=<AddBackward0>)
# tensor(2.4696, grad_fn=<AddBackward0>)
# tensor(2.4695, grad_fn=<AddBackward0>)
# tensor(2.4695, grad_fn=<AddBackward0>)
# tensor(2.4694, grad_fn=<AddBackward0>)
# tensor(2.4694, grad_fn=<AddBackward0>)
# tensor(2.4693, grad_fn=<AddBackward0>)
# tensor(2.4693, grad_fn=<AddBackward0>)
# tensor(2.4692, grad_fn=<AddBackward0>)
# tensor(2.4692, grad_fn=<AddBackward0>)
# tensor(2.4691, grad_fn=<AddBackward0>)
# tensor(2.4691, grad_fn=<AddBackward0>)
# tensor(2.4690, grad_fn=<AddBackward0>)
# tensor(2.4690, grad_fn=<AddBackward0>)
# tensor(2.4689, grad_fn=<AddBackward0>)
# tensor(2.4689, grad_fn=<AddBackward0>)
# tensor(2.4688, grad_fn=<AddBackward0>)
# tensor(2.4688, grad_fn=<AddBackward0>)
# tensor(2.4687, grad_fn=<AddBackward0>)
# tensor(2.4687, grad_fn=<AddBackward0>)
# tensor(2.4686, grad_fn=<AddBackward0>)
# tensor(2.4686, grad_fn=<AddBackward0>)
# tensor(2.4685, grad_fn=<AddBackward0>)
# tensor(2.4685, grad_fn=<AddBackward0>)
# tensor(2.4684, grad_fn=<AddBackward0>)
# tensor(2.4684, grad_fn=<AddBackward0>)
# tensor(2.4683, grad_fn=<AddBackward0>)
# tensor(2.4683, grad_fn=<AddBackward0>)
# tensor(2.4682, grad_fn=<AddBackward0>)
# tensor(2.4682, grad_fn=<AddBackward0>)
# tensor(2.4681, grad_fn=<AddBackward0>)
# tensor(2.4681, grad_fn=<AddBackward0>)
# tensor(2.4680, grad_fn=<AddBackward0>)
# tensor(2.4680, grad_fn=<AddBackward0>)
# tensor(2.4679, grad_fn=<AddBackward0>)
# tensor(2.4679, grad_fn=<AddBackward0>)
# tensor(2.4678, grad_fn=<AddBackward0>)
# tensor(2.4678, grad_fn=<AddBackward0>)
# tensor(2.4677, grad_fn=<AddBackward0>)
# tensor(2.4677, grad_fn=<AddBackward0>)
# tensor(2.4677, grad_fn=<AddBackward0>)
# tensor(2.4676, grad_fn=<AddBackward0>)
# tensor(2.4676, grad_fn=<AddBackward0>)
# tensor(2.4675, grad_fn=<AddBackward0>)
# tensor(2.4675, grad_fn=<AddBackward0>)
# tensor(2.4674, grad_fn=<AddBackward0>)
# tensor(2.4674, grad_fn=<AddBackward0>)
# tensor(2.4673, grad_fn=<AddBackward0>)
# tensor(2.4673, grad_fn=<AddBackward0>)
# ...
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4002, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4001, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.4000, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3999, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3998, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3997, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3996, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3995, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3994, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3993, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3992, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3991, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3990, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3989, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3988, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3987, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3986, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# tensor(2.3985, grad_fn=<AddBackward0>)
# 4501
# reduced chi^2 level 2 = 2.398475170135498
# reduced chi^2 level 1 = 2.1493003368377686
# Constrained alpha: -2.5999999046325684

# %%
closure_fit = Postfit()
# neutrino_pdfs, N_event_pred = closure_fit.apply_postfit_criteria(arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred,neutrino_pdfs)

# %%
# Quantitative validation of PDF uncertainties in closure tests
# theoretical prediction for # of events
pdf = "faserv"
lowx = -8
n=50
x_vals = generate_grid(lowx,n)

faser_pdf,x_faser = read_pdf(pdf,x_vals)
postfit_measures = Measures(cov_matrix, pdf, N_event_pred)
delta_chi = postfit_measures.compute_delta_chi(num_obs, fk_tables, binwidths, mask, level1[0],x_vals)
print(f'delta chi^2 = {delta_chi}')

phi_chi_squared = postfit_measures.compute_phi(data, chi_squares)
print(f'phi level 2 = {phi_chi_squared}')

dist,xnu  = postfit_measures.compute_distance(neutrino_pdfs,x_vals)
plt.plot(xnu,dist,'o')
plt.ylabel('distance to truth')
plt.xlabel('xnu')
plt.show()
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# torch.Size([50])
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001
# delta chi^2 = -0.98853600025177
# phi level 2 = 0.0
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
pdf = "faserv"
lowx = -8
n=250
x_vals = generate_grid(lowx,n)

faser_pdf,x_faser = read_pdf(pdf,x_vals)
cont_x = x_alpha_more_bins.detach().numpy().flatten()
mean_neutrino_fit = np.mean(neutrino_pdfs,axis=0)
error_neutrino_fit = np.std(neutrino_pdfs,axis=0) 

plt.plot(cont_x,mean_neutrino_fit,'o',label="best fit",markersize=1.5)
plt.axvline(x=min(xvals_per_obs[0])/14000, color='green', linestyle='--', label='no data to the left of this line')
plt.fill_between(cont_x,mean_neutrino_fit+error_neutrino_fit,mean_neutrino_fit-error_neutrino_fit,label='1 sigma error',color = 'red',alpha=0.6)
plt.plot(x_faser,faser_pdf,label ='faserv pdf')
plt.ylim(10**-3,10**5)
plt.xlim(10**-4,1.1)
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.savefig('neutrino_fit.pdf')
plt.show()
# Out:
# LHAPDF 6.5.4 loading /opt/anaconda3/envs/ML_fit/share/LHAPDF/faserv/faserv_0000.dat
# faserv PDF set, member #0, version 1; LHAPDF ID = 50000001

# %%
plt.plot(cont_x,mean_neutrino_fit/mean_neutrino_fit,'o',label="best fit",markersize=1.5)
plt.fill_between(cont_x,(mean_neutrino_fit+error_neutrino_fit)/mean_neutrino_fit,(mean_neutrino_fit-error_neutrino_fit)/mean_neutrino_fit,label='1 sigma error',color = 'red',alpha=0.6)
plt.plot(x_faser,faser_pdf/faser_pdf,label ='faserv pdf')
plt.xlim(6*10**-4,0.5)
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()
# Out:
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_87504/2878806403.py:3: RuntimeWarning: invalid value encountered in divide
#   plt.plot(x_faser,faser_pdf/faser_pdf,label ='faserv pdf')

# %%
mean_N_event_fits = np.mean(N_event_pred,axis=0)
sigma_N_event_fits = np.std(N_event_pred,axis=0)
start = 0
for i in range(num_obs):
    stop = len(xvals_per_obs[i])
    mean_N_event_fit = mean_N_event_fits[start:stop+start] 
    sigma_N_event_fit = sigma_N_event_fits[start:stop+start] 
    plt.plot(xvals_per_obs[i],mean_N_event_fit,label=f"{xlabels[i]} fit")
    
    plt.fill_between(xvals_per_obs[i],(mean_N_event_fit+sigma_N_event_fit),(mean_N_event_fit-sigma_N_event_fit),label='1 sigma error',color = 'red',alpha=0.6)
    
    plt.plot(xvals_per_obs[i],events_per_obs[i],'go',label='data',markersize=1.5)

    plt.xlabel(f'{xlabels[i]}')
    plt.ylabel('N')
    
    plt.legend()
    plt.show()
    start += stop

# %%
start = 0
for i in range(num_obs):
    stop = len(xvals_per_obs[i])
    mean_N_event_fit = mean_N_event_fits[start:stop+start] 
    sigma_N_event_fit = sigma_N_event_fits[start:stop+start] 
    
    plt.plot(xvals_per_obs[i],mean_N_event_fit/mean_N_event_fit,label=f"{xlabels[i]} fit")
    
    plt.fill_between(xvals_per_obs[i],(mean_N_event_fit+sigma_N_event_fit)/mean_N_event_fit,(mean_N_event_fit-sigma_N_event_fit)/mean_N_event_fit,label='1 sigma error',color = 'red',alpha=0.6)
    
    plt.plot(xvals_per_obs[i],events_per_obs[i]/events_per_obs[i],'go',label='data',markersize=1.5)

    plt.xlabel(f'{xlabels[i]}')
    plt.ylabel('relative N')
    
    plt.legend()
    plt.show()
    start += stop
# Out:
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_87504/400985866.py:7: RuntimeWarning: invalid value encountered in divide
#   plt.plot(xvals_per_obs[i],mean_N_event_fit/mean_N_event_fit,label=f"{xlabels[i]} fit")
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_87504/400985866.py:9: RuntimeWarning: invalid value encountered in divide
#   plt.fill_between(xvals_per_obs[i],(mean_N_event_fit+sigma_N_event_fit)/mean_N_event_fit,(mean_N_event_fit-sigma_N_event_fit)/mean_N_event_fit,label='1 sigma error',color = 'red',alpha=0.6)
# /var/folders/ph/sg5840xd0fxgcl0kh643h5_00000gp/T/ipykernel_87504/400985866.py:11: RuntimeWarning: invalid value encountered in divide
#   plt.plot(xvals_per_obs[i],events_per_obs[i]/events_per_obs[i],'go',label='data',markersize=1.5)

# %%
def compute_accuracy():
    log_spaced = np.logspace(np.log10(1e-5), np.log10(0.1), 10)
    linear_spaced = np.linspace(0.1, 1, 10)
    x_xi_measure = np.concatenate((log_spaced, linear_spaced))
    x_xi_measure= torch.tensor(x_xi_measure, dtype=torch.float32).view(-1,1)

    pdf = "faserv"

    faser_pdf,x_faser = read_pdf(pdf,x_xi_measure)
    faser_pdf =faser_pdf.detach().numpy().squeeze()

    arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level1,REPLICAS=  1)
    mean_neutrino_pdf =model(x_xi_measure).detach().numpy().squeeze()
    
    return mean_neutrino_pdf,faser_pdf,n

# mean_neutrino_pdf,faser_pdf,n = compute_accuracy()
# xi = np.sum(abs(mean_neutrino_pdf-faser_pdf) < error_neutrino_fit)/ n
# print(f'xi = {xi}')

# %%
def compute_bias_to_variance(num_level1_shifts,level0,level1,level2):
    biases = []
    variances = []
    level1 = np.array(level1)
    level0 = np.array(level0)
    diff_level01 = level1 - level0
    level2 -= diff_level01
    level0 = torch.tensor(level0, dtype=torch.float32)
    for i in range(num_level1_shifts):
        
        # generate level2 data with different level 1 shifts
        r_sys = np.random.normal(0, 1) * sig_sys / 10
        r_stat = np.random.normal(0, 1) * np.sqrt(data) / 10
        level2 += r_sys + r_stat
        level2 = torch.tensor(level2, dtype=torch.float32)
        
        arc_lenghts, chi_squares,pos_penaltys,int_penaltys,N_event_pred, neutrino_pdfs,model = perform_fit(level2,REPLICAS = 3)
        mean_N_events = np.mean(N_event_pred,axis=0)
        mean_N_events = torch.tensor(mean_N_events, dtype=torch.float32)
        
        mean_chi_square = raw_loss_fct(level0[0],mean_N_events,cov_matrix)
        biases.append(mean_chi_square)

        chi_square_level2 = 0
        for j in range (REPLICAS):
            chi_square_level2 += raw_loss_fct(level2[j],mean_N_events, cov_matrix)
        variances.append(chi_square_level2/REPLICAS)


    exp_bias = np.mean(biases)
    exp_variance = np.mean(variances)
    ratio = exp_bias/exp_variance
    return ratio
    
# ratio = compute_bias_to_variance(1,level0,level1,level2)
# print(f'ratio = {ratio}')


#BIAS:
    # mc reps = level 1 + level 2
    # average over level 1: keep level 2 the same, but add different level 1 shifts
    # compute reduced chi square with respect to level 0 data
    # VARIANCE:
    # mc reps = level 1 + level 2
    # average chi^2 over several level 2 shifts
    # do not average over level 1 shifts since it is expected to be constant
    # Compute reduced chi square with respect to all level 2 replics: so do not have to run a lot more fits it seems
    # however since these multiple level 1 fits have to be run anyway, it is no problemo
